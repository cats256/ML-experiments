# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchinfo import summary

# %%
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(device)
# Out:
# mps

# %% [markdown]
# Experiment with exploiting symmetries through convolution filter rotations and reflections. Works pretty well :)

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = datasets.FashionMNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root='./data', train=False, download=True, transform=transform)

# %%
train_data = train_dataset.data.to(device).float() / 255.0
train_targets = train_dataset.targets.to(device)

test_data = test_dataset.data.to(device).float() / 255.0
test_targets = test_dataset.targets.to(device)

train_data = train_data.unsqueeze(1)
test_data = test_data.unsqueeze(1)

def get_batches(data, targets, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size], targets[i:i + batch_size]

batch_size = 2000
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ExperimentalModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 4, kernel_size=2, stride=2, padding=1)       # 28x28 -> 15x15
        self.conv2 = nn.Conv2d(4, 8, kernel_size=3, stride=2, padding=1)   # 15x15 -> 8x8
        self.conv3 = nn.Conv2d(8, 8, kernel_size=4, stride=1, padding=1)   # 8x8   -> 7x7
        self.conv4 = nn.Conv2d(8, 16, kernel_size=5, stride=1, padding=1)  # 7x7   -> 5x5
        self.conv5 = nn.Conv2d(16, 16, kernel_size=5, stride=1, padding=0) # 5x5   -> 1x1

        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(16, 10)

    def _conv_relu(self, x: torch.Tensor, conv_layer: torch.nn.Conv2d):
        w   = conv_layer.weight
        s, p = conv_layer.stride, conv_layer.padding
    
        kernels = torch.cat([
            w,
            torch.rot90(w, 1, (2, 3)),
            torch.rot90(w, 2, (2, 3)),
            torch.rot90(w, 3, (2, 3)),
            torch.flip(w, (3,)),
            torch.flip(w, (2,)),
            w.transpose(2, 3),
            torch.flip(w.transpose(2, 3), (2, 3)),
        ], dim=0)
    
        y = F.conv2d(x, kernels, bias=conv_layer.bias.repeat(1), stride=s, padding=p)    
        return self.relu(y)

    def forward(self, x):
        x = self._conv_relu(x, self.conv1)
        x = self._conv_relu(x, self.conv2)
        x = self._conv_relu(x, self.conv3)
        x = self._conv_relu(x, self.conv4)
        x = self._conv_relu(x, self.conv5)

        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class DepthwiseSeparableConv(nn.Module):
    def __init__(self, in_channels, out_channels, kernel_size, stride, padding):
        super().__init__()
        self.depthwise = nn.Conv2d(in_channels, in_channels, kernel_size=kernel_size, stride=stride, padding=padding, groups=in_channels, bias=True)
        self.pointwise = nn.Conv2d(in_channels * 8, out_channels, kernel_size=1, bias=True)
        self.relu = nn.ReLU(inplace=True)

    def forward(self, x):
        w = self.depthwise.weight
        b = self.depthwise.bias
        s, p = self.depthwise.stride, self.depthwise.padding

        kernels = torch.cat([
            w,
            torch.rot90(w, 1, (2, 3)),
            torch.rot90(w, 2, (2, 3)),
            torch.rot90(w, 3, (2, 3)),
            torch.flip(w, (3,)),
            torch.flip(w, (2,)),
            w.transpose(2, 3),
            torch.flip(w.transpose(2, 3), (2, 3)),
        ], dim=0)

        x = F.conv2d(x, kernels, bias=b.repeat(8), stride=s, padding=p, groups=x.shape[1])
        x = self.relu(x)

        x = self.pointwise(x)
        return x

class ExperimentalModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = DepthwiseSeparableConv(1, 8, kernel_size=2, stride=2, padding=1)   # 28x28 -> 15x15
        self.conv2 = DepthwiseSeparableConv(8, 16, kernel_size=3, stride=2, padding=1)  # 15x15 -> 8x8
        self.conv3 = DepthwiseSeparableConv(16, 32, kernel_size=4, stride=1, padding=1)  # 8x8 -> 7x7
        self.conv4 = DepthwiseSeparableConv(32, 32, kernel_size=5, stride=1, padding=1)  # 7x7 -> 5x5
        self.conv5 = DepthwiseSeparableConv(32, 64, kernel_size=5, stride=1, padding=0)  # 5x5 -> 1x1

        self.fc = nn.Linear(64, 10)

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)

        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
learning_rate = 0.001 * 1
epochs = 1000

model = ExperimentalModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for name, param in model.named_parameters():
    print(f"{name}: {param.numel()} params, requires_grad={param.requires_grad}")

total_params = sum(p.numel() for p in model.parameters())
print()
print(total_params)
# Out:
# conv1.depthwise.weight: 4 params, requires_grad=True
# conv1.depthwise.bias: 1 params, requires_grad=True
# conv1.pointwise.weight: 64 params, requires_grad=True
# conv1.pointwise.bias: 8 params, requires_grad=True
# conv2.depthwise.weight: 72 params, requires_grad=True
# conv2.depthwise.bias: 8 params, requires_grad=True
# conv2.pointwise.weight: 1024 params, requires_grad=True
# conv2.pointwise.bias: 16 params, requires_grad=True
# conv3.depthwise.weight: 256 params, requires_grad=True
# conv3.depthwise.bias: 16 params, requires_grad=True
# conv3.pointwise.weight: 4096 params, requires_grad=True
# conv3.pointwise.bias: 32 params, requires_grad=True
# conv4.depthwise.weight: 800 params, requires_grad=True
# conv4.depthwise.bias: 32 params, requires_grad=True
# conv4.pointwise.weight: 8192 params, requires_grad=True
# conv4.pointwise.bias: 32 params, requires_grad=True
# conv5.depthwise.weight: 800 params, requires_grad=True
# conv5.depthwise.bias: 32 params, requires_grad=True
# conv5.pointwise.weight: 16384 params, requires_grad=True
# conv5.pointwise.bias: 64 params, requires_grad=True
# fc.weight: 640 params, requires_grad=True
# fc.bias: 10 params, requires_grad=True
#
# 32583

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 2.2931
# Epoch [1/1000], Validation Loss: 2.2249, Validation Accuracy: 37.24%
# Output Summary: Max=0.1836, Min=-0.1928, Median=-0.0041, Mean=-0.0026
#
# Epoch [2/1000], Training Loss: 1.5187
# Epoch [2/1000], Validation Loss: 0.8940, Validation Accuracy: 67.27%
# Output Summary: Max=24.1974, Min=-23.6897, Median=1.8750, Mean=0.2262
#
# Epoch [3/1000], Training Loss: 0.7783
# Epoch [3/1000], Validation Loss: 0.7291, Validation Accuracy: 73.09%
# Output Summary: Max=21.0874, Min=-25.0418, Median=2.3647, Mean=0.2783
#
# Epoch [4/1000], Training Loss: 0.6771
# Epoch [4/1000], Validation Loss: 0.6646, Validation Accuracy: 74.56%
# Output Summary: Max=21.5659, Min=-26.4458, Median=2.7635, Mean=0.2243
#
# Epoch [5/1000], Training Loss: 0.6306
# Epoch [5/1000], Validation Loss: 0.6291, Validation Accuracy: 76.51%
# Output Summary: Max=22.2256, Min=-26.9921, Median=3.0525, Mean=0.1838
#
# Epoch [6/1000], Training Loss: 0.6017
# Epoch [6/1000], Validation Loss: 0.6076, Validation Accuracy: 77.25%
# Output Summary: Max=23.1940, Min=-27.4050, Median=3.1127, Mean=0.1803
#
# Epoch [7/1000], Training Loss: 0.5791
# Epoch [7/1000], Validation Loss: 0.5880, Validation Accuracy: 77.80%
# Output Summary: Max=24.1958, Min=-27.9557, Median=3.1609, Mean=0.1706
#
# Epoch [8/1000], Training Loss: 0.5616
# Epoch [8/1000], Validation Loss: 0.5723, Validation Accuracy: 78.37%
# Output Summary: Max=24.8426, Min=-28.3376, Median=3.1723, Mean=0.1636
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 20
#      16     loss.backward()
#      19     optimizer.step()
# ---> 20     running_loss += loss.item()
#      21     num_batches += 1
#      23 print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")
#
# KeyboardInterrupt:

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 2.3012
# Epoch [1/1000], Validation Loss: 2.2882, Validation Accuracy: 19.46%
# Output Summary: Max=0.0703, Min=-0.1166, Median=-0.0117, Mean=-0.0130
#
# Epoch [2/1000], Training Loss: 2.0032
# Epoch [2/1000], Validation Loss: 1.4941, Validation Accuracy: 48.34%
# Output Summary: Max=4.3050, Min=-8.2861, Median=0.1374, Mean=-0.0165
#
# Epoch [3/1000], Training Loss: 1.0819
# Epoch [3/1000], Validation Loss: 0.8928, Validation Accuracy: 66.38%
# Output Summary: Max=23.2645, Min=-25.5696, Median=1.9330, Mean=-0.0560
#
# Epoch [4/1000], Training Loss: 0.8255
# Epoch [4/1000], Validation Loss: 0.7981, Validation Accuracy: 70.98%
# Output Summary: Max=22.4251, Min=-27.6378, Median=1.9379, Mean=-0.1756
#
# Epoch [5/1000], Training Loss: 0.7518
# Epoch [5/1000], Validation Loss: 0.7370, Validation Accuracy: 72.64%
# Output Summary: Max=23.8140, Min=-29.3738, Median=2.1945, Mean=-0.2213
#
# Epoch [6/1000], Training Loss: 0.6978
# Epoch [6/1000], Validation Loss: 0.6898, Validation Accuracy: 73.92%
# Output Summary: Max=24.8212, Min=-30.3995, Median=2.3010, Mean=-0.2720
#
# Epoch [7/1000], Training Loss: 0.6572
# Epoch [7/1000], Validation Loss: 0.6596, Validation Accuracy: 74.57%
# Output Summary: Max=24.8503, Min=-30.4997, Median=2.3447, Mean=-0.2800
#
# Epoch [8/1000], Training Loss: 0.6310
# Epoch [8/1000], Validation Loss: 0.6414, Validation Accuracy: 75.24%
# Output Summary: Max=24.7915, Min=-30.0924, Median=2.2950, Mean=-0.2725
#
# Epoch [9/1000], Training Loss: 0.6128
# Epoch [9/1000], Validation Loss: 0.6347, Validation Accuracy: 75.61%
# Output Summary: Max=24.5739, Min=-29.7025, Median=2.2609, Mean=-0.2740
#
# Epoch [10/1000], Training Loss: 0.5967
# Epoch [10/1000], Validation Loss: 0.6129, Validation Accuracy: 76.70%
# Output Summary: Max=24.6939, Min=-29.1637, Median=2.1561, Mean=-0.2721
#
# Epoch [11/1000], Training Loss: 0.5793
# Epoch [11/1000], Validation Loss: 0.5967, Validation Accuracy: 77.28%
# Output Summary: Max=24.9037, Min=-28.7846, Median=2.0808, Mean=-0.2746
#
# Epoch [12/1000], Training Loss: 0.5643
# Epoch [12/1000], Validation Loss: 0.5844, Validation Accuracy: 77.75%
# Output Summary: Max=25.0866, Min=-28.9738, Median=2.0187, Mean=-0.2832
#
# Epoch [13/1000], Training Loss: 0.5506
# Epoch [13/1000], Validation Loss: 0.5722, Validation Accuracy: 78.29%
# Output Summary: Max=25.1865, Min=-29.1716, Median=1.9656, Mean=-0.2917
#
# Epoch [14/1000], Training Loss: 0.5375
# Epoch [14/1000], Validation Loss: 0.5606, Validation Accuracy: 78.70%
# Output Summary: Max=25.1581, Min=-29.0955, Median=1.9119, Mean=-0.2986
#
# Epoch [15/1000], Training Loss: 0.5250
# Epoch [15/1000], Validation Loss: 0.5489, Validation Accuracy: 79.38%
# Output Summary: Max=25.0997, Min=-29.1170, Median=1.8747, Mean=-0.3066
#
# Epoch [16/1000], Training Loss: 0.5129
# Epoch [16/1000], Validation Loss: 0.5379, Validation Accuracy: 79.82%
# Output Summary: Max=25.1168, Min=-28.8534, Median=1.8081, Mean=-0.3123
#
# Epoch [17/1000], Training Loss: 0.5012
# Epoch [17/1000], Validation Loss: 0.5273, Validation Accuracy: 80.29%
# Output Summary: Max=25.0923, Min=-28.7165, Median=1.7454, Mean=-0.3244
#
# Epoch [18/1000], Training Loss: 0.4898
# Epoch [18/1000], Validation Loss: 0.5184, Validation Accuracy: 80.49%
# Output Summary: Max=25.1218, Min=-28.6254, Median=1.6773, Mean=-0.3328
#
# Epoch [19/1000], Training Loss: 0.4793
# Epoch [19/1000], Validation Loss: 0.5092, Validation Accuracy: 80.84%
# Output Summary: Max=25.2078, Min=-28.5643, Median=1.6216, Mean=-0.3433
#
# Epoch [20/1000], Training Loss: 0.4700
# Epoch [20/1000], Validation Loss: 0.5014, Validation Accuracy: 81.21%
# Output Summary: Max=25.2069, Min=-28.5763, Median=1.5644, Mean=-0.3611
#
# Epoch [21/1000], Training Loss: 0.4611
# Epoch [21/1000], Validation Loss: 0.4928, Validation Accuracy: 81.43%
# Output Summary: Max=25.1421, Min=-28.5313, Median=1.5069, Mean=-0.3788
#
# Epoch [22/1000], Training Loss: 0.4523
# Epoch [22/1000], Validation Loss: 0.4853, Validation Accuracy: 81.83%
# Output Summary: Max=25.1712, Min=-28.5455, Median=1.4549, Mean=-0.3929
#
# Epoch [23/1000], Training Loss: 0.4442
# Epoch [23/1000], Validation Loss: 0.4788, Validation Accuracy: 82.06%
# Output Summary: Max=25.2656, Min=-28.7022, Median=1.4097, Mean=-0.4084
#
# Epoch [24/1000], Training Loss: 0.4379
# Epoch [24/1000], Validation Loss: 0.4711, Validation Accuracy: 82.45%
# Output Summary: Max=25.2108, Min=-28.8062, Median=1.3650, Mean=-0.4132
#
# Epoch [25/1000], Training Loss: 0.4344
# Epoch [25/1000], Validation Loss: 0.4639, Validation Accuracy: 82.67%
# Output Summary: Max=24.3071, Min=-28.8443, Median=1.3251, Mean=-0.3909
#
# Epoch [26/1000], Training Loss: 0.4239
# Epoch [26/1000], Validation Loss: 0.4522, Validation Accuracy: 83.36%
# Output Summary: Max=24.5545, Min=-29.0494, Median=1.2679, Mean=-0.4035
#
# Epoch [27/1000], Training Loss: 0.4164
# Epoch [27/1000], Validation Loss: 0.4488, Validation Accuracy: 83.36%
# Output Summary: Max=24.7098, Min=-29.2613, Median=1.2685, Mean=-0.4118
#
# Epoch [28/1000], Training Loss: 0.4116
# Epoch [28/1000], Validation Loss: 0.4455, Validation Accuracy: 83.45%
# Output Summary: Max=24.7423, Min=-29.2836, Median=1.2454, Mean=-0.4135
#
# Epoch [29/1000], Training Loss: 0.4059
# Epoch [29/1000], Validation Loss: 0.4408, Validation Accuracy: 83.78%
# Output Summary: Max=24.7933, Min=-29.2494, Median=1.2204, Mean=-0.4127
#
# Epoch [30/1000], Training Loss: 0.4007
# Epoch [30/1000], Validation Loss: 0.4367, Validation Accuracy: 83.91%
# Output Summary: Max=24.8428, Min=-29.1869, Median=1.2083, Mean=-0.4089
#
# Epoch [31/1000], Training Loss: 0.3956
# Epoch [31/1000], Validation Loss: 0.4307, Validation Accuracy: 84.05%
# Output Summary: Max=24.8927, Min=-29.1169, Median=1.2142, Mean=-0.4044
#
# Epoch [32/1000], Training Loss: 0.3905
# Epoch [32/1000], Validation Loss: 0.4246, Validation Accuracy: 84.25%
# Output Summary: Max=25.1260, Min=-29.1493, Median=1.2102, Mean=-0.4006
#
# Epoch [33/1000], Training Loss: 0.3855
# Epoch [33/1000], Validation Loss: 0.4194, Validation Accuracy: 84.52%
# Output Summary: Max=25.2895, Min=-29.2720, Median=1.2213, Mean=-0.4030
#
# Epoch [34/1000], Training Loss: 0.3806
# Epoch [34/1000], Validation Loss: 0.4151, Validation Accuracy: 84.67%
# Output Summary: Max=25.3687, Min=-29.2384, Median=1.2105, Mean=-0.4046
#
# Epoch [35/1000], Training Loss: 0.3758
# Epoch [35/1000], Validation Loss: 0.4113, Validation Accuracy: 84.84%
# Output Summary: Max=25.4746, Min=-29.3265, Median=1.2171, Mean=-0.4097
#
# Epoch [36/1000], Training Loss: 0.3714
# Epoch [36/1000], Validation Loss: 0.4082, Validation Accuracy: 84.97%
# Output Summary: Max=25.4779, Min=-29.4168, Median=1.2296, Mean=-0.4105
#
# Epoch [37/1000], Training Loss: 0.3672
# Epoch [37/1000], Validation Loss: 0.4050, Validation Accuracy: 85.20%
# Output Summary: Max=25.5953, Min=-29.5833, Median=1.2222, Mean=-0.4160
#
# Epoch [38/1000], Training Loss: 0.3629
# Epoch [38/1000], Validation Loss: 0.4019, Validation Accuracy: 85.39%
# Output Summary: Max=25.6832, Min=-29.6622, Median=1.2288, Mean=-0.4190
#
# Epoch [39/1000], Training Loss: 0.3591
# Epoch [39/1000], Validation Loss: 0.3986, Validation Accuracy: 85.59%
# Output Summary: Max=25.7762, Min=-29.7192, Median=1.2401, Mean=-0.4225
#
# Epoch [40/1000], Training Loss: 0.3554
# Epoch [40/1000], Validation Loss: 0.3950, Validation Accuracy: 85.71%
# Output Summary: Max=25.9725, Min=-29.6966, Median=1.2579, Mean=-0.4209
#
# Epoch [41/1000], Training Loss: 0.3517
# Epoch [41/1000], Validation Loss: 0.3919, Validation Accuracy: 85.77%
# Output Summary: Max=26.1541, Min=-29.5518, Median=1.2240, Mean=-0.4185
#
# Epoch [42/1000], Training Loss: 0.3483
# Epoch [42/1000], Validation Loss: 0.3893, Validation Accuracy: 85.80%
# Output Summary: Max=26.2564, Min=-29.4096, Median=1.2096, Mean=-0.4197
#
# Epoch [43/1000], Training Loss: 0.3453
# Epoch [43/1000], Validation Loss: 0.3865, Validation Accuracy: 85.88%
# Output Summary: Max=26.4160, Min=-29.2914, Median=1.1911, Mean=-0.4178
#
# Epoch [44/1000], Training Loss: 0.3421
# Epoch [44/1000], Validation Loss: 0.3843, Validation Accuracy: 85.97%
# Output Summary: Max=26.5410, Min=-29.0279, Median=1.1601, Mean=-0.4198
#
# Epoch [45/1000], Training Loss: 0.3390
# Epoch [45/1000], Validation Loss: 0.3827, Validation Accuracy: 86.15%
# Output Summary: Max=26.7659, Min=-28.9285, Median=1.1562, Mean=-0.4231
#
# Epoch [46/1000], Training Loss: 0.3359
# Epoch [46/1000], Validation Loss: 0.3813, Validation Accuracy: 86.18%
# Output Summary: Max=27.0016, Min=-28.6831, Median=1.1182, Mean=-0.4253
#
# Epoch [47/1000], Training Loss: 0.3331
# Epoch [47/1000], Validation Loss: 0.3796, Validation Accuracy: 86.14%
# Output Summary: Max=27.2345, Min=-28.5690, Median=1.1094, Mean=-0.4273
#
# Epoch [48/1000], Training Loss: 0.3304
# Epoch [48/1000], Validation Loss: 0.3781, Validation Accuracy: 86.22%
# Output Summary: Max=27.4258, Min=-28.4205, Median=1.0951, Mean=-0.4306
#
# Epoch [49/1000], Training Loss: 0.3277
# Epoch [49/1000], Validation Loss: 0.3767, Validation Accuracy: 86.37%
# Output Summary: Max=27.6730, Min=-28.3895, Median=1.0723, Mean=-0.4336
#
# Epoch [50/1000], Training Loss: 0.3253
# Epoch [50/1000], Validation Loss: 0.3754, Validation Accuracy: 86.36%
# Output Summary: Max=27.7935, Min=-28.3289, Median=1.0792, Mean=-0.4311
#
# Epoch [51/1000], Training Loss: 0.3230
# Epoch [51/1000], Validation Loss: 0.3742, Validation Accuracy: 86.44%
# Output Summary: Max=27.9542, Min=-28.2104, Median=1.0651, Mean=-0.4328
#
# Epoch [52/1000], Training Loss: 0.3205
# Epoch [52/1000], Validation Loss: 0.3724, Validation Accuracy: 86.63%
# Output Summary: Max=28.1189, Min=-28.1280, Median=1.0584, Mean=-0.4311
#
# Epoch [53/1000], Training Loss: 0.3181
# Epoch [53/1000], Validation Loss: 0.3717, Validation Accuracy: 86.52%
# Output Summary: Max=28.2514, Min=-27.9316, Median=1.0288, Mean=-0.4309
#
# Epoch [54/1000], Training Loss: 0.3161
# Epoch [54/1000], Validation Loss: 0.3706, Validation Accuracy: 86.59%
# Output Summary: Max=28.3132, Min=-27.8955, Median=1.0148, Mean=-0.4307
#
# Epoch [55/1000], Training Loss: 0.3141
# Epoch [55/1000], Validation Loss: 0.3694, Validation Accuracy: 86.61%
# Output Summary: Max=28.3448, Min=-27.7732, Median=0.9894, Mean=-0.4330
#
# Epoch [56/1000], Training Loss: 0.3119
# Epoch [56/1000], Validation Loss: 0.3684, Validation Accuracy: 86.60%
# Output Summary: Max=28.4652, Min=-27.6470, Median=0.9609, Mean=-0.4333
#
# Epoch [57/1000], Training Loss: 0.3096
# Epoch [57/1000], Validation Loss: 0.3667, Validation Accuracy: 86.73%
# Output Summary: Max=28.6068, Min=-27.6449, Median=0.9623, Mean=-0.4389
#
# Epoch [58/1000], Training Loss: 0.3077
# Epoch [58/1000], Validation Loss: 0.3651, Validation Accuracy: 86.76%
# Output Summary: Max=28.7001, Min=-27.5367, Median=0.9511, Mean=-0.4391
#
# Epoch [59/1000], Training Loss: 0.3061
# Epoch [59/1000], Validation Loss: 0.3642, Validation Accuracy: 86.83%
# Output Summary: Max=28.7635, Min=-27.3820, Median=0.9208, Mean=-0.4374
#
# Epoch [60/1000], Training Loss: 0.3045
# Epoch [60/1000], Validation Loss: 0.3625, Validation Accuracy: 86.92%
# Output Summary: Max=28.8779, Min=-27.2627, Median=0.9103, Mean=-0.4368
#
# Epoch [61/1000], Training Loss: 0.3031
# Epoch [61/1000], Validation Loss: 0.3608, Validation Accuracy: 86.95%
# Output Summary: Max=29.1154, Min=-27.3455, Median=0.8821, Mean=-0.4414
#
# Epoch [62/1000], Training Loss: 0.3023
# Epoch [62/1000], Validation Loss: 0.3593, Validation Accuracy: 87.05%
# Output Summary: Max=29.4900, Min=-27.3881, Median=0.8223, Mean=-0.4388
#
# Epoch [63/1000], Training Loss: 0.3030
# Epoch [63/1000], Validation Loss: 0.3580, Validation Accuracy: 87.05%
# Output Summary: Max=29.4629, Min=-27.2447, Median=0.7877, Mean=-0.4207
#
# Epoch [64/1000], Training Loss: 0.3037
# Epoch [64/1000], Validation Loss: 0.3603, Validation Accuracy: 86.95%
# Output Summary: Max=28.8959, Min=-26.9158, Median=0.7127, Mean=-0.4076
#
# Epoch [65/1000], Training Loss: 0.2973
# Epoch [65/1000], Validation Loss: 0.3559, Validation Accuracy: 87.15%
# Output Summary: Max=29.1059, Min=-27.1724, Median=0.7179, Mean=-0.4318
#
# Epoch [66/1000], Training Loss: 0.2944
# Epoch [66/1000], Validation Loss: 0.3559, Validation Accuracy: 87.09%
# Output Summary: Max=29.3842, Min=-27.4132, Median=0.7317, Mean=-0.4272
#
# Epoch [67/1000], Training Loss: 0.2933
# Epoch [67/1000], Validation Loss: 0.3549, Validation Accuracy: 87.14%
# Output Summary: Max=29.7345, Min=-27.6261, Median=0.7238, Mean=-0.4306
#
# Epoch [68/1000], Training Loss: 0.2909
# Epoch [68/1000], Validation Loss: 0.3537, Validation Accuracy: 87.20%
# Output Summary: Max=29.8979, Min=-27.8196, Median=0.7045, Mean=-0.4319
#
# Epoch [69/1000], Training Loss: 0.2892
# Epoch [69/1000], Validation Loss: 0.3531, Validation Accuracy: 87.23%
# Output Summary: Max=30.1982, Min=-28.0369, Median=0.6817, Mean=-0.4379
#
# Epoch [70/1000], Training Loss: 0.2874
# Epoch [70/1000], Validation Loss: 0.3521, Validation Accuracy: 87.24%
# Output Summary: Max=30.5216, Min=-28.1777, Median=0.6562, Mean=-0.4350
#
# Epoch [71/1000], Training Loss: 0.2857
# Epoch [71/1000], Validation Loss: 0.3514, Validation Accuracy: 87.18%
# Output Summary: Max=30.7485, Min=-28.3411, Median=0.6513, Mean=-0.4383
#
# Epoch [72/1000], Training Loss: 0.2840
# Epoch [72/1000], Validation Loss: 0.3507, Validation Accuracy: 87.25%
# Output Summary: Max=30.8393, Min=-28.5488, Median=0.6313, Mean=-0.4431
#
# Epoch [73/1000], Training Loss: 0.2823
# Epoch [73/1000], Validation Loss: 0.3499, Validation Accuracy: 87.34%
# Output Summary: Max=30.9446, Min=-28.7551, Median=0.6099, Mean=-0.4454
#
# Epoch [74/1000], Training Loss: 0.2807
# Epoch [74/1000], Validation Loss: 0.3488, Validation Accuracy: 87.36%
# Output Summary: Max=31.1910, Min=-28.9244, Median=0.6063, Mean=-0.4490
#
# Epoch [75/1000], Training Loss: 0.2789
# Epoch [75/1000], Validation Loss: 0.3485, Validation Accuracy: 87.43%
# Output Summary: Max=31.4333, Min=-29.0065, Median=0.5999, Mean=-0.4540
#
# Epoch [76/1000], Training Loss: 0.2776
# Epoch [76/1000], Validation Loss: 0.3476, Validation Accuracy: 87.49%
# Output Summary: Max=31.6711, Min=-29.1717, Median=0.5688, Mean=-0.4564
#
# Epoch [77/1000], Training Loss: 0.2758
# Epoch [77/1000], Validation Loss: 0.3470, Validation Accuracy: 87.50%
# Output Summary: Max=31.6791, Min=-29.5254, Median=0.5453, Mean=-0.4623
#
# Epoch [78/1000], Training Loss: 0.2743
# Epoch [78/1000], Validation Loss: 0.3463, Validation Accuracy: 87.58%
# Output Summary: Max=31.9740, Min=-29.6979, Median=0.5238, Mean=-0.4628
#
# Epoch [79/1000], Training Loss: 0.2727
# Epoch [79/1000], Validation Loss: 0.3463, Validation Accuracy: 87.62%
# Output Summary: Max=32.0990, Min=-29.9109, Median=0.5019, Mean=-0.4658
#
# Epoch [80/1000], Training Loss: 0.2712
# Epoch [80/1000], Validation Loss: 0.3457, Validation Accuracy: 87.63%
# Output Summary: Max=32.2525, Min=-30.1063, Median=0.4730, Mean=-0.4700
#
# Epoch [81/1000], Training Loss: 0.2699
# Epoch [81/1000], Validation Loss: 0.3453, Validation Accuracy: 87.62%
# Output Summary: Max=32.4756, Min=-30.3473, Median=0.4447, Mean=-0.4700
#
# Epoch [82/1000], Training Loss: 0.2683
# Epoch [82/1000], Validation Loss: 0.3450, Validation Accuracy: 87.63%
# Output Summary: Max=32.5908, Min=-30.4666, Median=0.4195, Mean=-0.4718
#
# Epoch [83/1000], Training Loss: 0.2669
# Epoch [83/1000], Validation Loss: 0.3449, Validation Accuracy: 87.69%
# Output Summary: Max=32.6469, Min=-30.5800, Median=0.4019, Mean=-0.4736
#
# Epoch [84/1000], Training Loss: 0.2655
# Epoch [84/1000], Validation Loss: 0.3450, Validation Accuracy: 87.73%
# Output Summary: Max=32.8387, Min=-30.6922, Median=0.3808, Mean=-0.4721
#
# Epoch [85/1000], Training Loss: 0.2643
# Epoch [85/1000], Validation Loss: 0.3447, Validation Accuracy: 87.76%
# Output Summary: Max=33.0030, Min=-30.8887, Median=0.3703, Mean=-0.4695
#
# Epoch [86/1000], Training Loss: 0.2629
# Epoch [86/1000], Validation Loss: 0.3447, Validation Accuracy: 87.81%
# Output Summary: Max=33.1335, Min=-31.1370, Median=0.3595, Mean=-0.4751
#
# Epoch [87/1000], Training Loss: 0.2616
# Epoch [87/1000], Validation Loss: 0.3448, Validation Accuracy: 87.83%
# Output Summary: Max=33.4051, Min=-31.3283, Median=0.3341, Mean=-0.4780
#
# Epoch [88/1000], Training Loss: 0.2603
# Epoch [88/1000], Validation Loss: 0.3440, Validation Accuracy: 87.86%
# Output Summary: Max=33.4644, Min=-31.4969, Median=0.3294, Mean=-0.4808
#
# Epoch [89/1000], Training Loss: 0.2589
# Epoch [89/1000], Validation Loss: 0.3435, Validation Accuracy: 87.90%
# Output Summary: Max=33.5918, Min=-31.4294, Median=0.2952, Mean=-0.4787
#
# Epoch [90/1000], Training Loss: 0.2574
# Epoch [90/1000], Validation Loss: 0.3429, Validation Accuracy: 87.99%
# Output Summary: Max=33.7380, Min=-31.5051, Median=0.2553, Mean=-0.4794
#
# Epoch [91/1000], Training Loss: 0.2562
# Epoch [91/1000], Validation Loss: 0.3431, Validation Accuracy: 87.93%
# Output Summary: Max=33.9503, Min=-31.5452, Median=0.2283, Mean=-0.4860
#
# Epoch [92/1000], Training Loss: 0.2549
# Epoch [92/1000], Validation Loss: 0.3427, Validation Accuracy: 87.91%
# Output Summary: Max=34.1688, Min=-31.5006, Median=0.2050, Mean=-0.4879
#
# Epoch [93/1000], Training Loss: 0.2535
# Epoch [93/1000], Validation Loss: 0.3424, Validation Accuracy: 87.93%
# Output Summary: Max=34.3657, Min=-31.6765, Median=0.1786, Mean=-0.4938
#
# Epoch [94/1000], Training Loss: 0.2522
# Epoch [94/1000], Validation Loss: 0.3426, Validation Accuracy: 87.96%
# Output Summary: Max=34.4247, Min=-31.6927, Median=0.1602, Mean=-0.4923
#
# Epoch [95/1000], Training Loss: 0.2510
# Epoch [95/1000], Validation Loss: 0.3424, Validation Accuracy: 87.94%
# Output Summary: Max=34.5888, Min=-31.7992, Median=0.1296, Mean=-0.4945
#
# Epoch [96/1000], Training Loss: 0.2494
# Epoch [96/1000], Validation Loss: 0.3421, Validation Accuracy: 88.00%
# Output Summary: Max=34.8702, Min=-32.0230, Median=0.1149, Mean=-0.4982
#
# Epoch [97/1000], Training Loss: 0.2484
# Epoch [97/1000], Validation Loss: 0.3425, Validation Accuracy: 87.98%
# Output Summary: Max=35.2085, Min=-32.1813, Median=0.0928, Mean=-0.5021
#
# Epoch [98/1000], Training Loss: 0.2469
# Epoch [98/1000], Validation Loss: 0.3429, Validation Accuracy: 87.98%
# Output Summary: Max=35.4020, Min=-32.3287, Median=0.0782, Mean=-0.5056
#
# Epoch [99/1000], Training Loss: 0.2459
# Epoch [99/1000], Validation Loss: 0.3428, Validation Accuracy: 87.94%
# Output Summary: Max=35.5965, Min=-32.4455, Median=0.0491, Mean=-0.5088
#
# Epoch [100/1000], Training Loss: 0.2446
# Epoch [100/1000], Validation Loss: 0.3425, Validation Accuracy: 88.02%
# Output Summary: Max=36.0079, Min=-32.4278, Median=0.0091, Mean=-0.5046
#
# Epoch [101/1000], Training Loss: 0.2434
# Epoch [101/1000], Validation Loss: 0.3425, Validation Accuracy: 88.04%
# Output Summary: Max=36.2460, Min=-32.5019, Median=0.0086, Mean=-0.5056
#
# Epoch [102/1000], Training Loss: 0.2422
# Epoch [102/1000], Validation Loss: 0.3420, Validation Accuracy: 88.09%
# Output Summary: Max=36.4486, Min=-32.3959, Median=-0.0396, Mean=-0.5093
#
# Epoch [103/1000], Training Loss: 0.2409
# Epoch [103/1000], Validation Loss: 0.3424, Validation Accuracy: 88.07%
# Output Summary: Max=36.5690, Min=-32.4669, Median=-0.0593, Mean=-0.5112
#
# Epoch [104/1000], Training Loss: 0.2398
# Epoch [104/1000], Validation Loss: 0.3432, Validation Accuracy: 88.15%
# Output Summary: Max=37.0015, Min=-32.7302, Median=-0.0959, Mean=-0.5117
#
# Epoch [105/1000], Training Loss: 0.2386
# Epoch [105/1000], Validation Loss: 0.3429, Validation Accuracy: 88.08%
# Output Summary: Max=37.3085, Min=-32.9473, Median=-0.1136, Mean=-0.5188
#
# Epoch [106/1000], Training Loss: 0.2374
# Epoch [106/1000], Validation Loss: 0.3429, Validation Accuracy: 88.05%
# Output Summary: Max=37.6856, Min=-33.1069, Median=-0.1549, Mean=-0.5205
#
# Epoch [107/1000], Training Loss: 0.2361
# Epoch [107/1000], Validation Loss: 0.3432, Validation Accuracy: 88.09%
# Output Summary: Max=37.9892, Min=-33.1854, Median=-0.1811, Mean=-0.5234
#
# Epoch [108/1000], Training Loss: 0.2348
# Epoch [108/1000], Validation Loss: 0.3431, Validation Accuracy: 88.10%
# Output Summary: Max=38.2328, Min=-33.1901, Median=-0.2321, Mean=-0.5257
#
# Epoch [109/1000], Training Loss: 0.2338
# Epoch [109/1000], Validation Loss: 0.3435, Validation Accuracy: 88.08%
# Output Summary: Max=38.5835, Min=-33.2593, Median=-0.2449, Mean=-0.5285
#
# Epoch [110/1000], Training Loss: 0.2323
# Epoch [110/1000], Validation Loss: 0.3433, Validation Accuracy: 88.19%
# Output Summary: Max=39.0000, Min=-33.4123, Median=-0.2665, Mean=-0.5337
#
# Epoch [111/1000], Training Loss: 0.2312
# Epoch [111/1000], Validation Loss: 0.3436, Validation Accuracy: 88.17%
# Output Summary: Max=39.1073, Min=-33.3636, Median=-0.3082, Mean=-0.5391
#
# Epoch [112/1000], Training Loss: 0.2301
# Epoch [112/1000], Validation Loss: 0.3435, Validation Accuracy: 88.18%
# Output Summary: Max=39.3249, Min=-33.3424, Median=-0.3165, Mean=-0.5395
#
# Epoch [113/1000], Training Loss: 0.2287
# Epoch [113/1000], Validation Loss: 0.3442, Validation Accuracy: 88.15%
# Output Summary: Max=39.5106, Min=-33.4937, Median=-0.3531, Mean=-0.5454
#
# Epoch [114/1000], Training Loss: 0.2279
# Epoch [114/1000], Validation Loss: 0.3437, Validation Accuracy: 88.08%
# Output Summary: Max=39.5842, Min=-33.5248, Median=-0.3637, Mean=-0.5484
#
# Epoch [115/1000], Training Loss: 0.2267
# Epoch [115/1000], Validation Loss: 0.3440, Validation Accuracy: 88.16%
# Output Summary: Max=39.8674, Min=-33.5289, Median=-0.4090, Mean=-0.5509
#
# Epoch [116/1000], Training Loss: 0.2254
# Epoch [116/1000], Validation Loss: 0.3445, Validation Accuracy: 88.17%
# Output Summary: Max=40.1218, Min=-33.6385, Median=-0.4149, Mean=-0.5558
#
# Epoch [117/1000], Training Loss: 0.2246
# Epoch [117/1000], Validation Loss: 0.3446, Validation Accuracy: 88.27%
# Output Summary: Max=40.4607, Min=-33.6590, Median=-0.4283, Mean=-0.5579
#
# Epoch [118/1000], Training Loss: 0.2234
# Epoch [118/1000], Validation Loss: 0.3444, Validation Accuracy: 88.32%
# Output Summary: Max=40.7111, Min=-33.7711, Median=-0.4472, Mean=-0.5580
#
# Epoch [119/1000], Training Loss: 0.2223
# Epoch [119/1000], Validation Loss: 0.3446, Validation Accuracy: 88.40%
# Output Summary: Max=41.0440, Min=-33.8606, Median=-0.4507, Mean=-0.5674
#
# Epoch [120/1000], Training Loss: 0.2212
# Epoch [120/1000], Validation Loss: 0.3443, Validation Accuracy: 88.43%
# Output Summary: Max=41.4287, Min=-33.9895, Median=-0.4629, Mean=-0.5679
#
# Epoch [121/1000], Training Loss: 0.2201
# Epoch [121/1000], Validation Loss: 0.3451, Validation Accuracy: 88.43%
# Output Summary: Max=41.9413, Min=-34.1071, Median=-0.4799, Mean=-0.5762
#
# Epoch [122/1000], Training Loss: 0.2190
# Epoch [122/1000], Validation Loss: 0.3449, Validation Accuracy: 88.44%
# Output Summary: Max=42.2230, Min=-34.2780, Median=-0.4969, Mean=-0.5766
#
# Early stopping triggered after 122 epochs.

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 2.2538
# Epoch [1/1000], Validation Loss: 2.0663, Validation Accuracy: 29.65%
# Output Summary: Max=1.5856, Min=-1.4284, Median=0.0883, Mean=0.1063
#
# Epoch [2/1000], Training Loss: 1.5564
# Epoch [2/1000], Validation Loss: 1.0894, Validation Accuracy: 58.70%
# Output Summary: Max=16.0737, Min=-8.0528, Median=3.4470, Mean=3.3465
#
# Epoch [3/1000], Training Loss: 0.9512
# Epoch [3/1000], Validation Loss: 0.8822, Validation Accuracy: 66.97%
# Output Summary: Max=20.5775, Min=-11.3086, Median=5.0378, Mean=4.6663
#
# Epoch [4/1000], Training Loss: 0.8276
# Epoch [4/1000], Validation Loss: 0.7972, Validation Accuracy: 69.94%
# Output Summary: Max=22.5915, Min=-12.6064, Median=5.7124, Mean=5.2277
#
# Epoch [5/1000], Training Loss: 0.7596
# Epoch [5/1000], Validation Loss: 0.7475, Validation Accuracy: 71.02%
# Output Summary: Max=23.6714, Min=-14.5858, Median=6.1398, Mean=5.5061
#
# Epoch [6/1000], Training Loss: 0.7138
# Epoch [6/1000], Validation Loss: 0.7141, Validation Accuracy: 72.58%
# Output Summary: Max=24.4144, Min=-17.2047, Median=6.3949, Mean=5.5938
#
# Epoch [7/1000], Training Loss: 0.6830
# Epoch [7/1000], Validation Loss: 0.6881, Validation Accuracy: 73.58%
# Output Summary: Max=24.8987, Min=-19.1797, Median=6.4994, Mean=5.6080
#
# Epoch [8/1000], Training Loss: 0.6585
# Epoch [8/1000], Validation Loss: 0.6668, Validation Accuracy: 74.59%
# Output Summary: Max=25.3260, Min=-20.9300, Median=6.5629, Mean=5.5967
#
# Epoch [9/1000], Training Loss: 0.6379
# Epoch [9/1000], Validation Loss: 0.6486, Validation Accuracy: 75.35%
# Output Summary: Max=25.3249, Min=-22.4921, Median=6.6235, Mean=5.5817
#
# Epoch [10/1000], Training Loss: 0.6201
# Epoch [10/1000], Validation Loss: 0.6333, Validation Accuracy: 76.01%
# Output Summary: Max=25.4051, Min=-23.7286, Median=6.6496, Mean=5.5666
#
# Epoch [11/1000], Training Loss: 0.6039
# Epoch [11/1000], Validation Loss: 0.6201, Validation Accuracy: 76.65%
# Output Summary: Max=25.5545, Min=-24.7840, Median=6.6725, Mean=5.5536
#
# Epoch [12/1000], Training Loss: 0.5886
# Epoch [12/1000], Validation Loss: 0.6050, Validation Accuracy: 77.61%
# Output Summary: Max=25.6313, Min=-25.8608, Median=6.6508, Mean=5.4971
#
# Epoch [13/1000], Training Loss: 0.5743
# Epoch [13/1000], Validation Loss: 0.5904, Validation Accuracy: 78.26%
# Output Summary: Max=25.8058, Min=-26.8619, Median=6.6961, Mean=5.5007
#
# Epoch [14/1000], Training Loss: 0.5613
# Epoch [14/1000], Validation Loss: 0.5788, Validation Accuracy: 78.79%
# Output Summary: Max=26.0597, Min=-27.8262, Median=6.7669, Mean=5.5230
#
# Epoch [15/1000], Training Loss: 0.5499
# Epoch [15/1000], Validation Loss: 0.5659, Validation Accuracy: 79.37%
# Output Summary: Max=26.3602, Min=-28.7079, Median=6.8322, Mean=5.5294
#
# Epoch [16/1000], Training Loss: 0.5391
# Epoch [16/1000], Validation Loss: 0.5540, Validation Accuracy: 79.84%
# Output Summary: Max=26.7851, Min=-29.1960, Median=6.8750, Mean=5.5391
#
# Epoch [17/1000], Training Loss: 0.5278
# Epoch [17/1000], Validation Loss: 0.5450, Validation Accuracy: 80.16%
# Output Summary: Max=27.0677, Min=-29.7711, Median=6.9609, Mean=5.5783
#
# Epoch [18/1000], Training Loss: 0.5187
# Epoch [18/1000], Validation Loss: 0.5366, Validation Accuracy: 80.43%
# Output Summary: Max=27.1307, Min=-30.3224, Median=7.0274, Mean=5.5963
#
# Epoch [19/1000], Training Loss: 0.5110
# Epoch [19/1000], Validation Loss: 0.5288, Validation Accuracy: 80.57%
# Output Summary: Max=27.2109, Min=-30.8634, Median=7.0844, Mean=5.6107
#
# Epoch [20/1000], Training Loss: 0.5038
# Epoch [20/1000], Validation Loss: 0.5223, Validation Accuracy: 80.71%
# Output Summary: Max=27.2534, Min=-31.1036, Median=7.1145, Mean=5.6097
#
# Epoch [21/1000], Training Loss: 0.4973
# Epoch [21/1000], Validation Loss: 0.5166, Validation Accuracy: 80.95%
# Output Summary: Max=27.1914, Min=-31.3088, Median=7.1226, Mean=5.5870
#
# Epoch [22/1000], Training Loss: 0.4915
# Epoch [22/1000], Validation Loss: 0.5116, Validation Accuracy: 81.17%
# Output Summary: Max=27.2068, Min=-31.4524, Median=7.1265, Mean=5.5694
#
# Epoch [23/1000], Training Loss: 0.4859
# Epoch [23/1000], Validation Loss: 0.5071, Validation Accuracy: 81.42%
# Output Summary: Max=27.1791, Min=-31.5072, Median=7.1052, Mean=5.5363
#
# Epoch [24/1000], Training Loss: 0.4805
# Epoch [24/1000], Validation Loss: 0.5025, Validation Accuracy: 81.46%
# Output Summary: Max=27.2531, Min=-31.5182, Median=7.0870, Mean=5.5136
#
# Epoch [25/1000], Training Loss: 0.4753
# Epoch [25/1000], Validation Loss: 0.4973, Validation Accuracy: 81.71%
# Output Summary: Max=27.3573, Min=-31.6041, Median=7.1125, Mean=5.5155
#
# Epoch [26/1000], Training Loss: 0.4707
# Epoch [26/1000], Validation Loss: 0.4929, Validation Accuracy: 81.79%
# Output Summary: Max=27.5015, Min=-31.5757, Median=7.1316, Mean=5.5171
#
# Epoch [27/1000], Training Loss: 0.4664
# Epoch [27/1000], Validation Loss: 0.4885, Validation Accuracy: 82.03%
# Output Summary: Max=27.5955, Min=-31.5313, Median=7.1492, Mean=5.5245
#
# Epoch [28/1000], Training Loss: 0.4625
# Epoch [28/1000], Validation Loss: 0.4847, Validation Accuracy: 82.32%
# Output Summary: Max=27.6414, Min=-31.4101, Median=7.1322, Mean=5.5101
#
# Epoch [29/1000], Training Loss: 0.4587
# Epoch [29/1000], Validation Loss: 0.4811, Validation Accuracy: 82.46%
# Output Summary: Max=27.6609, Min=-31.2690, Median=7.1137, Mean=5.4956
#
# Epoch [30/1000], Training Loss: 0.4551
# Epoch [30/1000], Validation Loss: 0.4777, Validation Accuracy: 82.65%
# Output Summary: Max=27.6352, Min=-31.1861, Median=7.0978, Mean=5.4696
#
# Epoch [31/1000], Training Loss: 0.4518
# Epoch [31/1000], Validation Loss: 0.4745, Validation Accuracy: 82.94%
# Output Summary: Max=27.6163, Min=-31.0952, Median=7.0824, Mean=5.4422
#
# Epoch [32/1000], Training Loss: 0.4484
# Epoch [32/1000], Validation Loss: 0.4713, Validation Accuracy: 82.98%
# Output Summary: Max=27.6137, Min=-30.9598, Median=7.0614, Mean=5.4220
#
# Epoch [33/1000], Training Loss: 0.4453
# Epoch [33/1000], Validation Loss: 0.4684, Validation Accuracy: 83.07%
# Output Summary: Max=27.6570, Min=-30.9086, Median=7.0562, Mean=5.4073
#
# Epoch [34/1000], Training Loss: 0.4423
# Epoch [34/1000], Validation Loss: 0.4658, Validation Accuracy: 83.21%
# Output Summary: Max=27.7053, Min=-30.7773, Median=7.0476, Mean=5.3968
#
# Epoch [35/1000], Training Loss: 0.4395
# Epoch [35/1000], Validation Loss: 0.4629, Validation Accuracy: 83.36%
# Output Summary: Max=27.7610, Min=-30.8049, Median=7.0537, Mean=5.3889
#
# Epoch [36/1000], Training Loss: 0.4368
# Epoch [36/1000], Validation Loss: 0.4606, Validation Accuracy: 83.40%
# Output Summary: Max=27.8410, Min=-30.8387, Median=7.0669, Mean=5.3881
#
# Epoch [37/1000], Training Loss: 0.4342
# Epoch [37/1000], Validation Loss: 0.4580, Validation Accuracy: 83.53%
# Output Summary: Max=27.8360, Min=-30.7856, Median=7.0591, Mean=5.3709
#
# Epoch [38/1000], Training Loss: 0.4316
# Epoch [38/1000], Validation Loss: 0.4556, Validation Accuracy: 83.73%
# Output Summary: Max=27.8404, Min=-30.6995, Median=7.0316, Mean=5.3478
#
# Epoch [39/1000], Training Loss: 0.4292
# Epoch [39/1000], Validation Loss: 0.4531, Validation Accuracy: 83.72%
# Output Summary: Max=27.8072, Min=-30.6813, Median=7.0293, Mean=5.3255
#
# Epoch [40/1000], Training Loss: 0.4268
# Epoch [40/1000], Validation Loss: 0.4509, Validation Accuracy: 83.78%
# Output Summary: Max=27.7982, Min=-30.6091, Median=7.0223, Mean=5.3073
#
# Epoch [41/1000], Training Loss: 0.4245
# Epoch [41/1000], Validation Loss: 0.4489, Validation Accuracy: 83.91%
# Output Summary: Max=27.7256, Min=-30.5071, Median=6.9970, Mean=5.2761
#
# Epoch [42/1000], Training Loss: 0.4225
# Epoch [42/1000], Validation Loss: 0.4471, Validation Accuracy: 83.92%
# Output Summary: Max=27.6416, Min=-30.3339, Median=6.9585, Mean=5.2374
#
# Epoch [43/1000], Training Loss: 0.4206
# Epoch [43/1000], Validation Loss: 0.4455, Validation Accuracy: 83.98%
# Output Summary: Max=27.4861, Min=-30.1781, Median=6.9157, Mean=5.1895
#
# Epoch [44/1000], Training Loss: 0.4190
# Epoch [44/1000], Validation Loss: 0.4448, Validation Accuracy: 84.11%
# Output Summary: Max=27.2087, Min=-30.0547, Median=6.8571, Mean=5.1147
#
# Epoch [45/1000], Training Loss: 0.4178
# Epoch [45/1000], Validation Loss: 0.4446, Validation Accuracy: 84.18%
# Output Summary: Max=26.8996, Min=-29.8228, Median=6.7809, Mean=5.0373
#
# Epoch [46/1000], Training Loss: 0.4171
# Epoch [46/1000], Validation Loss: 0.4436, Validation Accuracy: 84.02%
# Output Summary: Max=26.6096, Min=-29.6923, Median=6.7097, Mean=4.9533
#
# Epoch [47/1000], Training Loss: 0.4161
# Epoch [47/1000], Validation Loss: 0.4428, Validation Accuracy: 84.09%
# Output Summary: Max=26.3247, Min=-29.5793, Median=6.6403, Mean=4.8631
#
# Epoch [48/1000], Training Loss: 0.4140
# Epoch [48/1000], Validation Loss: 0.4439, Validation Accuracy: 84.10%
# Output Summary: Max=26.2668, Min=-29.6093, Median=6.5963, Mean=4.7993
#
# Epoch [49/1000], Training Loss: 0.4106
# Epoch [49/1000], Validation Loss: 0.4408, Validation Accuracy: 84.23%
# Output Summary: Max=26.3615, Min=-29.6386, Median=6.5926, Mean=4.7830
#
# Epoch [50/1000], Training Loss: 0.4072
# Epoch [50/1000], Validation Loss: 0.4367, Validation Accuracy: 84.36%
# Output Summary: Max=26.5643, Min=-29.7056, Median=6.6175, Mean=4.7928
#
# Epoch [51/1000], Training Loss: 0.4046
# Epoch [51/1000], Validation Loss: 0.4345, Validation Accuracy: 84.48%
# Output Summary: Max=26.6454, Min=-29.5498, Median=6.6123, Mean=4.7813
#
# Epoch [52/1000], Training Loss: 0.4026
# Epoch [52/1000], Validation Loss: 0.4329, Validation Accuracy: 84.40%
# Output Summary: Max=26.6530, Min=-29.3846, Median=6.5917, Mean=4.7535
#
# Epoch [53/1000], Training Loss: 0.4007
# Epoch [53/1000], Validation Loss: 0.4310, Validation Accuracy: 84.46%
# Output Summary: Max=26.7445, Min=-29.3014, Median=6.6049, Mean=4.7449
#
# Epoch [54/1000], Training Loss: 0.3988
# Epoch [54/1000], Validation Loss: 0.4290, Validation Accuracy: 84.57%
# Output Summary: Max=26.8138, Min=-29.1850, Median=6.5993, Mean=4.7264
#
# Epoch [55/1000], Training Loss: 0.3969
# Epoch [55/1000], Validation Loss: 0.4273, Validation Accuracy: 84.73%
# Output Summary: Max=26.7934, Min=-29.0325, Median=6.5841, Mean=4.6991
#
# Epoch [56/1000], Training Loss: 0.3951
# Epoch [56/1000], Validation Loss: 0.4258, Validation Accuracy: 84.76%
# Output Summary: Max=26.7395, Min=-28.8168, Median=6.5536, Mean=4.6665
#
# Epoch [57/1000], Training Loss: 0.3935
# Epoch [57/1000], Validation Loss: 0.4246, Validation Accuracy: 84.77%
# Output Summary: Max=26.7263, Min=-28.7338, Median=6.5365, Mean=4.6486
#
# Epoch [58/1000], Training Loss: 0.3918
# Epoch [58/1000], Validation Loss: 0.4236, Validation Accuracy: 84.80%
# Output Summary: Max=26.7357, Min=-28.7627, Median=6.5302, Mean=4.6305
#
# Epoch [59/1000], Training Loss: 0.3902
# Epoch [59/1000], Validation Loss: 0.4232, Validation Accuracy: 84.77%
# Output Summary: Max=26.7533, Min=-28.6802, Median=6.5149, Mean=4.6197
#
# Epoch [60/1000], Training Loss: 0.3884
# Epoch [60/1000], Validation Loss: 0.4221, Validation Accuracy: 84.77%
# Output Summary: Max=26.7633, Min=-28.7286, Median=6.5029, Mean=4.6058
#
# Epoch [61/1000], Training Loss: 0.3867
# Epoch [61/1000], Validation Loss: 0.4210, Validation Accuracy: 84.78%
# Output Summary: Max=26.9048, Min=-28.8561, Median=6.5090, Mean=4.6065
#
# Epoch [62/1000], Training Loss: 0.3848
# Epoch [62/1000], Validation Loss: 0.4197, Validation Accuracy: 84.84%
# Output Summary: Max=27.0153, Min=-28.9655, Median=6.5142, Mean=4.5998
#
# Epoch [63/1000], Training Loss: 0.3831
# Epoch [63/1000], Validation Loss: 0.4184, Validation Accuracy: 84.88%
# Output Summary: Max=27.1140, Min=-29.0159, Median=6.4966, Mean=4.5814
#
# Epoch [64/1000], Training Loss: 0.3815
# Epoch [64/1000], Validation Loss: 0.4168, Validation Accuracy: 85.00%
# Output Summary: Max=27.2037, Min=-29.0586, Median=6.4953, Mean=4.5763
#
# Epoch [65/1000], Training Loss: 0.3800
# Epoch [65/1000], Validation Loss: 0.4153, Validation Accuracy: 85.02%
# Output Summary: Max=27.3143, Min=-29.0797, Median=6.4947, Mean=4.5659
#
# Epoch [66/1000], Training Loss: 0.3784
# Epoch [66/1000], Validation Loss: 0.4136, Validation Accuracy: 85.07%
# Output Summary: Max=27.3832, Min=-29.0229, Median=6.4805, Mean=4.5502
#
# Epoch [67/1000], Training Loss: 0.3769
# Epoch [67/1000], Validation Loss: 0.4121, Validation Accuracy: 85.17%
# Output Summary: Max=27.4797, Min=-28.9958, Median=6.4734, Mean=4.5374
#
# Epoch [68/1000], Training Loss: 0.3756
# Epoch [68/1000], Validation Loss: 0.4111, Validation Accuracy: 85.18%
# Output Summary: Max=27.5942, Min=-29.0052, Median=6.4769, Mean=4.5291
#
# Epoch [69/1000], Training Loss: 0.3742
# Epoch [69/1000], Validation Loss: 0.4097, Validation Accuracy: 85.19%
# Output Summary: Max=27.6843, Min=-29.0294, Median=6.4733, Mean=4.5176
#
# Epoch [70/1000], Training Loss: 0.3729
# Epoch [70/1000], Validation Loss: 0.4084, Validation Accuracy: 85.23%
# Output Summary: Max=27.6840, Min=-29.0503, Median=6.4654, Mean=4.4962
#
# Epoch [71/1000], Training Loss: 0.3716
# Epoch [71/1000], Validation Loss: 0.4070, Validation Accuracy: 85.28%
# Output Summary: Max=27.7883, Min=-29.0720, Median=6.4601, Mean=4.4844
#
# Epoch [72/1000], Training Loss: 0.3702
# Epoch [72/1000], Validation Loss: 0.4055, Validation Accuracy: 85.32%
# Output Summary: Max=27.8579, Min=-29.0850, Median=6.4476, Mean=4.4691
#
# Epoch [73/1000], Training Loss: 0.3689
# Epoch [73/1000], Validation Loss: 0.4043, Validation Accuracy: 85.35%
# Output Summary: Max=27.9494, Min=-29.0404, Median=6.4362, Mean=4.4556
#
# Epoch [74/1000], Training Loss: 0.3676
# Epoch [74/1000], Validation Loss: 0.4029, Validation Accuracy: 85.42%
# Output Summary: Max=28.0294, Min=-28.9975, Median=6.4200, Mean=4.4397
#
# Epoch [75/1000], Training Loss: 0.3663
# Epoch [75/1000], Validation Loss: 0.4017, Validation Accuracy: 85.48%
# Output Summary: Max=28.0828, Min=-28.9630, Median=6.4112, Mean=4.4297
#
# Epoch [76/1000], Training Loss: 0.3650
# Epoch [76/1000], Validation Loss: 0.4004, Validation Accuracy: 85.51%
# Output Summary: Max=28.0578, Min=-28.8659, Median=6.3753, Mean=4.4031
#
# Epoch [77/1000], Training Loss: 0.3638
# Epoch [77/1000], Validation Loss: 0.3991, Validation Accuracy: 85.49%
# Output Summary: Max=28.1052, Min=-28.8606, Median=6.3569, Mean=4.3807
#
# Epoch [78/1000], Training Loss: 0.3625
# Epoch [78/1000], Validation Loss: 0.3980, Validation Accuracy: 85.52%
# Output Summary: Max=28.1233, Min=-28.7888, Median=6.3235, Mean=4.3513
#
# Epoch [79/1000], Training Loss: 0.3613
# Epoch [79/1000], Validation Loss: 0.3969, Validation Accuracy: 85.55%
# Output Summary: Max=28.1578, Min=-28.8131, Median=6.3211, Mean=4.3421
#
# Epoch [80/1000], Training Loss: 0.3601
# Epoch [80/1000], Validation Loss: 0.3956, Validation Accuracy: 85.56%
# Output Summary: Max=28.1666, Min=-28.7640, Median=6.2969, Mean=4.3207
#
# Epoch [81/1000], Training Loss: 0.3589
# Epoch [81/1000], Validation Loss: 0.3947, Validation Accuracy: 85.61%
# Output Summary: Max=28.2136, Min=-28.6990, Median=6.2807, Mean=4.3075
#
# Epoch [82/1000], Training Loss: 0.3578
# Epoch [82/1000], Validation Loss: 0.3936, Validation Accuracy: 85.62%
# Output Summary: Max=28.2171, Min=-28.6214, Median=6.2519, Mean=4.2836
#
# Epoch [83/1000], Training Loss: 0.3567
# Epoch [83/1000], Validation Loss: 0.3926, Validation Accuracy: 85.65%
# Output Summary: Max=28.2965, Min=-28.5818, Median=6.2429, Mean=4.2738
#
# Epoch [84/1000], Training Loss: 0.3556
# Epoch [84/1000], Validation Loss: 0.3918, Validation Accuracy: 85.73%
# Output Summary: Max=28.2894, Min=-28.5408, Median=6.2190, Mean=4.2550
#
# Epoch [85/1000], Training Loss: 0.3547
# Epoch [85/1000], Validation Loss: 0.3909, Validation Accuracy: 85.74%
# Output Summary: Max=28.3276, Min=-28.4798, Median=6.1949, Mean=4.2385
#
# Epoch [86/1000], Training Loss: 0.3535
# Epoch [86/1000], Validation Loss: 0.3898, Validation Accuracy: 85.77%
# Output Summary: Max=28.3237, Min=-28.3579, Median=6.1596, Mean=4.2127
#
# Epoch [87/1000], Training Loss: 0.3525
# Epoch [87/1000], Validation Loss: 0.3887, Validation Accuracy: 85.82%
# Output Summary: Max=28.3295, Min=-28.2962, Median=6.1531, Mean=4.2009
#
# Epoch [88/1000], Training Loss: 0.3514
# Epoch [88/1000], Validation Loss: 0.3874, Validation Accuracy: 85.88%
# Output Summary: Max=28.3818, Min=-28.2195, Median=6.1278, Mean=4.1823
#
# Epoch [89/1000], Training Loss: 0.3504
# Epoch [89/1000], Validation Loss: 0.3862, Validation Accuracy: 85.91%
# Output Summary: Max=28.4074, Min=-28.2187, Median=6.1089, Mean=4.1622
#
# Epoch [90/1000], Training Loss: 0.3494
# Epoch [90/1000], Validation Loss: 0.3857, Validation Accuracy: 85.90%
# Output Summary: Max=28.3358, Min=-28.1307, Median=6.0733, Mean=4.1362
#
# Epoch [91/1000], Training Loss: 0.3485
# Epoch [91/1000], Validation Loss: 0.3845, Validation Accuracy: 85.96%
# Output Summary: Max=28.3341, Min=-28.0685, Median=6.0603, Mean=4.1150
#
# Epoch [92/1000], Training Loss: 0.3474
# Epoch [92/1000], Validation Loss: 0.3836, Validation Accuracy: 85.93%
# Output Summary: Max=28.3350, Min=-28.0370, Median=6.0354, Mean=4.0916
#
# Epoch [93/1000], Training Loss: 0.3464
# Epoch [93/1000], Validation Loss: 0.3825, Validation Accuracy: 86.01%
# Output Summary: Max=28.4395, Min=-28.0325, Median=6.0353, Mean=4.0857
#
# Epoch [94/1000], Training Loss: 0.3454
# Epoch [94/1000], Validation Loss: 0.3819, Validation Accuracy: 86.11%
# Output Summary: Max=28.4969, Min=-27.9978, Median=6.0155, Mean=4.0683
#
# Epoch [95/1000], Training Loss: 0.3445
# Epoch [95/1000], Validation Loss: 0.3809, Validation Accuracy: 86.13%
# Output Summary: Max=28.5152, Min=-27.9140, Median=5.9905, Mean=4.0483
#
# Epoch [96/1000], Training Loss: 0.3434
# Epoch [96/1000], Validation Loss: 0.3801, Validation Accuracy: 86.23%
# Output Summary: Max=28.5241, Min=-27.7628, Median=5.9507, Mean=4.0199
#
# Epoch [97/1000], Training Loss: 0.3425
# Epoch [97/1000], Validation Loss: 0.3791, Validation Accuracy: 86.25%
# Output Summary: Max=28.5746, Min=-27.7246, Median=5.9356, Mean=4.0061
#
# Epoch [98/1000], Training Loss: 0.3416
# Epoch [98/1000], Validation Loss: 0.3782, Validation Accuracy: 86.28%
# Output Summary: Max=28.5389, Min=-27.6844, Median=5.9070, Mean=3.9822
#
# Epoch [99/1000], Training Loss: 0.3406
# Epoch [99/1000], Validation Loss: 0.3772, Validation Accuracy: 86.40%
# Output Summary: Max=28.5707, Min=-27.5279, Median=5.8668, Mean=3.9614
#
# Epoch [100/1000], Training Loss: 0.3396
# Epoch [100/1000], Validation Loss: 0.3763, Validation Accuracy: 86.44%
# Output Summary: Max=28.6079, Min=-27.5032, Median=5.8457, Mean=3.9432
#
# Epoch [101/1000], Training Loss: 0.3386
# Epoch [101/1000], Validation Loss: 0.3752, Validation Accuracy: 86.48%
# Output Summary: Max=28.6214, Min=-27.4293, Median=5.8179, Mean=3.9203
#
# Epoch [102/1000], Training Loss: 0.3376
# Epoch [102/1000], Validation Loss: 0.3745, Validation Accuracy: 86.52%
# Output Summary: Max=28.6762, Min=-27.4562, Median=5.8043, Mean=3.9044
#
# Epoch [103/1000], Training Loss: 0.3367
# Epoch [103/1000], Validation Loss: 0.3736, Validation Accuracy: 86.45%
# Output Summary: Max=28.7231, Min=-27.5953, Median=5.7993, Mean=3.8878
#
# Epoch [104/1000], Training Loss: 0.3358
# Epoch [104/1000], Validation Loss: 0.3729, Validation Accuracy: 86.48%
# Output Summary: Max=28.7770, Min=-27.5766, Median=5.7827, Mean=3.8741
#
# Epoch [105/1000], Training Loss: 0.3350
# Epoch [105/1000], Validation Loss: 0.3721, Validation Accuracy: 86.50%
# Output Summary: Max=28.7882, Min=-27.5221, Median=5.7561, Mean=3.8560
#
# Epoch [106/1000], Training Loss: 0.3341
# Epoch [106/1000], Validation Loss: 0.3714, Validation Accuracy: 86.51%
# Output Summary: Max=28.8194, Min=-27.4789, Median=5.7515, Mean=3.8349
#
# Epoch [107/1000], Training Loss: 0.3333
# Epoch [107/1000], Validation Loss: 0.3707, Validation Accuracy: 86.51%
# Output Summary: Max=28.8566, Min=-27.4032, Median=5.7128, Mean=3.8194
#
# Epoch [108/1000], Training Loss: 0.3325
# Epoch [108/1000], Validation Loss: 0.3700, Validation Accuracy: 86.54%
# Output Summary: Max=28.9385, Min=-27.4667, Median=5.7152, Mean=3.8002
#
# Epoch [109/1000], Training Loss: 0.3317
# Epoch [109/1000], Validation Loss: 0.3691, Validation Accuracy: 86.57%
# Output Summary: Max=28.9211, Min=-27.4238, Median=5.6710, Mean=3.7756
#
# Epoch [110/1000], Training Loss: 0.3308
# Epoch [110/1000], Validation Loss: 0.3684, Validation Accuracy: 86.63%
# Output Summary: Max=28.9170, Min=-27.5167, Median=5.6447, Mean=3.7549
#
# Epoch [111/1000], Training Loss: 0.3299
# Epoch [111/1000], Validation Loss: 0.3676, Validation Accuracy: 86.63%
# Output Summary: Max=28.9607, Min=-27.5815, Median=5.6249, Mean=3.7393
#
# Epoch [112/1000], Training Loss: 0.3290
# Epoch [112/1000], Validation Loss: 0.3669, Validation Accuracy: 86.63%
# Output Summary: Max=29.0124, Min=-27.7346, Median=5.6193, Mean=3.7255
#
# Epoch [113/1000], Training Loss: 0.3283
# Epoch [113/1000], Validation Loss: 0.3662, Validation Accuracy: 86.67%
# Output Summary: Max=28.9838, Min=-27.7747, Median=5.5971, Mean=3.7068
#
# Epoch [114/1000], Training Loss: 0.3274
# Epoch [114/1000], Validation Loss: 0.3655, Validation Accuracy: 86.72%
# Output Summary: Max=28.9808, Min=-27.8838, Median=5.5894, Mean=3.6902
#
# Epoch [115/1000], Training Loss: 0.3266
# Epoch [115/1000], Validation Loss: 0.3650, Validation Accuracy: 86.77%
# Output Summary: Max=28.9845, Min=-27.9545, Median=5.5824, Mean=3.6782
#
# Epoch [116/1000], Training Loss: 0.3259
# Epoch [116/1000], Validation Loss: 0.3645, Validation Accuracy: 86.82%
# Output Summary: Max=29.1058, Min=-28.1801, Median=5.5740, Mean=3.6642
#
# Epoch [117/1000], Training Loss: 0.3251
# Epoch [117/1000], Validation Loss: 0.3636, Validation Accuracy: 86.87%
# Output Summary: Max=29.1356, Min=-28.2514, Median=5.5328, Mean=3.6364
#
# Epoch [118/1000], Training Loss: 0.3243
# Epoch [118/1000], Validation Loss: 0.3631, Validation Accuracy: 86.91%
# Output Summary: Max=29.1418, Min=-28.4352, Median=5.5281, Mean=3.6235
#
# Epoch [119/1000], Training Loss: 0.3235
# Epoch [119/1000], Validation Loss: 0.3624, Validation Accuracy: 86.96%
# Output Summary: Max=29.1880, Min=-28.5587, Median=5.5065, Mean=3.6074
#
# Epoch [120/1000], Training Loss: 0.3228
# Epoch [120/1000], Validation Loss: 0.3620, Validation Accuracy: 87.00%
# Output Summary: Max=29.1956, Min=-28.6695, Median=5.4778, Mean=3.5815
#
# Epoch [121/1000], Training Loss: 0.3221
# Epoch [121/1000], Validation Loss: 0.3611, Validation Accuracy: 86.99%
# Output Summary: Max=29.2979, Min=-28.9217, Median=5.4517, Mean=3.5512
#
# Epoch [122/1000], Training Loss: 0.3212
# Epoch [122/1000], Validation Loss: 0.3604, Validation Accuracy: 87.02%
# Output Summary: Max=29.2584, Min=-28.9928, Median=5.4180, Mean=3.5272
#
# Epoch [123/1000], Training Loss: 0.3204
# Epoch [123/1000], Validation Loss: 0.3601, Validation Accuracy: 87.05%
# Output Summary: Max=29.3659, Min=-29.1403, Median=5.3995, Mean=3.5097
#
# Epoch [124/1000], Training Loss: 0.3197
# Epoch [124/1000], Validation Loss: 0.3597, Validation Accuracy: 87.14%
# Output Summary: Max=29.4071, Min=-29.3100, Median=5.4033, Mean=3.5062
#
# Epoch [125/1000], Training Loss: 0.3189
# Epoch [125/1000], Validation Loss: 0.3593, Validation Accuracy: 87.20%
# Output Summary: Max=29.4072, Min=-29.3113, Median=5.3751, Mean=3.4883
#
# Epoch [126/1000], Training Loss: 0.3183
# Epoch [126/1000], Validation Loss: 0.3588, Validation Accuracy: 87.16%
# Output Summary: Max=29.3519, Min=-29.4183, Median=5.3609, Mean=3.4645
#
# Epoch [127/1000], Training Loss: 0.3176
# Epoch [127/1000], Validation Loss: 0.3583, Validation Accuracy: 87.20%
# Output Summary: Max=29.3563, Min=-29.4473, Median=5.3259, Mean=3.4419
#
# Epoch [128/1000], Training Loss: 0.3168
# Epoch [128/1000], Validation Loss: 0.3576, Validation Accuracy: 87.20%
# Output Summary: Max=29.3193, Min=-29.5345, Median=5.2994, Mean=3.4147
#
# Epoch [129/1000], Training Loss: 0.3161
# Epoch [129/1000], Validation Loss: 0.3570, Validation Accuracy: 87.26%
# Output Summary: Max=29.2927, Min=-29.6632, Median=5.2753, Mean=3.3930
#
# Epoch [130/1000], Training Loss: 0.3154
# Epoch [130/1000], Validation Loss: 0.3568, Validation Accuracy: 87.28%
# Output Summary: Max=29.4022, Min=-29.8557, Median=5.2828, Mean=3.3882
#
# Epoch [131/1000], Training Loss: 0.3147
# Epoch [131/1000], Validation Loss: 0.3563, Validation Accuracy: 87.27%
# Output Summary: Max=29.4249, Min=-29.9408, Median=5.2723, Mean=3.3775
#
# Epoch [132/1000], Training Loss: 0.3140
# Epoch [132/1000], Validation Loss: 0.3558, Validation Accuracy: 87.24%
# Output Summary: Max=29.4065, Min=-29.9463, Median=5.2267, Mean=3.3495
#
# Epoch [133/1000], Training Loss: 0.3134
# Epoch [133/1000], Validation Loss: 0.3554, Validation Accuracy: 87.33%
# Output Summary: Max=29.4852, Min=-30.1851, Median=5.2366, Mean=3.3371
#
# Epoch [134/1000], Training Loss: 0.3125
# Epoch [134/1000], Validation Loss: 0.3551, Validation Accuracy: 87.35%
# Output Summary: Max=29.5086, Min=-30.1505, Median=5.1908, Mean=3.3135
#
# Epoch [135/1000], Training Loss: 0.3119
# Epoch [135/1000], Validation Loss: 0.3550, Validation Accuracy: 87.31%
# Output Summary: Max=29.5755, Min=-30.3445, Median=5.2188, Mean=3.3020
#
# Epoch [136/1000], Training Loss: 0.3111
# Epoch [136/1000], Validation Loss: 0.3543, Validation Accuracy: 87.41%
# Output Summary: Max=29.5762, Min=-30.0421, Median=5.1590, Mean=3.2850
#
# Epoch [137/1000], Training Loss: 0.3104
# Epoch [137/1000], Validation Loss: 0.3539, Validation Accuracy: 87.42%
# Output Summary: Max=29.6198, Min=-30.2771, Median=5.1676, Mean=3.2648
#
# Epoch [138/1000], Training Loss: 0.3097
# Epoch [138/1000], Validation Loss: 0.3537, Validation Accuracy: 87.40%
# Output Summary: Max=29.6585, Min=-30.2773, Median=5.1330, Mean=3.2474
#
# Epoch [139/1000], Training Loss: 0.3091
# Epoch [139/1000], Validation Loss: 0.3534, Validation Accuracy: 87.38%
# Output Summary: Max=29.7649, Min=-30.4980, Median=5.1298, Mean=3.2237
#
# Epoch [140/1000], Training Loss: 0.3085
# Epoch [140/1000], Validation Loss: 0.3531, Validation Accuracy: 87.42%
# Output Summary: Max=29.7859, Min=-30.5078, Median=5.0921, Mean=3.2097
#
# Epoch [141/1000], Training Loss: 0.3078
# Epoch [141/1000], Validation Loss: 0.3529, Validation Accuracy: 87.42%
# Output Summary: Max=29.9349, Min=-30.6923, Median=5.0797, Mean=3.1871
#
# Epoch [142/1000], Training Loss: 0.3073
# Epoch [142/1000], Validation Loss: 0.3527, Validation Accuracy: 87.42%
# Output Summary: Max=29.9916, Min=-30.9180, Median=5.0785, Mean=3.1723
#
# Epoch [143/1000], Training Loss: 0.3067
# Epoch [143/1000], Validation Loss: 0.3523, Validation Accuracy: 87.45%
# Output Summary: Max=30.0437, Min=-30.9737, Median=5.0621, Mean=3.1550
#
# Epoch [144/1000], Training Loss: 0.3060
# Epoch [144/1000], Validation Loss: 0.3521, Validation Accuracy: 87.49%
# Output Summary: Max=30.1275, Min=-31.0590, Median=5.0391, Mean=3.1396
#
# Epoch [145/1000], Training Loss: 0.3054
# Epoch [145/1000], Validation Loss: 0.3516, Validation Accuracy: 87.48%
# Output Summary: Max=30.1433, Min=-31.0422, Median=5.0098, Mean=3.1205
#
# Epoch [146/1000], Training Loss: 0.3048
# Epoch [146/1000], Validation Loss: 0.3513, Validation Accuracy: 87.47%
# Output Summary: Max=30.1777, Min=-31.2277, Median=5.0067, Mean=3.1024
#
# Epoch [147/1000], Training Loss: 0.3041
# Epoch [147/1000], Validation Loss: 0.3508, Validation Accuracy: 87.52%
# Output Summary: Max=30.1667, Min=-31.1180, Median=4.9528, Mean=3.0820
#
# Epoch [148/1000], Training Loss: 0.3034
# Epoch [148/1000], Validation Loss: 0.3504, Validation Accuracy: 87.53%
# Output Summary: Max=30.2053, Min=-31.1046, Median=4.9306, Mean=3.0660
#
# Epoch [149/1000], Training Loss: 0.3027
# Epoch [149/1000], Validation Loss: 0.3502, Validation Accuracy: 87.53%
# Output Summary: Max=30.3263, Min=-31.2985, Median=4.9475, Mean=3.0637
#
# Epoch [150/1000], Training Loss: 0.3020
# Epoch [150/1000], Validation Loss: 0.3499, Validation Accuracy: 87.52%
# Output Summary: Max=30.3340, Min=-31.2215, Median=4.9144, Mean=3.0424
#
# Epoch [151/1000], Training Loss: 0.3014
# Epoch [151/1000], Validation Loss: 0.3496, Validation Accuracy: 87.54%
# Output Summary: Max=30.4065, Min=-31.3168, Median=4.9003, Mean=3.0276
#
# Epoch [152/1000], Training Loss: 0.3007
# Epoch [152/1000], Validation Loss: 0.3492, Validation Accuracy: 87.56%
# Output Summary: Max=30.4849, Min=-31.3962, Median=4.8804, Mean=3.0085
#
# Epoch [153/1000], Training Loss: 0.3001
# Epoch [153/1000], Validation Loss: 0.3490, Validation Accuracy: 87.58%
# Output Summary: Max=30.5236, Min=-31.5109, Median=4.8765, Mean=2.9976
#
# Epoch [154/1000], Training Loss: 0.2996
# Epoch [154/1000], Validation Loss: 0.3490, Validation Accuracy: 87.62%
# Output Summary: Max=30.5898, Min=-31.5618, Median=4.8690, Mean=2.9887
#
# Epoch [155/1000], Training Loss: 0.2990
# Epoch [155/1000], Validation Loss: 0.3487, Validation Accuracy: 87.61%
# Output Summary: Max=30.7065, Min=-31.6367, Median=4.8439, Mean=2.9750
#
# Epoch [156/1000], Training Loss: 0.2984
# Epoch [156/1000], Validation Loss: 0.3484, Validation Accuracy: 87.57%
# Output Summary: Max=30.7560, Min=-31.5930, Median=4.8137, Mean=2.9575
#
# Epoch [157/1000], Training Loss: 0.2978
# Epoch [157/1000], Validation Loss: 0.3483, Validation Accuracy: 87.57%
# Output Summary: Max=30.8090, Min=-31.7304, Median=4.7953, Mean=2.9393
#
# Epoch [158/1000], Training Loss: 0.2974
# Epoch [158/1000], Validation Loss: 0.3477, Validation Accuracy: 87.60%
# Output Summary: Max=30.8107, Min=-31.7686, Median=4.7790, Mean=2.9249
#
# Epoch [159/1000], Training Loss: 0.2966
# Epoch [159/1000], Validation Loss: 0.3475, Validation Accuracy: 87.63%
# Output Summary: Max=30.8993, Min=-31.8713, Median=4.7718, Mean=2.9143
#
# Epoch [160/1000], Training Loss: 0.2961
# Epoch [160/1000], Validation Loss: 0.3474, Validation Accuracy: 87.64%
# Output Summary: Max=30.9738, Min=-31.9919, Median=4.7622, Mean=2.9004
#
# Epoch [161/1000], Training Loss: 0.2954
# Epoch [161/1000], Validation Loss: 0.3471, Validation Accuracy: 87.67%
# Output Summary: Max=31.0476, Min=-32.0598, Median=4.7365, Mean=2.8841
#
# Epoch [162/1000], Training Loss: 0.2948
# Epoch [162/1000], Validation Loss: 0.3463, Validation Accuracy: 87.70%
# Output Summary: Max=31.0756, Min=-32.1421, Median=4.7135, Mean=2.8643
#
# Epoch [163/1000], Training Loss: 0.2941
# Epoch [163/1000], Validation Loss: 0.3462, Validation Accuracy: 87.74%
# Output Summary: Max=31.1665, Min=-32.1497, Median=4.6892, Mean=2.8490
#
# Epoch [164/1000], Training Loss: 0.2936
# Epoch [164/1000], Validation Loss: 0.3462, Validation Accuracy: 87.75%
# Output Summary: Max=31.2214, Min=-32.3106, Median=4.6803, Mean=2.8320
#
# Epoch [165/1000], Training Loss: 0.2930
# Epoch [165/1000], Validation Loss: 0.3458, Validation Accuracy: 87.71%
# Output Summary: Max=31.2666, Min=-32.3290, Median=4.6476, Mean=2.8133
#
# Epoch [166/1000], Training Loss: 0.2924
# Epoch [166/1000], Validation Loss: 0.3454, Validation Accuracy: 87.71%
# Output Summary: Max=31.3728, Min=-32.3547, Median=4.6214, Mean=2.7989
#
# Epoch [167/1000], Training Loss: 0.2918
# Epoch [167/1000], Validation Loss: 0.3454, Validation Accuracy: 87.75%
# Output Summary: Max=31.4045, Min=-32.4731, Median=4.6191, Mean=2.7802
#
# Epoch [168/1000], Training Loss: 0.2913
# Epoch [168/1000], Validation Loss: 0.3450, Validation Accuracy: 87.79%
# Output Summary: Max=31.4802, Min=-32.6150, Median=4.6045, Mean=2.7637
#
# Epoch [169/1000], Training Loss: 0.2907
# Epoch [169/1000], Validation Loss: 0.3449, Validation Accuracy: 87.82%
# Output Summary: Max=31.5350, Min=-32.6248, Median=4.5794, Mean=2.7518
#
# Epoch [170/1000], Training Loss: 0.2901
# Epoch [170/1000], Validation Loss: 0.3445, Validation Accuracy: 87.86%
# Output Summary: Max=31.5870, Min=-32.7407, Median=4.5624, Mean=2.7327
#
# Epoch [171/1000], Training Loss: 0.2894
# Epoch [171/1000], Validation Loss: 0.3439, Validation Accuracy: 87.83%
# Output Summary: Max=31.6166, Min=-32.7359, Median=4.5359, Mean=2.7167
#
# Epoch [172/1000], Training Loss: 0.2887
# Epoch [172/1000], Validation Loss: 0.3433, Validation Accuracy: 87.85%
# Output Summary: Max=31.7333, Min=-32.9324, Median=4.5313, Mean=2.7032
#
# Epoch [173/1000], Training Loss: 0.2881
# Epoch [173/1000], Validation Loss: 0.3432, Validation Accuracy: 87.85%
# Output Summary: Max=31.8067, Min=-33.0486, Median=4.5307, Mean=2.6920
#
# Epoch [174/1000], Training Loss: 0.2875
# Epoch [174/1000], Validation Loss: 0.3429, Validation Accuracy: 87.86%
# Output Summary: Max=31.9118, Min=-33.0740, Median=4.5113, Mean=2.6786
#
# Epoch [175/1000], Training Loss: 0.2868
# Epoch [175/1000], Validation Loss: 0.3425, Validation Accuracy: 87.85%
# Output Summary: Max=31.9801, Min=-33.2122, Median=4.5125, Mean=2.6640
#
# Epoch [176/1000], Training Loss: 0.2862
# Epoch [176/1000], Validation Loss: 0.3420, Validation Accuracy: 87.84%
# Output Summary: Max=32.0416, Min=-33.1786, Median=4.4965, Mean=2.6564
#
# Epoch [177/1000], Training Loss: 0.2855
# Epoch [177/1000], Validation Loss: 0.3414, Validation Accuracy: 87.80%
# Output Summary: Max=32.1728, Min=-33.3034, Median=4.4836, Mean=2.6440
#
# Epoch [178/1000], Training Loss: 0.2850
# Epoch [178/1000], Validation Loss: 0.3409, Validation Accuracy: 87.84%
# Output Summary: Max=32.2882, Min=-33.4861, Median=4.4957, Mean=2.6329
#
# Epoch [179/1000], Training Loss: 0.2844
# Epoch [179/1000], Validation Loss: 0.3405, Validation Accuracy: 87.85%
# Output Summary: Max=32.3746, Min=-33.5398, Median=4.4930, Mean=2.6254
#
# Epoch [180/1000], Training Loss: 0.2838
# Epoch [180/1000], Validation Loss: 0.3403, Validation Accuracy: 87.83%
# Output Summary: Max=32.3861, Min=-33.6449, Median=4.4817, Mean=2.6038
#
# Epoch [181/1000], Training Loss: 0.2833
# Epoch [181/1000], Validation Loss: 0.3398, Validation Accuracy: 87.85%
# Output Summary: Max=32.3946, Min=-33.6301, Median=4.4673, Mean=2.5947
#
# Epoch [182/1000], Training Loss: 0.2828
# Epoch [182/1000], Validation Loss: 0.3395, Validation Accuracy: 87.89%
# Output Summary: Max=32.4289, Min=-33.6997, Median=4.4483, Mean=2.5816
#
# Epoch [183/1000], Training Loss: 0.2821
# Epoch [183/1000], Validation Loss: 0.3388, Validation Accuracy: 87.90%
# Output Summary: Max=32.4907, Min=-33.9008, Median=4.4341, Mean=2.5633
#
# Epoch [184/1000], Training Loss: 0.2816
# Epoch [184/1000], Validation Loss: 0.3385, Validation Accuracy: 87.91%
# Output Summary: Max=32.5539, Min=-33.9940, Median=4.4267, Mean=2.5575
#
# Epoch [185/1000], Training Loss: 0.2811
# Epoch [185/1000], Validation Loss: 0.3382, Validation Accuracy: 87.91%
# Output Summary: Max=32.6328, Min=-34.0714, Median=4.4279, Mean=2.5487
#
# Epoch [186/1000], Training Loss: 0.2806
# Epoch [186/1000], Validation Loss: 0.3378, Validation Accuracy: 87.96%
# Output Summary: Max=32.6535, Min=-34.1357, Median=4.4087, Mean=2.5334
#
# Epoch [187/1000], Training Loss: 0.2800
# Epoch [187/1000], Validation Loss: 0.3377, Validation Accuracy: 87.98%
# Output Summary: Max=32.7330, Min=-34.2309, Median=4.4120, Mean=2.5254
#
# Epoch [188/1000], Training Loss: 0.2795
# Epoch [188/1000], Validation Loss: 0.3374, Validation Accuracy: 87.99%
# Output Summary: Max=32.8129, Min=-34.3141, Median=4.3988, Mean=2.5131
#
# Epoch [189/1000], Training Loss: 0.2790
# Epoch [189/1000], Validation Loss: 0.3369, Validation Accuracy: 88.00%
# Output Summary: Max=32.8446, Min=-34.3968, Median=4.3804, Mean=2.4995
#
# Epoch [190/1000], Training Loss: 0.2785
# Epoch [190/1000], Validation Loss: 0.3369, Validation Accuracy: 87.96%
# Output Summary: Max=32.9741, Min=-34.5177, Median=4.3880, Mean=2.4932
#
# Epoch [191/1000], Training Loss: 0.2781
# Epoch [191/1000], Validation Loss: 0.3369, Validation Accuracy: 87.99%
# Output Summary: Max=32.9164, Min=-34.4583, Median=4.3500, Mean=2.4768
#
# Epoch [192/1000], Training Loss: 0.2777
# Epoch [192/1000], Validation Loss: 0.3363, Validation Accuracy: 88.01%
# Output Summary: Max=33.0811, Min=-34.6177, Median=4.3498, Mean=2.4613
#
# Epoch [193/1000], Training Loss: 0.2771
# Epoch [193/1000], Validation Loss: 0.3364, Validation Accuracy: 88.02%
# Output Summary: Max=33.1610, Min=-34.6540, Median=4.3354, Mean=2.4504
#
# Epoch [194/1000], Training Loss: 0.2766
# Epoch [194/1000], Validation Loss: 0.3361, Validation Accuracy: 88.09%
# Output Summary: Max=33.2519, Min=-34.7158, Median=4.3082, Mean=2.4308
#
# Epoch [195/1000], Training Loss: 0.2761
# Epoch [195/1000], Validation Loss: 0.3356, Validation Accuracy: 88.15%
# Output Summary: Max=33.3453, Min=-34.7713, Median=4.2908, Mean=2.4150
#
# Epoch [196/1000], Training Loss: 0.2756
# Epoch [196/1000], Validation Loss: 0.3354, Validation Accuracy: 88.14%
# Output Summary: Max=33.4696, Min=-34.9196, Median=4.2827, Mean=2.4008
#
# Epoch [197/1000], Training Loss: 0.2752
# Epoch [197/1000], Validation Loss: 0.3351, Validation Accuracy: 88.13%
# Output Summary: Max=33.5272, Min=-34.9751, Median=4.2651, Mean=2.3840
#
# Epoch [198/1000], Training Loss: 0.2746
# Epoch [198/1000], Validation Loss: 0.3349, Validation Accuracy: 88.06%
# Output Summary: Max=33.5818, Min=-35.1158, Median=4.2402, Mean=2.3609
#
# Epoch [199/1000], Training Loss: 0.2740
# Epoch [199/1000], Validation Loss: 0.3345, Validation Accuracy: 88.03%
# Output Summary: Max=33.5727, Min=-35.1554, Median=4.2373, Mean=2.3485
#
# Epoch [200/1000], Training Loss: 0.2735
# Epoch [200/1000], Validation Loss: 0.3342, Validation Accuracy: 88.05%
# Output Summary: Max=33.7118, Min=-35.4247, Median=4.2361, Mean=2.3288

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 1.7081
# Epoch [1/1000], Validation Loss: 0.9695, Validation Accuracy: 64.26%
# Output Summary: Max=18.9550, Min=-17.7916, Median=2.9532, Mean=2.6816
#
# Epoch [2/1000], Training Loss: 0.8493
# Epoch [2/1000], Validation Loss: 0.7686, Validation Accuracy: 71.64%
# Output Summary: Max=21.4130, Min=-23.1725, Median=3.5562, Mean=2.6070
#
# Epoch [3/1000], Training Loss: 0.7148
# Epoch [3/1000], Validation Loss: 0.6822, Validation Accuracy: 74.29%
# Output Summary: Max=20.8488, Min=-18.8119, Median=3.2916, Mean=2.4231
#
# Epoch [4/1000], Training Loss: 0.6425
# Epoch [4/1000], Validation Loss: 0.6331, Validation Accuracy: 76.68%
# Output Summary: Max=20.0240, Min=-17.0283, Median=2.9606, Mean=2.2373
#
# Epoch [5/1000], Training Loss: 0.5873
# Epoch [5/1000], Validation Loss: 0.5805, Validation Accuracy: 78.63%
# Output Summary: Max=21.2734, Min=-17.3467, Median=3.0032, Mean=2.3032
#
# Epoch [6/1000], Training Loss: 0.5582
# Epoch [6/1000], Validation Loss: 0.5695, Validation Accuracy: 79.12%
# Output Summary: Max=21.8886, Min=-16.2397, Median=2.9556, Mean=2.3227
#
# Epoch [7/1000], Training Loss: 0.5318
# Epoch [7/1000], Validation Loss: 0.5378, Validation Accuracy: 80.13%
# Output Summary: Max=22.3919, Min=-16.6754, Median=3.0707, Mean=2.4165
#
# Epoch [8/1000], Training Loss: 0.5084
# Epoch [8/1000], Validation Loss: 0.5226, Validation Accuracy: 80.44%
# Output Summary: Max=23.4307, Min=-17.3372, Median=3.1962, Mean=2.5334
#
# Epoch [9/1000], Training Loss: 0.4904
# Epoch [9/1000], Validation Loss: 0.5053, Validation Accuracy: 81.02%
# Output Summary: Max=24.3192, Min=-17.8862, Median=3.2292, Mean=2.5734
#
# Epoch [10/1000], Training Loss: 0.4727
# Epoch [10/1000], Validation Loss: 0.4906, Validation Accuracy: 81.77%
# Output Summary: Max=24.9677, Min=-18.0515, Median=3.2960, Mean=2.6523
#
# Epoch [11/1000], Training Loss: 0.4567
# Epoch [11/1000], Validation Loss: 0.4775, Validation Accuracy: 82.36%
# Output Summary: Max=25.4991, Min=-18.0428, Median=3.3623, Mean=2.7259
#
# Epoch [12/1000], Training Loss: 0.4423
# Epoch [12/1000], Validation Loss: 0.4658, Validation Accuracy: 82.64%
# Output Summary: Max=25.9130, Min=-17.7904, Median=3.3771, Mean=2.7682
#
# Epoch [13/1000], Training Loss: 0.4294
# Epoch [13/1000], Validation Loss: 0.4560, Validation Accuracy: 83.19%
# Output Summary: Max=26.3996, Min=-17.8533, Median=3.3399, Mean=2.7593
#
# Epoch [14/1000], Training Loss: 0.4184
# Epoch [14/1000], Validation Loss: 0.4453, Validation Accuracy: 83.49%
# Output Summary: Max=26.7255, Min=-17.9976, Median=3.2920, Mean=2.7646
#
# Epoch [15/1000], Training Loss: 0.4085
# Epoch [15/1000], Validation Loss: 0.4417, Validation Accuracy: 83.52%
# Output Summary: Max=27.1134, Min=-18.0920, Median=3.1801, Mean=2.7522
#
# Epoch [16/1000], Training Loss: 0.4018
# Epoch [16/1000], Validation Loss: 0.4404, Validation Accuracy: 83.49%
# Output Summary: Max=26.5298, Min=-17.7640, Median=3.0157, Mean=2.6703
#
# Epoch [17/1000], Training Loss: 0.3900
# Epoch [17/1000], Validation Loss: 0.4192, Validation Accuracy: 84.54%
# Output Summary: Max=26.4086, Min=-18.0744, Median=3.0812, Mean=2.6773
#
# Epoch [18/1000], Training Loss: 0.3816
# Epoch [18/1000], Validation Loss: 0.4160, Validation Accuracy: 84.62%
# Output Summary: Max=27.0625, Min=-18.0572, Median=3.0520, Mean=2.6957
#
# Epoch [19/1000], Training Loss: 0.3776
# Epoch [19/1000], Validation Loss: 0.4075, Validation Accuracy: 85.16%
# Output Summary: Max=26.1324, Min=-17.7273, Median=2.9643, Mean=2.5822
#
# Epoch [20/1000], Training Loss: 0.3676
# Epoch [20/1000], Validation Loss: 0.4006, Validation Accuracy: 85.40%
# Output Summary: Max=26.6290, Min=-17.7856, Median=2.9793, Mean=2.5916
#
# Epoch [21/1000], Training Loss: 0.3613
# Epoch [21/1000], Validation Loss: 0.3964, Validation Accuracy: 85.64%
# Output Summary: Max=26.9165, Min=-17.7831, Median=2.9538, Mean=2.5810
#
# Epoch [22/1000], Training Loss: 0.3565
# Epoch [22/1000], Validation Loss: 0.3920, Validation Accuracy: 85.63%
# Output Summary: Max=27.0021, Min=-18.3479, Median=2.9274, Mean=2.5045
#
# Epoch [23/1000], Training Loss: 0.3511
# Epoch [23/1000], Validation Loss: 0.3895, Validation Accuracy: 85.72%
# Output Summary: Max=27.0547, Min=-18.7816, Median=2.8648, Mean=2.4547
#
# Epoch [24/1000], Training Loss: 0.3454
# Epoch [24/1000], Validation Loss: 0.3835, Validation Accuracy: 86.04%
# Output Summary: Max=27.0717, Min=-18.9777, Median=2.8581, Mean=2.3975
#
# Epoch [25/1000], Training Loss: 0.3399
# Epoch [25/1000], Validation Loss: 0.3775, Validation Accuracy: 86.22%
# Output Summary: Max=26.8111, Min=-18.8467, Median=2.7503, Mean=2.2803
#
# Epoch [26/1000], Training Loss: 0.3351
# Epoch [26/1000], Validation Loss: 0.3731, Validation Accuracy: 86.29%
# Output Summary: Max=26.9974, Min=-19.1030, Median=2.6766, Mean=2.2494
#
# Epoch [27/1000], Training Loss: 0.3300
# Epoch [27/1000], Validation Loss: 0.3695, Validation Accuracy: 86.58%
# Output Summary: Max=27.2201, Min=-19.3125, Median=2.6392, Mean=2.2085
#
# Epoch [28/1000], Training Loss: 0.3254
# Epoch [28/1000], Validation Loss: 0.3652, Validation Accuracy: 86.66%
# Output Summary: Max=27.5307, Min=-19.7915, Median=2.6520, Mean=2.2022
#
# Epoch [29/1000], Training Loss: 0.3213
# Epoch [29/1000], Validation Loss: 0.3609, Validation Accuracy: 86.87%
# Output Summary: Max=27.7115, Min=-20.1496, Median=2.5725, Mean=2.1407
#
# Epoch [30/1000], Training Loss: 0.3176
# Epoch [30/1000], Validation Loss: 0.3607, Validation Accuracy: 86.84%
# Output Summary: Max=27.8003, Min=-20.3266, Median=2.5898, Mean=2.1077
#
# Epoch [31/1000], Training Loss: 0.3141
# Epoch [31/1000], Validation Loss: 0.3632, Validation Accuracy: 86.75%
# Output Summary: Max=28.0120, Min=-20.7384, Median=2.5591, Mean=2.1207
#
# Epoch [32/1000], Training Loss: 0.3101
# Epoch [32/1000], Validation Loss: 0.3592, Validation Accuracy: 86.82%
# Output Summary: Max=28.2279, Min=-20.9540, Median=2.4641, Mean=2.0605
#
# Epoch [33/1000], Training Loss: 0.3047
# Epoch [33/1000], Validation Loss: 0.3475, Validation Accuracy: 87.43%
# Output Summary: Max=28.8210, Min=-21.7712, Median=2.4377, Mean=2.0473
#
# Epoch [34/1000], Training Loss: 0.2991
# Epoch [34/1000], Validation Loss: 0.3464, Validation Accuracy: 87.39%
# Output Summary: Max=29.4792, Min=-22.4191, Median=2.4905, Mean=2.0767
#
# Epoch [35/1000], Training Loss: 0.2956
# Epoch [35/1000], Validation Loss: 0.3428, Validation Accuracy: 87.54%
# Output Summary: Max=29.5902, Min=-22.6482, Median=2.3714, Mean=2.0032
#
# Epoch [36/1000], Training Loss: 0.2930
# Epoch [36/1000], Validation Loss: 0.3394, Validation Accuracy: 87.54%
# Output Summary: Max=29.4378, Min=-22.6022, Median=2.3084, Mean=1.9518
#
# Epoch [37/1000], Training Loss: 0.2901
# Epoch [37/1000], Validation Loss: 0.3410, Validation Accuracy: 87.42%
# Output Summary: Max=29.3364, Min=-22.3207, Median=2.2535, Mean=1.9073
#
# Epoch [38/1000], Training Loss: 0.2868
# Epoch [38/1000], Validation Loss: 0.3373, Validation Accuracy: 87.56%
# Output Summary: Max=29.8431, Min=-22.2867, Median=2.2480, Mean=1.9061
#
# Epoch [39/1000], Training Loss: 0.2833
# Epoch [39/1000], Validation Loss: 0.3352, Validation Accuracy: 87.80%
# Output Summary: Max=30.3019, Min=-22.4633, Median=2.2703, Mean=1.9202
#
# Epoch [40/1000], Training Loss: 0.2807
# Epoch [40/1000], Validation Loss: 0.3344, Validation Accuracy: 87.82%
# Output Summary: Max=30.3619, Min=-22.5330, Median=2.2194, Mean=1.8871
#
# Epoch [41/1000], Training Loss: 0.2775
# Epoch [41/1000], Validation Loss: 0.3314, Validation Accuracy: 87.96%
# Output Summary: Max=30.7594, Min=-23.1794, Median=2.2385, Mean=1.8452
#
# Epoch [42/1000], Training Loss: 0.2747
# Epoch [42/1000], Validation Loss: 0.3288, Validation Accuracy: 88.06%
# Output Summary: Max=30.6061, Min=-23.5924, Median=2.1823, Mean=1.8223
#
# Epoch [43/1000], Training Loss: 0.2764
# Epoch [43/1000], Validation Loss: 0.3323, Validation Accuracy: 87.93%
# Output Summary: Max=29.6547, Min=-23.0216, Median=2.1249, Mean=1.7754
#
# Epoch [44/1000], Training Loss: 0.2808
# Epoch [44/1000], Validation Loss: 0.3448, Validation Accuracy: 87.38%
# Output Summary: Max=28.7265, Min=-21.9521, Median=1.8397, Mean=1.5318
#
# Epoch [45/1000], Training Loss: 0.2745
# Epoch [45/1000], Validation Loss: 0.3321, Validation Accuracy: 88.01%
# Output Summary: Max=29.6045, Min=-22.5924, Median=1.9468, Mean=1.6568
#
# Epoch [46/1000], Training Loss: 0.2719
# Epoch [46/1000], Validation Loss: 0.3302, Validation Accuracy: 87.89%
# Output Summary: Max=29.7705, Min=-22.5165, Median=1.8630, Mean=1.5872
#
# Epoch [47/1000], Training Loss: 0.2697
# Epoch [47/1000], Validation Loss: 0.3207, Validation Accuracy: 88.14%
# Output Summary: Max=29.8287, Min=-22.5879, Median=1.7081, Mean=1.5149
#
# Epoch [48/1000], Training Loss: 0.2670
# Epoch [48/1000], Validation Loss: 0.3175, Validation Accuracy: 88.54%
# Output Summary: Max=29.9733, Min=-23.4744, Median=1.5627, Mean=1.4855
#
# Epoch [49/1000], Training Loss: 0.2657
# Epoch [49/1000], Validation Loss: 0.3274, Validation Accuracy: 88.13%
# Output Summary: Max=30.0189, Min=-24.1512, Median=1.4722, Mean=1.4527
#
# Epoch [50/1000], Training Loss: 0.2666
# Epoch [50/1000], Validation Loss: 0.3289, Validation Accuracy: 88.11%
# Output Summary: Max=29.9064, Min=-24.5758, Median=1.3341, Mean=1.2947
#
# Epoch [51/1000], Training Loss: 0.2617
# Epoch [51/1000], Validation Loss: 0.3211, Validation Accuracy: 88.51%
# Output Summary: Max=30.2016, Min=-25.1099, Median=1.4103, Mean=1.2965
#
# Epoch [52/1000], Training Loss: 0.2558
# Epoch [52/1000], Validation Loss: 0.3184, Validation Accuracy: 88.58%
# Output Summary: Max=31.0798, Min=-26.4328, Median=1.3634, Mean=1.3020
#
# Epoch [53/1000], Training Loss: 0.2519
# Epoch [53/1000], Validation Loss: 0.3163, Validation Accuracy: 88.63%
# Output Summary: Max=32.1804, Min=-27.4546, Median=1.3594, Mean=1.3095
#
# Epoch [54/1000], Training Loss: 0.2485
# Epoch [54/1000], Validation Loss: 0.3124, Validation Accuracy: 88.94%
# Output Summary: Max=32.5406, Min=-28.3540, Median=1.3473, Mean=1.3332
#
# Epoch [55/1000], Training Loss: 0.2454
# Epoch [55/1000], Validation Loss: 0.3097, Validation Accuracy: 89.09%
# Output Summary: Max=33.6926, Min=-28.8838, Median=1.3213, Mean=1.3498
#
# Epoch [56/1000], Training Loss: 0.2428
# Epoch [56/1000], Validation Loss: 0.3090, Validation Accuracy: 89.01%
# Output Summary: Max=34.2713, Min=-29.2940, Median=1.3049, Mean=1.3523
#
# Epoch [57/1000], Training Loss: 0.2400
# Epoch [57/1000], Validation Loss: 0.3095, Validation Accuracy: 89.06%
# Output Summary: Max=34.9823, Min=-30.0827, Median=1.3408, Mean=1.3890
#
# Epoch [58/1000], Training Loss: 0.2377
# Epoch [58/1000], Validation Loss: 0.3115, Validation Accuracy: 88.98%
# Output Summary: Max=35.3224, Min=-30.9893, Median=1.3450, Mean=1.3511
#
# Epoch [59/1000], Training Loss: 0.2380
# Epoch [59/1000], Validation Loss: 0.3113, Validation Accuracy: 89.10%
# Output Summary: Max=35.3932, Min=-30.5455, Median=1.3089, Mean=1.3298
#
# Epoch [60/1000], Training Loss: 0.2387
# Epoch [60/1000], Validation Loss: 0.3146, Validation Accuracy: 88.95%
# Output Summary: Max=34.9317, Min=-29.8931, Median=1.1755, Mean=1.2397
#
# Epoch [61/1000], Training Loss: 0.2405
# Epoch [61/1000], Validation Loss: 0.3213, Validation Accuracy: 88.23%
# Output Summary: Max=33.3628, Min=-29.6167, Median=0.7255, Mean=0.9435
#
# Epoch [62/1000], Training Loss: 0.2418
# Epoch [62/1000], Validation Loss: 0.3158, Validation Accuracy: 88.58%
# Output Summary: Max=31.7002, Min=-29.2388, Median=0.6930, Mean=0.8182
#
# Epoch [63/1000], Training Loss: 0.2417
# Epoch [63/1000], Validation Loss: 0.3227, Validation Accuracy: 88.41%
# Output Summary: Max=31.8059, Min=-28.4193, Median=0.6948, Mean=0.8286
#
# Epoch [64/1000], Training Loss: 0.2398
# Epoch [64/1000], Validation Loss: 0.3127, Validation Accuracy: 88.74%
# Output Summary: Max=32.4966, Min=-29.6584, Median=0.7826, Mean=0.9117
#
# Epoch [65/1000], Training Loss: 0.2343
# Epoch [65/1000], Validation Loss: 0.3107, Validation Accuracy: 88.67%
# Output Summary: Max=32.9024, Min=-29.7804, Median=0.8716, Mean=0.9053
#
# Epoch [66/1000], Training Loss: 0.2301
# Epoch [66/1000], Validation Loss: 0.3105, Validation Accuracy: 88.79%
# Output Summary: Max=32.4341, Min=-29.7026, Median=0.8354, Mean=0.8592
#
# Epoch [67/1000], Training Loss: 0.2268
# Epoch [67/1000], Validation Loss: 0.3125, Validation Accuracy: 88.61%
# Output Summary: Max=32.5938, Min=-30.2413, Median=0.7403, Mean=0.7725
#
# Epoch [68/1000], Training Loss: 0.2242
# Epoch [68/1000], Validation Loss: 0.3153, Validation Accuracy: 88.35%
# Output Summary: Max=32.9124, Min=-30.0715, Median=0.6792, Mean=0.6667
#
# Epoch [69/1000], Training Loss: 0.2232
# Epoch [69/1000], Validation Loss: 0.3198, Validation Accuracy: 88.18%
# Output Summary: Max=33.8324, Min=-31.1229, Median=0.7136, Mean=0.6640
#
# Epoch [70/1000], Training Loss: 0.2239
# Epoch [70/1000], Validation Loss: 0.3211, Validation Accuracy: 88.28%
# Output Summary: Max=34.0250, Min=-31.0973, Median=0.7357, Mean=0.6814
#
# Epoch [71/1000], Training Loss: 0.2243
# Epoch [71/1000], Validation Loss: 0.3180, Validation Accuracy: 88.16%
# Output Summary: Max=33.7773, Min=-31.6336, Median=0.7555, Mean=0.7370
#
# Epoch [72/1000], Training Loss: 0.2239
# Epoch [72/1000], Validation Loss: 0.3137, Validation Accuracy: 88.48%
# Output Summary: Max=34.2633, Min=-31.4323, Median=0.7801, Mean=0.7427
#
# Epoch [73/1000], Training Loss: 0.2236
# Epoch [73/1000], Validation Loss: 0.3101, Validation Accuracy: 88.67%
# Output Summary: Max=35.8459, Min=-32.0069, Median=0.8021, Mean=0.7304
#
# Epoch [74/1000], Training Loss: 0.2190
# Epoch [74/1000], Validation Loss: 0.3101, Validation Accuracy: 88.80%
# Output Summary: Max=36.6854, Min=-31.4705, Median=0.9478, Mean=0.9871
#
# Epoch [75/1000], Training Loss: 0.2142
# Epoch [75/1000], Validation Loss: 0.3166, Validation Accuracy: 88.68%
# Output Summary: Max=37.6049, Min=-32.2043, Median=0.9274, Mean=1.0021
#
# Epoch [76/1000], Training Loss: 0.2119
# Epoch [76/1000], Validation Loss: 0.3205, Validation Accuracy: 88.57%
# Output Summary: Max=37.8406, Min=-32.9829, Median=0.7965, Mean=0.8665
#
# Early stopping triggered after 76 epochs.

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 0.2124
# Epoch [1/1000], Validation Loss: 0.3223, Validation Accuracy: 88.62%
# Output Summary: Max=37.2345, Min=-33.2681, Median=0.7298, Mean=0.7523
#
# Epoch [2/1000], Training Loss: 0.2127
# Epoch [2/1000], Validation Loss: 0.3344, Validation Accuracy: 88.15%
# Output Summary: Max=37.0837, Min=-33.0560, Median=0.6679, Mean=0.7063
#
# Epoch [3/1000], Training Loss: 0.2153
# Epoch [3/1000], Validation Loss: 0.3228, Validation Accuracy: 88.87%
# Output Summary: Max=34.9332, Min=-32.7047, Median=0.7557, Mean=0.7112
#
# Epoch [4/1000], Training Loss: 0.2118
# Epoch [4/1000], Validation Loss: 0.3239, Validation Accuracy: 88.56%
# Output Summary: Max=34.5521, Min=-33.6289, Median=0.5247, Mean=0.5905
#
# Epoch [5/1000], Training Loss: 0.2117
# Epoch [5/1000], Validation Loss: 0.3217, Validation Accuracy: 88.77%
# Output Summary: Max=34.6413, Min=-34.3847, Median=0.3629, Mean=0.5237
#
# Epoch [6/1000], Training Loss: 0.2150
# Epoch [6/1000], Validation Loss: 0.3180, Validation Accuracy: 88.92%
# Output Summary: Max=32.7073, Min=-32.6934, Median=0.5559, Mean=0.7181
#
# Epoch [7/1000], Training Loss: 0.2053
# Epoch [7/1000], Validation Loss: 0.3194, Validation Accuracy: 88.83%
# Output Summary: Max=34.3165, Min=-34.2061, Median=0.6462, Mean=0.6520
#
# Epoch [8/1000], Training Loss: 0.2013
# Epoch [8/1000], Validation Loss: 0.3225, Validation Accuracy: 88.81%
# Output Summary: Max=36.6524, Min=-35.0121, Median=0.5087, Mean=0.6107
#
# Epoch [9/1000], Training Loss: 0.2005
# Epoch [9/1000], Validation Loss: 0.3224, Validation Accuracy: 88.72%
# Output Summary: Max=37.4624, Min=-35.1836, Median=0.5738, Mean=0.5779
#
# Epoch [10/1000], Training Loss: 0.1987
# Epoch [10/1000], Validation Loss: 0.3240, Validation Accuracy: 88.75%
# Output Summary: Max=37.9571, Min=-35.4544, Median=0.5847, Mean=0.5832
#
# Epoch [11/1000], Training Loss: 0.1997
# Epoch [11/1000], Validation Loss: 0.3230, Validation Accuracy: 88.98%
# Output Summary: Max=37.9384, Min=-36.5678, Median=0.5835, Mean=0.6219
#
# Epoch [12/1000], Training Loss: 0.2012
# Epoch [12/1000], Validation Loss: 0.3190, Validation Accuracy: 89.01%
# Output Summary: Max=35.8686, Min=-36.0494, Median=0.5491, Mean=0.5503
#
# Epoch [13/1000], Training Loss: 0.1987
# Epoch [13/1000], Validation Loss: 0.3125, Validation Accuracy: 88.95%
# Output Summary: Max=36.3054, Min=-36.7003, Median=0.5709, Mean=0.4886
#
# Epoch [14/1000], Training Loss: 0.1972
# Epoch [14/1000], Validation Loss: 0.3150, Validation Accuracy: 88.94%
# Output Summary: Max=37.1042, Min=-39.4707, Median=0.5245, Mean=0.4549
#
# Epoch [15/1000], Training Loss: 0.1951
# Epoch [15/1000], Validation Loss: 0.3156, Validation Accuracy: 88.93%
# Output Summary: Max=37.0815, Min=-39.2707, Median=0.6004, Mean=0.4647
#
# Epoch [16/1000], Training Loss: 0.1927
# Epoch [16/1000], Validation Loss: 0.3189, Validation Accuracy: 88.94%
# Output Summary: Max=37.3613, Min=-38.3525, Median=0.6785, Mean=0.5133
#
# Epoch [17/1000], Training Loss: 0.1960
# Epoch [17/1000], Validation Loss: 0.3143, Validation Accuracy: 89.09%
# Output Summary: Max=37.9599, Min=-39.5218, Median=0.4091, Mean=0.3812
#
# Epoch [18/1000], Training Loss: 0.1883
# Epoch [18/1000], Validation Loss: 0.3164, Validation Accuracy: 89.15%
# Output Summary: Max=40.4484, Min=-41.5098, Median=0.4130, Mean=0.3964
#
# Epoch [19/1000], Training Loss: 0.1814
# Epoch [19/1000], Validation Loss: 0.3184, Validation Accuracy: 89.12%
# Output Summary: Max=42.7548, Min=-42.9489, Median=0.4608, Mean=0.4526
#
# Epoch [20/1000], Training Loss: 0.1805
# Epoch [20/1000], Validation Loss: 0.3223, Validation Accuracy: 89.03%
# Output Summary: Max=44.6349, Min=-44.1849, Median=0.4126, Mean=0.4477
#
# Epoch [21/1000], Training Loss: 0.1797
# Epoch [21/1000], Validation Loss: 0.3287, Validation Accuracy: 88.69%
# Output Summary: Max=45.6228, Min=-46.3515, Median=0.3690, Mean=0.3976
#
# Epoch [22/1000], Training Loss: 0.1791
# Epoch [22/1000], Validation Loss: 0.3381, Validation Accuracy: 88.77%
# Output Summary: Max=46.8894, Min=-47.9501, Median=0.3932, Mean=0.4251
#
# Epoch [23/1000], Training Loss: 0.1809
# Epoch [23/1000], Validation Loss: 0.3340, Validation Accuracy: 88.68%
# Output Summary: Max=46.3137, Min=-47.1365, Median=0.3639, Mean=0.3708
#
# Epoch [24/1000], Training Loss: 0.1837
# Epoch [24/1000], Validation Loss: 0.3282, Validation Accuracy: 88.94%
# Output Summary: Max=44.2859, Min=-43.9678, Median=0.2048, Mean=0.1800
#
# Epoch [25/1000], Training Loss: 0.1822
# Epoch [25/1000], Validation Loss: 0.3327, Validation Accuracy: 88.96%
# Output Summary: Max=43.8606, Min=-41.7181, Median=0.1705, Mean=0.1837
#
# Epoch [26/1000], Training Loss: 0.1807
# Epoch [26/1000], Validation Loss: 0.3313, Validation Accuracy: 89.20%
# Output Summary: Max=44.2515, Min=-43.8303, Median=0.3296, Mean=0.2498
#
# Epoch [27/1000], Training Loss: 0.1802
# Epoch [27/1000], Validation Loss: 0.3262, Validation Accuracy: 89.33%
# Output Summary: Max=42.8525, Min=-43.8929, Median=0.2944, Mean=0.2016
#
# Epoch [28/1000], Training Loss: 0.1733
# Epoch [28/1000], Validation Loss: 0.3273, Validation Accuracy: 89.25%
# Output Summary: Max=44.0472, Min=-44.2969, Median=0.3113, Mean=0.2109
#
# Epoch [29/1000], Training Loss: 0.1692
# Epoch [29/1000], Validation Loss: 0.3301, Validation Accuracy: 89.30%
# Output Summary: Max=45.2551, Min=-47.4292, Median=0.2653, Mean=0.1672
#
# Epoch [30/1000], Training Loss: 0.1680
# Epoch [30/1000], Validation Loss: 0.3339, Validation Accuracy: 89.36%
# Output Summary: Max=46.3187, Min=-49.7640, Median=0.1448, Mean=0.0389
#
# Epoch [31/1000], Training Loss: 0.1680
# Epoch [31/1000], Validation Loss: 0.3334, Validation Accuracy: 89.25%
# Output Summary: Max=45.5009, Min=-50.2811, Median=0.0245, Mean=-0.0684
#
# Epoch [32/1000], Training Loss: 0.1688
# Epoch [32/1000], Validation Loss: 0.3382, Validation Accuracy: 89.11%
# Output Summary: Max=45.3377, Min=-48.6728, Median=-0.0489, Mean=-0.1267
#
# Epoch [33/1000], Training Loss: 0.1706
# Epoch [33/1000], Validation Loss: 0.3511, Validation Accuracy: 88.51%
# Output Summary: Max=45.3311, Min=-47.7046, Median=-0.0069, Mean=-0.1319
#
# Early stopping triggered after 33 epochs.

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 1.8539
# Epoch [1/1000], Validation Loss: 1.0479, Validation Accuracy: 63.64%
# Output Summary: Max=13.4919, Min=-10.8509, Median=0.7589, Mean=0.8177
#
# Epoch [2/1000], Training Loss: 0.9139
# Epoch [2/1000], Validation Loss: 0.8332, Validation Accuracy: 69.59%
# Output Summary: Max=15.8360, Min=-20.6593, Median=0.9988, Mean=0.5593
#
# Epoch [3/1000], Training Loss: 0.7718
# Epoch [3/1000], Validation Loss: 0.7377, Validation Accuracy: 73.09%
# Output Summary: Max=17.5524, Min=-21.9330, Median=1.3413, Mean=0.4340
#
# Epoch [4/1000], Training Loss: 0.6963
# Epoch [4/1000], Validation Loss: 0.7229, Validation Accuracy: 73.43%
# Output Summary: Max=18.3551, Min=-22.0460, Median=1.6436, Mean=0.5397
#
# Epoch [5/1000], Training Loss: 0.6553
# Epoch [5/1000], Validation Loss: 0.7225, Validation Accuracy: 73.15%
# Output Summary: Max=19.3050, Min=-23.2021, Median=1.9817, Mean=0.6588
#
# Epoch [6/1000], Training Loss: 0.6309
# Epoch [6/1000], Validation Loss: 0.6526, Validation Accuracy: 75.31%
# Output Summary: Max=18.8202, Min=-22.3241, Median=1.9062, Mean=0.5915
#
# Epoch [7/1000], Training Loss: 0.6002
# Epoch [7/1000], Validation Loss: 0.6187, Validation Accuracy: 76.40%
# Output Summary: Max=19.0335, Min=-21.5735, Median=1.9059, Mean=0.6107
#
# Epoch [8/1000], Training Loss: 0.5788
# Epoch [8/1000], Validation Loss: 0.6036, Validation Accuracy: 77.03%
# Output Summary: Max=19.4754, Min=-21.2164, Median=1.9744, Mean=0.6477
#
# Epoch [9/1000], Training Loss: 0.5612
# Epoch [9/1000], Validation Loss: 0.5780, Validation Accuracy: 78.04%
# Output Summary: Max=19.5344, Min=-21.2089, Median=1.9095, Mean=0.5760
#
# Epoch [10/1000], Training Loss: 0.5438
# Epoch [10/1000], Validation Loss: 0.5680, Validation Accuracy: 78.38%
# Output Summary: Max=20.0994, Min=-21.6643, Median=1.9390, Mean=0.5957
#
# Epoch [11/1000], Training Loss: 0.5305
# Epoch [11/1000], Validation Loss: 0.5470, Validation Accuracy: 79.68%
# Output Summary: Max=19.9104, Min=-21.8651, Median=1.7277, Mean=0.4785
#
# Epoch [12/1000], Training Loss: 0.5185
# Epoch [12/1000], Validation Loss: 0.5391, Validation Accuracy: 79.86%
# Output Summary: Max=19.7511, Min=-22.4370, Median=1.5590, Mean=0.3683
#
# Epoch [13/1000], Training Loss: 0.5087
# Epoch [13/1000], Validation Loss: 0.5387, Validation Accuracy: 80.01%
# Output Summary: Max=19.4884, Min=-22.8003, Median=1.4039, Mean=0.2631
#
# Epoch [14/1000], Training Loss: 0.4951
# Epoch [14/1000], Validation Loss: 0.5178, Validation Accuracy: 80.79%
# Output Summary: Max=21.2277, Min=-24.7019, Median=1.5911, Mean=0.3380
#
# Epoch [15/1000], Training Loss: 0.4797
# Epoch [15/1000], Validation Loss: 0.5123, Validation Accuracy: 80.91%
# Output Summary: Max=21.5324, Min=-25.2552, Median=1.4557, Mean=0.2627
#
# Epoch [16/1000], Training Loss: 0.4709
# Epoch [16/1000], Validation Loss: 0.5000, Validation Accuracy: 81.50%
# Output Summary: Max=21.8185, Min=-25.8281, Median=1.4184, Mean=0.2486
#
# Epoch [17/1000], Training Loss: 0.4603
# Epoch [17/1000], Validation Loss: 0.4866, Validation Accuracy: 82.13%
# Output Summary: Max=22.1907, Min=-26.4794, Median=1.4093, Mean=0.2322
#
# Epoch [18/1000], Training Loss: 0.4507
# Epoch [18/1000], Validation Loss: 0.4738, Validation Accuracy: 82.78%
# Output Summary: Max=22.1568, Min=-27.1293, Median=1.3705, Mean=0.1805
#
# Epoch [19/1000], Training Loss: 0.4410
# Epoch [19/1000], Validation Loss: 0.4662, Validation Accuracy: 83.02%
# Output Summary: Max=22.4428, Min=-27.6401, Median=1.2861, Mean=0.1233
#
# Epoch [20/1000], Training Loss: 0.4329
# Epoch [20/1000], Validation Loss: 0.4587, Validation Accuracy: 83.14%
# Output Summary: Max=22.4922, Min=-28.0658, Median=1.2471, Mean=0.0956
#
# Epoch [21/1000], Training Loss: 0.4252
# Epoch [21/1000], Validation Loss: 0.4524, Validation Accuracy: 83.45%
# Output Summary: Max=22.7695, Min=-28.5603, Median=1.2119, Mean=0.0716
#
# Epoch [22/1000], Training Loss: 0.4186
# Epoch [22/1000], Validation Loss: 0.4484, Validation Accuracy: 83.69%
# Output Summary: Max=22.9911, Min=-29.1710, Median=1.1671, Mean=0.0777
#
# Epoch [23/1000], Training Loss: 0.4133
# Epoch [23/1000], Validation Loss: 0.4433, Validation Accuracy: 83.82%
# Output Summary: Max=22.6060, Min=-29.1969, Median=1.0723, Mean=0.0268
#
# Epoch [24/1000], Training Loss: 0.4057
# Epoch [24/1000], Validation Loss: 0.4328, Validation Accuracy: 84.24%
# Output Summary: Max=22.9287, Min=-29.8024, Median=1.0641, Mean=-0.0027
#
# Epoch [25/1000], Training Loss: 0.3977
# Epoch [25/1000], Validation Loss: 0.4281, Validation Accuracy: 84.46%
# Output Summary: Max=23.2634, Min=-30.2152, Median=1.0037, Mean=-0.0321
#
# Epoch [26/1000], Training Loss: 0.3917
# Epoch [26/1000], Validation Loss: 0.4220, Validation Accuracy: 84.57%
# Output Summary: Max=23.4003, Min=-30.2183, Median=0.9355, Mean=-0.0607
#
# Epoch [27/1000], Training Loss: 0.3857
# Epoch [27/1000], Validation Loss: 0.4165, Validation Accuracy: 84.88%
# Output Summary: Max=23.2083, Min=-29.9203, Median=0.7375, Mean=-0.1636
#
# Epoch [28/1000], Training Loss: 0.3783
# Epoch [28/1000], Validation Loss: 0.4098, Validation Accuracy: 85.17%
# Output Summary: Max=23.5879, Min=-30.6331, Median=0.7776, Mean=-0.1751
#
# Epoch [29/1000], Training Loss: 0.3729
# Epoch [29/1000], Validation Loss: 0.4056, Validation Accuracy: 85.27%
# Output Summary: Max=23.5012, Min=-30.7120, Median=0.7315, Mean=-0.2084
#
# Epoch [30/1000], Training Loss: 0.3680
# Epoch [30/1000], Validation Loss: 0.4011, Validation Accuracy: 85.39%
# Output Summary: Max=23.6747, Min=-31.0575, Median=0.7270, Mean=-0.2141
#
# Epoch [31/1000], Training Loss: 0.3634
# Epoch [31/1000], Validation Loss: 0.3974, Validation Accuracy: 85.49%
# Output Summary: Max=23.9162, Min=-31.7313, Median=0.6697, Mean=-0.2473
#
# Epoch [32/1000], Training Loss: 0.3576
# Epoch [32/1000], Validation Loss: 0.3917, Validation Accuracy: 85.81%
# Output Summary: Max=24.3784, Min=-32.5865, Median=0.6536, Mean=-0.2667
#
# Epoch [33/1000], Training Loss: 0.3539
# Epoch [33/1000], Validation Loss: 0.3907, Validation Accuracy: 85.80%
# Output Summary: Max=24.5992, Min=-32.9261, Median=0.6575, Mean=-0.2702
#
# Epoch [34/1000], Training Loss: 0.3499
# Epoch [34/1000], Validation Loss: 0.3861, Validation Accuracy: 86.02%
# Output Summary: Max=24.9091, Min=-33.2535, Median=0.6153, Mean=-0.2829
#
# Epoch [35/1000], Training Loss: 0.3453
# Epoch [35/1000], Validation Loss: 0.3811, Validation Accuracy: 86.13%
# Output Summary: Max=25.2294, Min=-33.9936, Median=0.6702, Mean=-0.2803
#
# Epoch [36/1000], Training Loss: 0.3416
# Epoch [36/1000], Validation Loss: 0.3799, Validation Accuracy: 86.27%
# Output Summary: Max=25.2256, Min=-34.0329, Median=0.5462, Mean=-0.3369
#
# Epoch [37/1000], Training Loss: 0.3395
# Epoch [37/1000], Validation Loss: 0.3768, Validation Accuracy: 86.34%
# Output Summary: Max=25.2138, Min=-34.1488, Median=0.5437, Mean=-0.3486
#
# Epoch [38/1000], Training Loss: 0.3350
# Epoch [38/1000], Validation Loss: 0.3711, Validation Accuracy: 86.52%
# Output Summary: Max=25.5873, Min=-34.7493, Median=0.4811, Mean=-0.3879
#
# Epoch [39/1000], Training Loss: 0.3318
# Epoch [39/1000], Validation Loss: 0.3709, Validation Accuracy: 86.68%
# Output Summary: Max=26.1797, Min=-34.8358, Median=0.5209, Mean=-0.3747
#
# Epoch [40/1000], Training Loss: 0.3296
# Epoch [40/1000], Validation Loss: 0.3687, Validation Accuracy: 86.82%
# Output Summary: Max=26.0685, Min=-34.9060, Median=0.3861, Mean=-0.4388
#
# Epoch [41/1000], Training Loss: 0.3273
# Epoch [41/1000], Validation Loss: 0.3660, Validation Accuracy: 86.89%
# Output Summary: Max=26.0597, Min=-34.8582, Median=0.2752, Mean=-0.5034
#
# Epoch [42/1000], Training Loss: 0.3238
# Epoch [42/1000], Validation Loss: 0.3626, Validation Accuracy: 87.03%
# Output Summary: Max=26.3695, Min=-35.5600, Median=0.2184, Mean=-0.5527
#
# Epoch [43/1000], Training Loss: 0.3207
# Epoch [43/1000], Validation Loss: 0.3609, Validation Accuracy: 87.07%
# Output Summary: Max=26.6166, Min=-35.7300, Median=0.1693, Mean=-0.5803
#
# Epoch [44/1000], Training Loss: 0.3183
# Epoch [44/1000], Validation Loss: 0.3594, Validation Accuracy: 87.16%
# Output Summary: Max=26.5615, Min=-35.8458, Median=0.1290, Mean=-0.6147
#
# Epoch [45/1000], Training Loss: 0.3163
# Epoch [45/1000], Validation Loss: 0.3571, Validation Accuracy: 87.26%
# Output Summary: Max=26.8715, Min=-35.8725, Median=0.1149, Mean=-0.6381
#
# Epoch [46/1000], Training Loss: 0.3142
# Epoch [46/1000], Validation Loss: 0.3555, Validation Accuracy: 87.32%
# Output Summary: Max=26.9382, Min=-36.0648, Median=0.0730, Mean=-0.6785
#
# Epoch [47/1000], Training Loss: 0.3126
# Epoch [47/1000], Validation Loss: 0.3528, Validation Accuracy: 87.37%
# Output Summary: Max=27.1027, Min=-36.1367, Median=0.0412, Mean=-0.6987
#
# Epoch [48/1000], Training Loss: 0.3105
# Epoch [48/1000], Validation Loss: 0.3521, Validation Accuracy: 87.48%
# Output Summary: Max=27.4724, Min=-36.2341, Median=0.0115, Mean=-0.7109
#
# Epoch [49/1000], Training Loss: 0.3094
# Epoch [49/1000], Validation Loss: 0.3512, Validation Accuracy: 87.58%
# Output Summary: Max=27.8783, Min=-36.2779, Median=0.0655, Mean=-0.6875
#
# Epoch [50/1000], Training Loss: 0.3086
# Epoch [50/1000], Validation Loss: 0.3515, Validation Accuracy: 87.35%
# Output Summary: Max=28.0273, Min=-36.6955, Median=0.1122, Mean=-0.7045
#
# Epoch [51/1000], Training Loss: 0.3064
# Epoch [51/1000], Validation Loss: 0.3511, Validation Accuracy: 87.44%
# Output Summary: Max=27.8074, Min=-36.7449, Median=-0.0416, Mean=-0.7963
#
# Epoch [52/1000], Training Loss: 0.3038
# Epoch [52/1000], Validation Loss: 0.3478, Validation Accuracy: 87.71%
# Output Summary: Max=27.9466, Min=-36.8774, Median=-0.1383, Mean=-0.8545
#
# Epoch [53/1000], Training Loss: 0.3008
# Epoch [53/1000], Validation Loss: 0.3450, Validation Accuracy: 87.79%
# Output Summary: Max=28.1855, Min=-37.6705, Median=-0.2405, Mean=-0.9533
#
# Epoch [54/1000], Training Loss: 0.2991
# Epoch [54/1000], Validation Loss: 0.3435, Validation Accuracy: 87.67%
# Output Summary: Max=27.7807, Min=-37.6185, Median=-0.3635, Mean=-1.0384
#
# Epoch [55/1000], Training Loss: 0.2973
# Epoch [55/1000], Validation Loss: 0.3418, Validation Accuracy: 87.70%
# Output Summary: Max=27.9230, Min=-37.7099, Median=-0.4089, Mean=-1.0800
#
# Epoch [56/1000], Training Loss: 0.2954
# Epoch [56/1000], Validation Loss: 0.3403, Validation Accuracy: 87.77%
# Output Summary: Max=28.1287, Min=-38.0397, Median=-0.4588, Mean=-1.1275
#
# Epoch [57/1000], Training Loss: 0.2955
# Epoch [57/1000], Validation Loss: 0.3407, Validation Accuracy: 87.98%
# Output Summary: Max=28.4548, Min=-37.4287, Median=-0.4350, Mean=-1.0937
#
# Epoch [58/1000], Training Loss: 0.2912
# Epoch [58/1000], Validation Loss: 0.3395, Validation Accuracy: 87.93%
# Output Summary: Max=28.5558, Min=-38.3098, Median=-0.6003, Mean=-1.2401
#
# Epoch [59/1000], Training Loss: 0.2890
# Epoch [59/1000], Validation Loss: 0.3383, Validation Accuracy: 87.98%
# Output Summary: Max=28.8166, Min=-38.3817, Median=-0.6308, Mean=-1.2561
#
# Epoch [60/1000], Training Loss: 0.2872
# Epoch [60/1000], Validation Loss: 0.3362, Validation Accuracy: 87.91%
# Output Summary: Max=29.1837, Min=-39.0485, Median=-0.6554, Mean=-1.2886
#
# Epoch [61/1000], Training Loss: 0.2849
# Epoch [61/1000], Validation Loss: 0.3344, Validation Accuracy: 88.15%
# Output Summary: Max=29.4969, Min=-39.3152, Median=-0.6369, Mean=-1.2899
#
# Epoch [62/1000], Training Loss: 0.2833
# Epoch [62/1000], Validation Loss: 0.3323, Validation Accuracy: 88.12%
# Output Summary: Max=29.1894, Min=-39.3647, Median=-0.7202, Mean=-1.3357
#
# Epoch [63/1000], Training Loss: 0.2813
# Epoch [63/1000], Validation Loss: 0.3309, Validation Accuracy: 88.12%
# Output Summary: Max=28.7675, Min=-39.8061, Median=-0.7570, Mean=-1.4131
#
# Epoch [64/1000], Training Loss: 0.2794
# Epoch [64/1000], Validation Loss: 0.3282, Validation Accuracy: 88.15%
# Output Summary: Max=28.9906, Min=-39.8953, Median=-0.7541, Mean=-1.4274
#
# Epoch [65/1000], Training Loss: 0.2783
# Epoch [65/1000], Validation Loss: 0.3278, Validation Accuracy: 88.20%
# Output Summary: Max=29.3036, Min=-39.6677, Median=-0.7338, Mean=-1.4112
#
# Epoch [66/1000], Training Loss: 0.2770
# Epoch [66/1000], Validation Loss: 0.3276, Validation Accuracy: 88.16%
# Output Summary: Max=29.2251, Min=-38.9049, Median=-0.7492, Mean=-1.3803
#
# Epoch [67/1000], Training Loss: 0.2758
# Epoch [67/1000], Validation Loss: 0.3268, Validation Accuracy: 88.16%
# Output Summary: Max=29.1899, Min=-39.0771, Median=-0.8335, Mean=-1.4516
#
# Epoch [68/1000], Training Loss: 0.2738
# Epoch [68/1000], Validation Loss: 0.3246, Validation Accuracy: 88.35%
# Output Summary: Max=29.1288, Min=-39.2823, Median=-0.9014, Mean=-1.4799
#
# Epoch [69/1000], Training Loss: 0.2719
# Epoch [69/1000], Validation Loss: 0.3274, Validation Accuracy: 88.23%
# Output Summary: Max=29.2770, Min=-39.4379, Median=-0.9300, Mean=-1.5113
#
# Epoch [70/1000], Training Loss: 0.2706
# Epoch [70/1000], Validation Loss: 0.3278, Validation Accuracy: 88.27%
# Output Summary: Max=29.1395, Min=-39.1301, Median=-0.9834, Mean=-1.5584
#
# Epoch [71/1000], Training Loss: 0.2693
# Epoch [71/1000], Validation Loss: 0.3279, Validation Accuracy: 88.25%
# Output Summary: Max=29.1123, Min=-39.5119, Median=-1.0135, Mean=-1.6198
#
# Epoch [72/1000], Training Loss: 0.2679
# Epoch [72/1000], Validation Loss: 0.3240, Validation Accuracy: 88.46%
# Output Summary: Max=29.1973, Min=-39.4701, Median=-1.0224, Mean=-1.6299
#
# Epoch [73/1000], Training Loss: 0.2674
# Epoch [73/1000], Validation Loss: 0.3221, Validation Accuracy: 88.42%
# Output Summary: Max=28.7352, Min=-38.4674, Median=-1.0900, Mean=-1.6260
#
# Epoch [74/1000], Training Loss: 0.2679
# Epoch [74/1000], Validation Loss: 0.3187, Validation Accuracy: 88.55%
# Output Summary: Max=28.3349, Min=-38.3403, Median=-1.0593, Mean=-1.6455
#
# Epoch [75/1000], Training Loss: 0.2674
# Epoch [75/1000], Validation Loss: 0.3164, Validation Accuracy: 88.58%
# Output Summary: Max=28.5552, Min=-38.4045, Median=-0.9438, Mean=-1.6241
#
# Epoch [76/1000], Training Loss: 0.2659
# Epoch [76/1000], Validation Loss: 0.3196, Validation Accuracy: 88.40%
# Output Summary: Max=28.5059, Min=-38.1909, Median=-0.9543, Mean=-1.6418
#
# Epoch [77/1000], Training Loss: 0.2630
# Epoch [77/1000], Validation Loss: 0.3209, Validation Accuracy: 88.18%
# Output Summary: Max=28.2618, Min=-38.2556, Median=-1.1483, Mean=-1.7860
#
# Epoch [78/1000], Training Loss: 0.2607
# Epoch [78/1000], Validation Loss: 0.3140, Validation Accuracy: 88.77%
# Output Summary: Max=29.6213, Min=-38.8309, Median=-1.0286, Mean=-1.6908
#
# Epoch [79/1000], Training Loss: 0.2577
# Epoch [79/1000], Validation Loss: 0.3120, Validation Accuracy: 88.86%
# Output Summary: Max=29.4394, Min=-39.1184, Median=-0.9939, Mean=-1.7304
#
# Epoch [80/1000], Training Loss: 0.2564
# Epoch [80/1000], Validation Loss: 0.3111, Validation Accuracy: 88.86%
# Output Summary: Max=29.4040, Min=-39.3498, Median=-1.0524, Mean=-1.7934
#
# Epoch [81/1000], Training Loss: 0.2557
# Epoch [81/1000], Validation Loss: 0.3114, Validation Accuracy: 88.90%
# Output Summary: Max=29.4810, Min=-39.0836, Median=-1.0289, Mean=-1.7822
#
# Epoch [82/1000], Training Loss: 0.2547
# Epoch [82/1000], Validation Loss: 0.3113, Validation Accuracy: 88.89%
# Output Summary: Max=29.7414, Min=-39.1026, Median=-1.0386, Mean=-1.7998
#
# Epoch [83/1000], Training Loss: 0.2545
# Epoch [83/1000], Validation Loss: 0.3104, Validation Accuracy: 88.90%
# Output Summary: Max=29.6165, Min=-39.0995, Median=-1.0610, Mean=-1.8297
#
# Epoch [84/1000], Training Loss: 0.2538
# Epoch [84/1000], Validation Loss: 0.3101, Validation Accuracy: 89.03%
# Output Summary: Max=29.0904, Min=-39.5775, Median=-1.1579, Mean=-1.9297
#
# Epoch [85/1000], Training Loss: 0.2510
# Epoch [85/1000], Validation Loss: 0.3112, Validation Accuracy: 88.90%
# Output Summary: Max=29.0995, Min=-40.0014, Median=-1.2977, Mean=-2.0380
#
# Epoch [86/1000], Training Loss: 0.2491
# Epoch [86/1000], Validation Loss: 0.3065, Validation Accuracy: 89.15%
# Output Summary: Max=29.3607, Min=-39.6640, Median=-1.2922, Mean=-1.9919
#
# Epoch [87/1000], Training Loss: 0.2475
# Epoch [87/1000], Validation Loss: 0.3053, Validation Accuracy: 89.07%
# Output Summary: Max=29.8942, Min=-40.0521, Median=-1.3046, Mean=-2.0042
#
# Epoch [88/1000], Training Loss: 0.2459
# Epoch [88/1000], Validation Loss: 0.3048, Validation Accuracy: 89.08%
# Output Summary: Max=30.0971, Min=-40.1242, Median=-1.3698, Mean=-2.0492
#
# Epoch [89/1000], Training Loss: 0.2452
# Epoch [89/1000], Validation Loss: 0.3062, Validation Accuracy: 89.18%
# Output Summary: Max=29.9103, Min=-40.0226, Median=-1.4852, Mean=-2.1209
#
# Epoch [90/1000], Training Loss: 0.2442
# Epoch [90/1000], Validation Loss: 0.3057, Validation Accuracy: 89.18%
# Output Summary: Max=30.5138, Min=-40.1636, Median=-1.4419, Mean=-2.1019
#
# Epoch [91/1000], Training Loss: 0.2435
# Epoch [91/1000], Validation Loss: 0.3054, Validation Accuracy: 89.20%
# Output Summary: Max=30.2760, Min=-40.0329, Median=-1.4737, Mean=-2.1180
#
# Epoch [92/1000], Training Loss: 0.2423
# Epoch [92/1000], Validation Loss: 0.3049, Validation Accuracy: 89.29%
# Output Summary: Max=30.3861, Min=-40.3182, Median=-1.5183, Mean=-2.1501
#
# Epoch [93/1000], Training Loss: 0.2410
# Epoch [93/1000], Validation Loss: 0.3064, Validation Accuracy: 89.26%
# Output Summary: Max=30.0150, Min=-41.4334, Median=-1.6366, Mean=-2.2644
#
# Epoch [94/1000], Training Loss: 0.2416
# Epoch [94/1000], Validation Loss: 0.3084, Validation Accuracy: 89.04%
# Output Summary: Max=29.8938, Min=-42.2625, Median=-1.6455, Mean=-2.2956
#
# Epoch [95/1000], Training Loss: 0.2406
# Epoch [95/1000], Validation Loss: 0.3038, Validation Accuracy: 89.15%
# Output Summary: Max=29.8720, Min=-41.9514, Median=-1.6851, Mean=-2.3329
#
# Epoch [96/1000], Training Loss: 0.2392
# Epoch [96/1000], Validation Loss: 0.3038, Validation Accuracy: 89.05%
# Output Summary: Max=30.3310, Min=-42.6585, Median=-1.7121, Mean=-2.3307
#
# Epoch [97/1000], Training Loss: 0.2381
# Epoch [97/1000], Validation Loss: 0.3046, Validation Accuracy: 89.02%
# Output Summary: Max=30.8263, Min=-42.7355, Median=-1.7337, Mean=-2.3405
#
# Epoch [98/1000], Training Loss: 0.2371
# Epoch [98/1000], Validation Loss: 0.3015, Validation Accuracy: 89.35%
# Output Summary: Max=31.1008, Min=-43.3354, Median=-1.6987, Mean=-2.3508
#
# Epoch [99/1000], Training Loss: 0.2363
# Epoch [99/1000], Validation Loss: 0.2996, Validation Accuracy: 89.36%
# Output Summary: Max=30.5900, Min=-43.0842, Median=-1.6729, Mean=-2.3410
#
# Epoch [100/1000], Training Loss: 0.2340
# Epoch [100/1000], Validation Loss: 0.2992, Validation Accuracy: 89.53%
# Output Summary: Max=30.7850, Min=-43.7099, Median=-1.7327, Mean=-2.3555
#
# Epoch [101/1000], Training Loss: 0.2331
# Epoch [101/1000], Validation Loss: 0.3001, Validation Accuracy: 89.63%
# Output Summary: Max=31.1642, Min=-43.4724, Median=-1.9081, Mean=-2.3910
#
# Epoch [102/1000], Training Loss: 0.2321
# Epoch [102/1000], Validation Loss: 0.3034, Validation Accuracy: 89.38%
# Output Summary: Max=32.0109, Min=-43.4582, Median=-1.7675, Mean=-2.3300
#
# Epoch [103/1000], Training Loss: 0.2320
# Epoch [103/1000], Validation Loss: 0.3002, Validation Accuracy: 89.59%
# Output Summary: Max=31.3494, Min=-43.4925, Median=-1.8484, Mean=-2.3743
#
# Epoch [104/1000], Training Loss: 0.2290
# Epoch [104/1000], Validation Loss: 0.3008, Validation Accuracy: 89.53%
# Output Summary: Max=31.5058, Min=-44.0341, Median=-1.8109, Mean=-2.4067
#
# Epoch [105/1000], Training Loss: 0.2282
# Epoch [105/1000], Validation Loss: 0.3026, Validation Accuracy: 89.46%
# Output Summary: Max=31.4647, Min=-44.4785, Median=-1.9243, Mean=-2.4871
#
# Epoch [106/1000], Training Loss: 0.2263
# Epoch [106/1000], Validation Loss: 0.2995, Validation Accuracy: 89.62%
# Output Summary: Max=32.0269, Min=-44.4023, Median=-1.9335, Mean=-2.4604
#
# Epoch [107/1000], Training Loss: 0.2247
# Epoch [107/1000], Validation Loss: 0.2996, Validation Accuracy: 89.64%
# Output Summary: Max=32.5677, Min=-44.8188, Median=-1.9684, Mean=-2.4969
#
# Epoch [108/1000], Training Loss: 0.2235
# Epoch [108/1000], Validation Loss: 0.3003, Validation Accuracy: 89.73%
# Output Summary: Max=33.0822, Min=-44.8391, Median=-1.9091, Mean=-2.4220
#
# Epoch [109/1000], Training Loss: 0.2232
# Epoch [109/1000], Validation Loss: 0.3041, Validation Accuracy: 89.64%
# Output Summary: Max=33.3442, Min=-44.7556, Median=-1.9262, Mean=-2.4276
#
# Epoch [110/1000], Training Loss: 0.2245
# Epoch [110/1000], Validation Loss: 0.3048, Validation Accuracy: 89.52%
# Output Summary: Max=32.6679, Min=-44.8924, Median=-1.9915, Mean=-2.5179
#
# Epoch [111/1000], Training Loss: 0.2237
# Epoch [111/1000], Validation Loss: 0.3041, Validation Accuracy: 89.46%
# Output Summary: Max=32.0198, Min=-44.9788, Median=-1.9970, Mean=-2.5408
#
# Epoch [112/1000], Training Loss: 0.2244
# Epoch [112/1000], Validation Loss: 0.3104, Validation Accuracy: 89.23%
# Output Summary: Max=31.8427, Min=-43.9148, Median=-1.9732, Mean=-2.4929
#
# Epoch [113/1000], Training Loss: 0.2335
# Epoch [113/1000], Validation Loss: 0.3042, Validation Accuracy: 89.38%
# Output Summary: Max=30.3739, Min=-41.7977, Median=-1.9728, Mean=-2.4936
#
# Epoch [114/1000], Training Loss: 0.2245
# Epoch [114/1000], Validation Loss: 0.3038, Validation Accuracy: 89.32%
# Output Summary: Max=32.2928, Min=-42.8144, Median=-1.7529, Mean=-2.3484
#
# Epoch [115/1000], Training Loss: 0.2225
# Epoch [115/1000], Validation Loss: 0.3003, Validation Accuracy: 89.45%
# Output Summary: Max=31.6831, Min=-43.6529, Median=-1.9494, Mean=-2.5144
#
# Epoch [116/1000], Training Loss: 0.2199
# Epoch [116/1000], Validation Loss: 0.3009, Validation Accuracy: 89.56%
# Output Summary: Max=32.8420, Min=-45.1937, Median=-2.0585, Mean=-2.5707
#
# Epoch [117/1000], Training Loss: 0.2190
# Epoch [117/1000], Validation Loss: 0.3077, Validation Accuracy: 89.27%
# Output Summary: Max=33.4493, Min=-44.7822, Median=-2.1358, Mean=-2.5853
#
# Epoch [118/1000], Training Loss: 0.2178
# Epoch [118/1000], Validation Loss: 0.3082, Validation Accuracy: 89.22%
# Output Summary: Max=34.1726, Min=-44.8504, Median=-2.2367, Mean=-2.6340
#
# Epoch [119/1000], Training Loss: 0.2154
# Epoch [119/1000], Validation Loss: 0.3055, Validation Accuracy: 89.38%
# Output Summary: Max=35.0869, Min=-45.5898, Median=-2.3162, Mean=-2.6838
#
# Epoch [120/1000], Training Loss: 0.2137
# Epoch [120/1000], Validation Loss: 0.3009, Validation Accuracy: 89.56%
# Output Summary: Max=35.2964, Min=-46.7746, Median=-2.4625, Mean=-2.8175
#
# Early stopping triggered after 120 epochs.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ExperimentalModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 4 * 8, kernel_size=2, stride=2)       # 28x28 -> 14x14
        self.conv2 = nn.Conv2d(8 * 4, 8 * 8, kernel_size=2, stride=2)   # 14x14 -> 7x7
        self.conv3 = nn.Conv2d(8 * 8, 8 * 8, kernel_size=2, stride=1)   # 7x7   -> 6x6
        self.conv4 = nn.Conv2d(8 * 8, 16 * 8, kernel_size=2, stride=2)  # 6x6   -> 3x3
        self.conv5 = nn.Conv2d(8 * 16, 16 * 8, kernel_size=2, stride=1) # 3x3   -> 2x2
        self.conv6 = nn.Conv2d(8 * 16, 32 * 8, kernel_size=2, stride=1) # 2x2   -> 1x1

        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(32 * 8, 10)

    def _conv_relu(self, x, conv_layer):
        return self.relu(conv_layer(x))

    def forward(self, x):
        x = self._conv_relu(x, self.conv1)
        x = self._conv_relu(x, self.conv2)
        x = self._conv_relu(x, self.conv3)
        x = self._conv_relu(x, self.conv4)
        x = self._conv_relu(x, self.conv5)
        x = self._conv_relu(x, self.conv6)

        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
learning_rate = 0.001 * 1
epochs = 1000

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ExperimentalModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for name, param in model.named_parameters():
    print(f"{name}: {param.numel()} params, requires_grad={param.requires_grad}")

total_params = sum(p.numel() for p in model.parameters())
print()
print(total_params)
# Out:
# conv1.weight: 128 params, requires_grad=True
# conv1.bias: 32 params, requires_grad=True
# conv2.weight: 8192 params, requires_grad=True
# conv2.bias: 64 params, requires_grad=True
# conv3.weight: 16384 params, requires_grad=True
# conv3.bias: 64 params, requires_grad=True
# conv4.weight: 32768 params, requires_grad=True
# conv4.bias: 128 params, requires_grad=True
# conv5.weight: 65536 params, requires_grad=True
# conv5.bias: 128 params, requires_grad=True
# conv6.weight: 131072 params, requires_grad=True
# conv6.bias: 256 params, requires_grad=True
# fc.weight: 2560 params, requires_grad=True
# fc.bias: 10 params, requires_grad=True
#
# 257322

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(1000):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 1.6043
# Epoch [1/1000], Validation Loss: 0.8719, Validation Accuracy: 67.78%
# Output Summary: Max=13.6333, Min=-18.7842, Median=0.8420, Mean=-0.0718
#
# Epoch [2/1000], Training Loss: 0.7601
# Epoch [2/1000], Validation Loss: 0.7028, Validation Accuracy: 73.42%
# Output Summary: Max=15.4859, Min=-22.1852, Median=1.0870, Mean=-0.4387
#
# Epoch [3/1000], Training Loss: 0.6564
# Epoch [3/1000], Validation Loss: 0.6429, Validation Accuracy: 74.93%
# Output Summary: Max=17.0843, Min=-23.9776, Median=1.4523, Mean=-0.4943
#
# Epoch [4/1000], Training Loss: 0.6023
# Epoch [4/1000], Validation Loss: 0.6106, Validation Accuracy: 76.33%
# Output Summary: Max=18.0315, Min=-25.8195, Median=1.4430, Mean=-0.5481
#
# Epoch [5/1000], Training Loss: 0.5609
# Epoch [5/1000], Validation Loss: 0.5582, Validation Accuracy: 79.34%
# Output Summary: Max=18.4508, Min=-26.6314, Median=1.3929, Mean=-0.5886
#
# Epoch [6/1000], Training Loss: 0.5211
# Epoch [6/1000], Validation Loss: 0.5224, Validation Accuracy: 80.69%
# Output Summary: Max=18.8175, Min=-27.0738, Median=1.3032, Mean=-0.5791
#
# Epoch [7/1000], Training Loss: 0.4888
# Epoch [7/1000], Validation Loss: 0.4983, Validation Accuracy: 81.42%
# Output Summary: Max=18.1076, Min=-26.3507, Median=1.1014, Mean=-0.5563
#
# Epoch [8/1000], Training Loss: 0.4602
# Epoch [8/1000], Validation Loss: 0.4767, Validation Accuracy: 82.50%
# Output Summary: Max=18.4348, Min=-26.2959, Median=1.0424, Mean=-0.5800
#
# Epoch [9/1000], Training Loss: 0.4416
# Epoch [9/1000], Validation Loss: 0.4608, Validation Accuracy: 83.01%
# Output Summary: Max=18.2291, Min=-25.8578, Median=0.9884, Mean=-0.6073
#
# Epoch [10/1000], Training Loss: 0.4256
# Epoch [10/1000], Validation Loss: 0.4486, Validation Accuracy: 83.45%
# Output Summary: Max=18.0318, Min=-25.4211, Median=0.8810, Mean=-0.6496
#
# Epoch [11/1000], Training Loss: 0.4103
# Epoch [11/1000], Validation Loss: 0.4391, Validation Accuracy: 83.88%
# Output Summary: Max=17.8084, Min=-24.5674, Median=0.7847, Mean=-0.6729
#
# Epoch [12/1000], Training Loss: 0.3977
# Epoch [12/1000], Validation Loss: 0.4254, Validation Accuracy: 84.36%
# Output Summary: Max=17.1794, Min=-23.8777, Median=0.5616, Mean=-0.7250
#
# Epoch [13/1000], Training Loss: 0.3868
# Epoch [13/1000], Validation Loss: 0.4098, Validation Accuracy: 84.97%
# Output Summary: Max=17.0089, Min=-23.8658, Median=0.3486, Mean=-0.7806
#
# Epoch [14/1000], Training Loss: 0.3759
# Epoch [14/1000], Validation Loss: 0.4010, Validation Accuracy: 85.29%
# Output Summary: Max=16.9854, Min=-23.7206, Median=0.2067, Mean=-0.7854
#
# Epoch [15/1000], Training Loss: 0.3649
# Epoch [15/1000], Validation Loss: 0.3906, Validation Accuracy: 85.76%
# Output Summary: Max=16.7616, Min=-23.6374, Median=0.0656, Mean=-0.8231
#
# Epoch [16/1000], Training Loss: 0.3557
# Epoch [16/1000], Validation Loss: 0.3838, Validation Accuracy: 85.78%
# Output Summary: Max=16.6946, Min=-23.5431, Median=-0.0542, Mean=-0.8440
#
# Epoch [17/1000], Training Loss: 0.3476
# Epoch [17/1000], Validation Loss: 0.3770, Validation Accuracy: 85.94%
# Output Summary: Max=16.9350, Min=-23.7000, Median=-0.0819, Mean=-0.8463
#
# Epoch [18/1000], Training Loss: 0.3396
# Epoch [18/1000], Validation Loss: 0.3708, Validation Accuracy: 86.41%
# Output Summary: Max=17.0068, Min=-23.6632, Median=-0.1746, Mean=-0.8746
#
# Epoch [19/1000], Training Loss: 0.3324
# Epoch [19/1000], Validation Loss: 0.3640, Validation Accuracy: 86.59%
# Output Summary: Max=17.0387, Min=-23.5257, Median=-0.2732, Mean=-0.8973
#
# Epoch [20/1000], Training Loss: 0.3262
# Epoch [20/1000], Validation Loss: 0.3594, Validation Accuracy: 86.76%
# Output Summary: Max=17.3867, Min=-23.7176, Median=-0.2911, Mean=-0.9223
#
# Epoch [21/1000], Training Loss: 0.3193
# Epoch [21/1000], Validation Loss: 0.3542, Validation Accuracy: 87.11%
# Output Summary: Max=17.2694, Min=-23.8866, Median=-0.3286, Mean=-0.9555
#
# Epoch [22/1000], Training Loss: 0.3127
# Epoch [22/1000], Validation Loss: 0.3484, Validation Accuracy: 87.23%
# Output Summary: Max=17.3043, Min=-23.6332, Median=-0.3706, Mean=-0.9762
#
# Epoch [23/1000], Training Loss: 0.3075
# Epoch [23/1000], Validation Loss: 0.3445, Validation Accuracy: 87.34%
# Output Summary: Max=17.4369, Min=-23.3781, Median=-0.4413, Mean=-1.0185
#
# Epoch [24/1000], Training Loss: 0.3028
# Epoch [24/1000], Validation Loss: 0.3411, Validation Accuracy: 87.49%
# Output Summary: Max=17.4615, Min=-23.2711, Median=-0.5129, Mean=-1.0438
#
# Epoch [25/1000], Training Loss: 0.2978
# Epoch [25/1000], Validation Loss: 0.3377, Validation Accuracy: 87.58%
# Output Summary: Max=17.5616, Min=-23.8232, Median=-0.5286, Mean=-1.0651
#
# Epoch [26/1000], Training Loss: 0.2924
# Epoch [26/1000], Validation Loss: 0.3340, Validation Accuracy: 87.65%
# Output Summary: Max=17.6959, Min=-24.0450, Median=-0.6093, Mean=-1.0952
#
# Epoch [27/1000], Training Loss: 0.2878
# Epoch [27/1000], Validation Loss: 0.3315, Validation Accuracy: 87.73%
# Output Summary: Max=17.4888, Min=-24.3643, Median=-0.6797, Mean=-1.1289
#
# Epoch [28/1000], Training Loss: 0.2843
# Epoch [28/1000], Validation Loss: 0.3309, Validation Accuracy: 87.72%
# Output Summary: Max=17.9230, Min=-24.7374, Median=-0.6707, Mean=-1.1522
#
# Epoch [29/1000], Training Loss: 0.2810
# Epoch [29/1000], Validation Loss: 0.3300, Validation Accuracy: 87.83%
# Output Summary: Max=17.9181, Min=-24.8195, Median=-0.7065, Mean=-1.1811
#
# Epoch [30/1000], Training Loss: 0.2784
# Epoch [30/1000], Validation Loss: 0.3341, Validation Accuracy: 87.61%
# Output Summary: Max=18.0732, Min=-24.8816, Median=-0.7148, Mean=-1.1868
#
# Epoch [31/1000], Training Loss: 0.2763
# Epoch [31/1000], Validation Loss: 0.3262, Validation Accuracy: 87.93%
# Output Summary: Max=17.4106, Min=-24.8343, Median=-0.7091, Mean=-1.2227
#
# Epoch [32/1000], Training Loss: 0.2732
# Epoch [32/1000], Validation Loss: 0.3163, Validation Accuracy: 88.38%
# Output Summary: Max=16.8053, Min=-24.1043, Median=-0.8308, Mean=-1.2680
#
# Epoch [33/1000], Training Loss: 0.2689
# Epoch [33/1000], Validation Loss: 0.3113, Validation Accuracy: 88.60%
# Output Summary: Max=16.9432, Min=-24.2125, Median=-0.9387, Mean=-1.3710
#
# Epoch [34/1000], Training Loss: 0.2630
# Epoch [34/1000], Validation Loss: 0.3066, Validation Accuracy: 88.84%
# Output Summary: Max=17.1328, Min=-24.6029, Median=-0.9406, Mean=-1.4042
#
# Epoch [35/1000], Training Loss: 0.2598
# Epoch [35/1000], Validation Loss: 0.3053, Validation Accuracy: 88.89%
# Output Summary: Max=17.4889, Min=-24.9821, Median=-0.9977, Mean=-1.4494
#
# Epoch [36/1000], Training Loss: 0.2570
# Epoch [36/1000], Validation Loss: 0.3039, Validation Accuracy: 89.03%
# Output Summary: Max=17.8900, Min=-25.2559, Median=-1.0407, Mean=-1.4736
#
# Epoch [37/1000], Training Loss: 0.2540
# Epoch [37/1000], Validation Loss: 0.3030, Validation Accuracy: 88.95%
# Output Summary: Max=18.0186, Min=-25.6816, Median=-1.0556, Mean=-1.4860
#
# Epoch [38/1000], Training Loss: 0.2521
# Epoch [38/1000], Validation Loss: 0.3098, Validation Accuracy: 88.79%
# Output Summary: Max=18.3744, Min=-25.9474, Median=-1.1431, Mean=-1.5397
#
# Epoch [39/1000], Training Loss: 0.2511
# Epoch [39/1000], Validation Loss: 0.3095, Validation Accuracy: 88.68%
# Output Summary: Max=18.4451, Min=-26.1047, Median=-1.2032, Mean=-1.5438
#
# Epoch [40/1000], Training Loss: 0.2459
# Epoch [40/1000], Validation Loss: 0.3015, Validation Accuracy: 89.04%
# Output Summary: Max=18.9904, Min=-26.4958, Median=-1.2238, Mean=-1.5790
#
# Epoch [41/1000], Training Loss: 0.2391
# Epoch [41/1000], Validation Loss: 0.2981, Validation Accuracy: 89.23%
# Output Summary: Max=19.5940, Min=-27.3533, Median=-1.2663, Mean=-1.6322
#
# Epoch [42/1000], Training Loss: 0.2350
# Epoch [42/1000], Validation Loss: 0.2962, Validation Accuracy: 89.28%
# Output Summary: Max=20.1303, Min=-27.7471, Median=-1.3646, Mean=-1.7151
#
# Epoch [43/1000], Training Loss: 0.2317
# Epoch [43/1000], Validation Loss: 0.2944, Validation Accuracy: 89.25%
# Output Summary: Max=20.5185, Min=-28.6569, Median=-1.4035, Mean=-1.7462
#
# Epoch [44/1000], Training Loss: 0.2288
# Epoch [44/1000], Validation Loss: 0.2936, Validation Accuracy: 89.39%
# Output Summary: Max=20.7374, Min=-29.0795, Median=-1.4414, Mean=-1.7763
#
# Epoch [45/1000], Training Loss: 0.2263
# Epoch [45/1000], Validation Loss: 0.2929, Validation Accuracy: 89.36%
# Output Summary: Max=20.8566, Min=-29.7917, Median=-1.5250, Mean=-1.8142
#
# Epoch [46/1000], Training Loss: 0.2241
# Epoch [46/1000], Validation Loss: 0.2917, Validation Accuracy: 89.49%
# Output Summary: Max=21.0505, Min=-30.0454, Median=-1.5601, Mean=-1.8614
#
# Epoch [47/1000], Training Loss: 0.2217
# Epoch [47/1000], Validation Loss: 0.2899, Validation Accuracy: 89.57%
# Output Summary: Max=21.1315, Min=-30.4335, Median=-1.6747, Mean=-1.9179
#
# Epoch [48/1000], Training Loss: 0.2195
# Epoch [48/1000], Validation Loss: 0.2883, Validation Accuracy: 89.71%
# Output Summary: Max=21.3703, Min=-30.0540, Median=-1.6975, Mean=-1.9526
#
# Epoch [49/1000], Training Loss: 0.2167
# Epoch [49/1000], Validation Loss: 0.2868, Validation Accuracy: 89.83%
# Output Summary: Max=21.5512, Min=-31.4732, Median=-1.7495, Mean=-2.0097
#
# Epoch [50/1000], Training Loss: 0.2140
# Epoch [50/1000], Validation Loss: 0.2846, Validation Accuracy: 90.05%
# Output Summary: Max=21.6587, Min=-32.3484, Median=-1.8352, Mean=-2.0518
#
# Epoch [51/1000], Training Loss: 0.2113
# Epoch [51/1000], Validation Loss: 0.2852, Validation Accuracy: 89.93%
# Output Summary: Max=22.1716, Min=-33.6722, Median=-1.8937, Mean=-2.1084
#
# Epoch [52/1000], Training Loss: 0.2086
# Epoch [52/1000], Validation Loss: 0.2842, Validation Accuracy: 90.03%
# Output Summary: Max=22.6356, Min=-34.8373, Median=-1.9852, Mean=-2.1853
#
# Epoch [53/1000], Training Loss: 0.2055
# Epoch [53/1000], Validation Loss: 0.2838, Validation Accuracy: 89.84%
# Output Summary: Max=23.0537, Min=-35.8665, Median=-2.0919, Mean=-2.2735
#
# Epoch [54/1000], Training Loss: 0.2025
# Epoch [54/1000], Validation Loss: 0.2856, Validation Accuracy: 89.78%
# Output Summary: Max=23.4717, Min=-36.2284, Median=-2.1464, Mean=-2.3276
#
# Epoch [55/1000], Training Loss: 0.2002
# Epoch [55/1000], Validation Loss: 0.2870, Validation Accuracy: 89.83%
# Output Summary: Max=23.8185, Min=-36.8910, Median=-2.2486, Mean=-2.4052
#
# Epoch [56/1000], Training Loss: 0.1969
# Epoch [56/1000], Validation Loss: 0.2878, Validation Accuracy: 89.79%
# Output Summary: Max=23.7929, Min=-38.1359, Median=-2.3385, Mean=-2.4389
#
# Epoch [57/1000], Training Loss: 0.1953
# Epoch [57/1000], Validation Loss: 0.2907, Validation Accuracy: 89.64%
# Output Summary: Max=23.9367, Min=-39.4322, Median=-2.4678, Mean=-2.5166
#
# Epoch [58/1000], Training Loss: 0.1929
# Epoch [58/1000], Validation Loss: 0.2920, Validation Accuracy: 89.66%
# Output Summary: Max=24.4154, Min=-40.3095, Median=-2.5890, Mean=-2.5760
#
# Epoch [59/1000], Training Loss: 0.1915
# Epoch [59/1000], Validation Loss: 0.2915, Validation Accuracy: 89.65%
# Output Summary: Max=24.8145, Min=-40.7866, Median=-2.6266, Mean=-2.5994
#
# Epoch [60/1000], Training Loss: 0.1903
# Epoch [60/1000], Validation Loss: 0.2833, Validation Accuracy: 90.02%
# Output Summary: Max=24.4098, Min=-40.3541, Median=-2.6461, Mean=-2.6408
#
# Epoch [61/1000], Training Loss: 0.1911
# Epoch [61/1000], Validation Loss: 0.2860, Validation Accuracy: 90.14%
# Output Summary: Max=24.7534, Min=-40.3256, Median=-2.7133, Mean=-2.7257
#
# Epoch [62/1000], Training Loss: 0.1859
# Epoch [62/1000], Validation Loss: 0.2863, Validation Accuracy: 90.04%
# Output Summary: Max=25.4879, Min=-40.8548, Median=-2.8309, Mean=-2.8455
#
# Epoch [63/1000], Training Loss: 0.1831
# Epoch [63/1000], Validation Loss: 0.2873, Validation Accuracy: 89.98%
# Output Summary: Max=25.6050, Min=-40.4144, Median=-2.7994, Mean=-2.8440
#
# Epoch [64/1000], Training Loss: 0.1825
# Epoch [64/1000], Validation Loss: 0.2902, Validation Accuracy: 90.00%
# Output Summary: Max=25.6525, Min=-40.7546, Median=-2.9805, Mean=-2.9479
#
# Epoch [65/1000], Training Loss: 0.1810
# Epoch [65/1000], Validation Loss: 0.2933, Validation Accuracy: 89.87%
# Output Summary: Max=25.5880, Min=-40.4127, Median=-3.0456, Mean=-2.9606
#
# Epoch [66/1000], Training Loss: 0.1796
# Epoch [66/1000], Validation Loss: 0.2934, Validation Accuracy: 89.87%
# Output Summary: Max=25.7117, Min=-40.7844, Median=-3.1726, Mean=-3.0193
#
# Epoch [67/1000], Training Loss: 0.1766
# Epoch [67/1000], Validation Loss: 0.2911, Validation Accuracy: 89.96%
# Output Summary: Max=26.2715, Min=-41.5284, Median=-3.2305, Mean=-3.0770
#
# Epoch [68/1000], Training Loss: 0.1722
# Epoch [68/1000], Validation Loss: 0.2928, Validation Accuracy: 90.10%
# Output Summary: Max=26.9427, Min=-43.0435, Median=-3.3485, Mean=-3.1785
#
# Epoch [69/1000], Training Loss: 0.1683
# Epoch [69/1000], Validation Loss: 0.2924, Validation Accuracy: 90.12%
# Output Summary: Max=27.2137, Min=-42.9764, Median=-3.3402, Mean=-3.2317
#
# Epoch [70/1000], Training Loss: 0.1638
# Epoch [70/1000], Validation Loss: 0.2914, Validation Accuracy: 90.06%
# Output Summary: Max=27.7317, Min=-42.9327, Median=-3.4434, Mean=-3.3443
#
# Epoch [71/1000], Training Loss: 0.1594
# Epoch [71/1000], Validation Loss: 0.2920, Validation Accuracy: 90.29%
# Output Summary: Max=28.2193, Min=-44.0786, Median=-3.5191, Mean=-3.4899
#
# Epoch [72/1000], Training Loss: 0.1564
# Epoch [72/1000], Validation Loss: 0.2942, Validation Accuracy: 90.13%
# Output Summary: Max=28.9542, Min=-45.1194, Median=-3.6156, Mean=-3.6040
#
# Epoch [73/1000], Training Loss: 0.1547
# Epoch [73/1000], Validation Loss: 0.2970, Validation Accuracy: 90.09%
# Output Summary: Max=29.2183, Min=-45.7160, Median=-3.6585, Mean=-3.6699
#
# Epoch [74/1000], Training Loss: 0.1547
# Epoch [74/1000], Validation Loss: 0.3079, Validation Accuracy: 89.90%
# Output Summary: Max=29.3298, Min=-46.2983, Median=-3.6717, Mean=-3.7132
#
# Epoch [75/1000], Training Loss: 0.1538
# Epoch [75/1000], Validation Loss: 0.3107, Validation Accuracy: 89.89%
# Output Summary: Max=30.0241, Min=-47.2283, Median=-3.7805, Mean=-3.7987
#
# Epoch [76/1000], Training Loss: 0.1565
# Epoch [76/1000], Validation Loss: 0.3071, Validation Accuracy: 89.81%
# Output Summary: Max=29.8758, Min=-46.2011, Median=-3.8827, Mean=-3.8094
#
# Epoch [77/1000], Training Loss: 0.1582
# Epoch [77/1000], Validation Loss: 0.3074, Validation Accuracy: 89.82%
# Output Summary: Max=30.4617, Min=-45.5972, Median=-4.0334, Mean=-3.9115
#
# Epoch [78/1000], Training Loss: 0.1523
# Epoch [78/1000], Validation Loss: 0.3115, Validation Accuracy: 89.46%
# Output Summary: Max=29.7549, Min=-45.4224, Median=-4.0346, Mean=-3.9145
#
# Epoch [79/1000], Training Loss: 0.1512
# Epoch [79/1000], Validation Loss: 0.3218, Validation Accuracy: 88.97%
# Output Summary: Max=29.7782, Min=-44.8221, Median=-3.9799, Mean=-3.8669
#
# Epoch [80/1000], Training Loss: 0.1514
# Epoch [80/1000], Validation Loss: 0.3216, Validation Accuracy: 89.19%
# Output Summary: Max=30.7457, Min=-47.1354, Median=-4.0248, Mean=-3.9394
#
# Early stopping triggered after 80 epochs.
