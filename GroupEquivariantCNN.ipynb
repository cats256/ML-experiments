# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader
from torchinfo import summary

# %% [markdown]
# Experiment with exploiting symmetries through convolution filter rotations and reflections. Works pretty well :)

# %%
# !pip install -U -q triton

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = datasets.MNIST(root='./data', train=True, download=True, transform=transform)
test_dataset = datasets.MNIST(root='./data', train=False, download=True, transform=transform)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9912422/9912422 [00:00<00:00, 43841482.92it/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28881/28881 [00:00<00:00, 1163300.97it/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1648877/1648877 [00:00<00:00, 10659561.31it/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4542/4542 [00:00<00:00, 4175000.83it/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_data = train_dataset.data.to(device).float() / 255.0
train_targets = train_dataset.targets.to(device)

test_data = test_dataset.data.to(device).float() / 255.0
test_targets = test_dataset.targets.to(device)

train_data = train_data.unsqueeze(1)
test_data = test_data.unsqueeze(1)

def get_batches(data, targets, batch_size):
    for i in range(0, len(data), batch_size):
        yield data[i:i + batch_size], targets[i:i + batch_size]

batch_size = 2000
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

class ExperimentalModel(nn.Module):
    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv2d(1, 4, kernel_size=2, stride=2)       # 28x28 -> 14x14
        self.conv2 = nn.Conv2d(8 * 4, 8, kernel_size=2, stride=2)   # 14x14 -> 7x7
        self.conv3 = nn.Conv2d(8 * 8, 8, kernel_size=2, stride=1)   # 7x7   -> 6x6
        self.conv4 = nn.Conv2d(8 * 8, 16, kernel_size=2, stride=2)  # 6x6   -> 3x3
        self.conv5 = nn.Conv2d(8 * 16, 16, kernel_size=2, stride=1) # 3x3   -> 2x2
        self.conv6 = nn.Conv2d(8 * 16, 32, kernel_size=2, stride=1) # 2x2   -> 1x1

        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Linear(32 * 8, 10)

    def _conv_relu(self, x, conv_layer):
        weight = conv_layer.weight
        bias = conv_layer.bias
        stride = conv_layer.stride
        padding = conv_layer.padding

        def conv_with(kernel):
            return F.conv2d(x, kernel, bias=bias, stride=stride, padding=padding)

        kernels = [
            weight,
            torch.rot90(weight, k=1, dims=[2, 3]),
            torch.rot90(weight, k=2, dims=[2, 3]),
            torch.rot90(weight, k=3, dims=[2, 3]),
            torch.flip(weight, dims=[3]),
            torch.flip(weight, dims=[2]),
            weight.transpose(2, 3),
            torch.flip(weight.transpose(2, 3), dims=[2, 3])
        ]

        outputs = [conv_with(k) for k in kernels]
        y = torch.cat(outputs, dim=1)
        return self.relu(y)

    def _conv_relu(self, x: torch.Tensor, conv_layer: torch.nn.Conv2d):
        w   = conv_layer.weight
        s, p = conv_layer.stride, conv_layer.padding
    
        kernels = torch.cat([
            w,
            torch.rot90(w, 1, (2, 3)),
            torch.rot90(w, 2, (2, 3)),
            torch.rot90(w, 3, (2, 3)),
            torch.flip(w, (3,)),
            torch.flip(w, (2,)),
            w.transpose(2, 3),
            torch.flip(w.transpose(2, 3), (2, 3)),
        ], dim=0)
    
        y = F.conv2d(x, kernels, bias=conv_layer.bias.repeat(8), stride=s, padding=p)    
        return self.relu(y)

    def forward(self, x):
        x = self._conv_relu(x, self.conv1)
        x = self._conv_relu(x, self.conv2)
        x = self._conv_relu(x, self.conv3)
        x = self._conv_relu(x, self.conv4)
        x = self._conv_relu(x, self.conv5)
        x = self._conv_relu(x, self.conv6)

        x = x.view(x.size(0), -1)
        x = self.fc(x)
        return x

# %%
learning_rate = 0.001 * 1
epochs = 1000

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ExperimentalModel().to(device)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
for name, param in model.named_parameters():
    print(f"{name}: {param.numel()} params, requires_grad={param.requires_grad}")

total_params = sum(p.numel() for p in model.parameters())
print()
print(total_params)
# Out:
# conv1.weight: 16 params, requires_grad=True
# conv1.bias: 4 params, requires_grad=True
# conv2.weight: 1024 params, requires_grad=True
# conv2.bias: 8 params, requires_grad=True
# conv3.weight: 2048 params, requires_grad=True
# conv3.bias: 8 params, requires_grad=True
# conv4.weight: 4096 params, requires_grad=True
# conv4.bias: 16 params, requires_grad=True
# conv5.weight: 8192 params, requires_grad=True
# conv5.bias: 16 params, requires_grad=True
# conv6.weight: 16384 params, requires_grad=True
# conv6.bias: 32 params, requires_grad=True
# fc.weight: 2560 params, requires_grad=True
# fc.bias: 10 params, requires_grad=True
#
# 34414

# %%
patience = 20
best_val_loss = float('inf')
no_improvement_epochs = 0

all_outputs = []

for epoch in range(200):
    model.train()
    running_loss = 0.0
    num_batches = 0
    
    for data, target in get_batches(train_data, train_targets, batch_size):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()


        optimizer.step()
        running_loss += loss.item()
        num_batches += 1

    print(f"Epoch [{epoch + 1}/{epochs}], Training Loss: {running_loss / num_batches:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    num_batches = 0
    epoch_outputs = []

    with torch.no_grad():
        for data, target in get_batches(test_data, test_targets, batch_size):
            outputs = model(data)
            loss = criterion(outputs, target)
            val_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            total += target.size(0)
            num_batches += 1
            correct += (predicted == target).sum().item()

            epoch_outputs.append(outputs)

    all_outputs_tensor = torch.cat(epoch_outputs, dim=0)
    all_outputs.append(all_outputs_tensor)

    max_val = torch.max(all_outputs_tensor).item()
    min_val = torch.min(all_outputs_tensor).item()
    median_val = torch.median(all_outputs_tensor).item()
    mean_val = torch.mean(all_outputs_tensor).item()

    accuracy = 100 * correct / total
    val_loss /= num_batches
    print(f"Epoch [{epoch + 1}/{epochs}], Validation Loss: {val_loss:.4f}, Validation Accuracy: {accuracy:.2f}%")
    print(f"Output Summary: Max={max_val:.4f}, Min={min_val:.4f}, Median={median_val:.4f}, Mean={mean_val:.4f}")
    print()

    if val_loss < best_val_loss:
        best_val_loss = val_loss
        no_improvement_epochs = 0
    else:
        no_improvement_epochs += 1

    if no_improvement_epochs >= patience:
        print(f"Early stopping triggered after {epoch + 1} epochs.")
        break
# Out:
# Epoch [1/1000], Training Loss: 2.2464
# Epoch [1/1000], Validation Loss: 2.0184, Validation Accuracy: 38.88%
# Output Summary: Max=3.5927, Min=-1.6119, Median=0.0114, Mean=0.0279
#
# Epoch [2/1000], Training Loss: 1.3496
# Epoch [2/1000], Validation Loss: 0.7923, Validation Accuracy: 74.37%
# Output Summary: Max=18.9871, Min=-13.3122, Median=2.1739, Mean=1.7690
#
# Epoch [3/1000], Training Loss: 0.6346
# Epoch [3/1000], Validation Loss: 0.5064, Validation Accuracy: 85.13%
# Output Summary: Max=19.1920, Min=-11.6659, Median=2.1465, Mean=2.0111
#
# Epoch [4/1000], Training Loss: 0.4763
# Epoch [4/1000], Validation Loss: 0.4288, Validation Accuracy: 86.99%
# Output Summary: Max=20.5189, Min=-14.0178, Median=2.1201, Mean=2.0524
#
# Epoch [5/1000], Training Loss: 0.4275
# Epoch [5/1000], Validation Loss: 0.3959, Validation Accuracy: 88.01%
# Output Summary: Max=20.7456, Min=-14.6761, Median=1.8109, Mean=1.8743
#
# Epoch [6/1000], Training Loss: 0.3866
# Epoch [6/1000], Validation Loss: 0.3471, Validation Accuracy: 89.67%
# Output Summary: Max=20.1220, Min=-14.4107, Median=1.7333, Mean=1.8054
#
# Epoch [7/1000], Training Loss: 0.3474
# Epoch [7/1000], Validation Loss: 0.3177, Validation Accuracy: 90.32%
# Output Summary: Max=20.0754, Min=-14.6632, Median=1.7076, Mean=1.8018
#
# Epoch [8/1000], Training Loss: 0.3213
# Epoch [8/1000], Validation Loss: 0.3031, Validation Accuracy: 90.66%
# Output Summary: Max=20.1537, Min=-15.3039, Median=1.6321, Mean=1.7703
#
# Epoch [9/1000], Training Loss: 0.3007
# Epoch [9/1000], Validation Loss: 0.2758, Validation Accuracy: 91.36%
# Output Summary: Max=20.0275, Min=-16.1826, Median=1.6143, Mean=1.7279
#
# Epoch [10/1000], Training Loss: 0.2793
# Epoch [10/1000], Validation Loss: 0.2477, Validation Accuracy: 92.23%
# Output Summary: Max=19.9085, Min=-16.9313, Median=1.6489, Mean=1.7124
#
# Epoch [11/1000], Training Loss: 0.2590
# Epoch [11/1000], Validation Loss: 0.2409, Validation Accuracy: 92.42%
# Output Summary: Max=20.3983, Min=-17.6245, Median=1.5510, Mean=1.7218
#
# Epoch [12/1000], Training Loss: 0.2433
# Epoch [12/1000], Validation Loss: 0.2289, Validation Accuracy: 92.78%
# Output Summary: Max=20.4628, Min=-18.1948, Median=1.5065, Mean=1.7196
#
# Epoch [13/1000], Training Loss: 0.2279
# Epoch [13/1000], Validation Loss: 0.2056, Validation Accuracy: 93.41%
# Output Summary: Max=20.4430, Min=-18.8159, Median=1.5398, Mean=1.7315
#
# Epoch [14/1000], Training Loss: 0.2116
# Epoch [14/1000], Validation Loss: 0.1932, Validation Accuracy: 93.74%
# Output Summary: Max=20.5316, Min=-19.2192, Median=1.5284, Mean=1.7529
#
# Epoch [15/1000], Training Loss: 0.1974
# Epoch [15/1000], Validation Loss: 0.1791, Validation Accuracy: 94.18%
# Output Summary: Max=20.6925, Min=-19.5848, Median=1.5354, Mean=1.7918
#
# Epoch [16/1000], Training Loss: 0.1867
# Epoch [16/1000], Validation Loss: 0.1713, Validation Accuracy: 94.45%
# Output Summary: Max=21.2852, Min=-19.8713, Median=1.5182, Mean=1.8254
#
# Epoch [17/1000], Training Loss: 0.1741
# Epoch [17/1000], Validation Loss: 0.1543, Validation Accuracy: 94.97%
# Output Summary: Max=21.5057, Min=-20.2259, Median=1.5669, Mean=1.8497
#
# Epoch [18/1000], Training Loss: 0.1657
# Epoch [18/1000], Validation Loss: 0.1409, Validation Accuracy: 95.61%
# Output Summary: Max=21.4455, Min=-20.6381, Median=1.5830, Mean=1.8103
#
# Epoch [19/1000], Training Loss: 0.1560
# Epoch [19/1000], Validation Loss: 0.1442, Validation Accuracy: 95.50%
# Output Summary: Max=22.4446, Min=-20.9617, Median=1.5281, Mean=1.9112
#
# Epoch [20/1000], Training Loss: 0.1461
# Epoch [20/1000], Validation Loss: 0.1277, Validation Accuracy: 95.99%
# Output Summary: Max=22.5759, Min=-21.7255, Median=1.5790, Mean=1.9087
#
# Epoch [21/1000], Training Loss: 0.1381
# Epoch [21/1000], Validation Loss: 0.1241, Validation Accuracy: 96.07%
# Output Summary: Max=23.0623, Min=-22.1756, Median=1.5538, Mean=1.9464
#
# Epoch [22/1000], Training Loss: 0.1324
# Epoch [22/1000], Validation Loss: 0.1209, Validation Accuracy: 96.09%
# Output Summary: Max=23.5739, Min=-22.6170, Median=1.5898, Mean=1.9999
#
# Epoch [23/1000], Training Loss: 0.1251
# Epoch [23/1000], Validation Loss: 0.1133, Validation Accuracy: 96.40%
# Output Summary: Max=23.7484, Min=-22.7851, Median=1.6183, Mean=2.0290
#
# Epoch [24/1000], Training Loss: 0.1189
# Epoch [24/1000], Validation Loss: 0.1089, Validation Accuracy: 96.56%
# Output Summary: Max=24.1885, Min=-23.2019, Median=1.6611, Mean=2.0751
#
# Epoch [25/1000], Training Loss: 0.1139
# Epoch [25/1000], Validation Loss: 0.1054, Validation Accuracy: 96.73%
# Output Summary: Max=24.6296, Min=-23.4611, Median=1.6961, Mean=2.1252
#
# Epoch [26/1000], Training Loss: 0.1095
# Epoch [26/1000], Validation Loss: 0.1022, Validation Accuracy: 96.79%
# Output Summary: Max=24.9918, Min=-23.7222, Median=1.7159, Mean=2.1402
#
# Epoch [27/1000], Training Loss: 0.1052
# Epoch [27/1000], Validation Loss: 0.0999, Validation Accuracy: 96.88%
# Output Summary: Max=25.2625, Min=-24.0020, Median=1.7383, Mean=2.1737
#
# Epoch [28/1000], Training Loss: 0.1015
# Epoch [28/1000], Validation Loss: 0.0942, Validation Accuracy: 96.99%
# Output Summary: Max=25.0515, Min=-23.9164, Median=1.7586, Mean=2.1538
#
# Epoch [29/1000], Training Loss: 0.0974
# Epoch [29/1000], Validation Loss: 0.0891, Validation Accuracy: 97.14%
# Output Summary: Max=25.0867, Min=-24.3671, Median=1.7641, Mean=2.1573
#
# Epoch [30/1000], Training Loss: 0.0943
# Epoch [30/1000], Validation Loss: 0.0858, Validation Accuracy: 97.17%
# Output Summary: Max=24.9537, Min=-24.7185, Median=1.7420, Mean=2.1549
#
# Epoch [31/1000], Training Loss: 0.0910
# Epoch [31/1000], Validation Loss: 0.0814, Validation Accuracy: 97.40%
# Output Summary: Max=24.6177, Min=-24.9484, Median=1.7153, Mean=2.1089
#
# Epoch [32/1000], Training Loss: 0.0869
# Epoch [32/1000], Validation Loss: 0.0813, Validation Accuracy: 97.38%
# Output Summary: Max=25.5697, Min=-25.2469, Median=1.7463, Mean=2.1815
#
# Epoch [33/1000], Training Loss: 0.0847
# Epoch [33/1000], Validation Loss: 0.0784, Validation Accuracy: 97.54%
# Output Summary: Max=25.3595, Min=-25.4290, Median=1.7515, Mean=2.1641
#
# Epoch [34/1000], Training Loss: 0.0836
# Epoch [34/1000], Validation Loss: 0.0808, Validation Accuracy: 97.41%
# Output Summary: Max=26.0890, Min=-25.9023, Median=1.7632, Mean=2.2130
#
# Epoch [35/1000], Training Loss: 0.0820
# Epoch [35/1000], Validation Loss: 0.0960, Validation Accuracy: 96.98%
# Output Summary: Max=27.5437, Min=-27.0406, Median=1.8348, Mean=2.3435
#
# Epoch [36/1000], Training Loss: 0.0786
# Epoch [36/1000], Validation Loss: 0.0815, Validation Accuracy: 97.37%
# Output Summary: Max=26.6596, Min=-27.2030, Median=1.8394, Mean=2.3142
#
# Epoch [37/1000], Training Loss: 0.0765
# Epoch [37/1000], Validation Loss: 0.0729, Validation Accuracy: 97.78%
# Output Summary: Max=26.1676, Min=-27.1761, Median=1.8333, Mean=2.2465
#
# Epoch [38/1000], Training Loss: 0.0750
# Epoch [38/1000], Validation Loss: 0.0693, Validation Accuracy: 97.85%
# Output Summary: Max=25.5925, Min=-27.1508, Median=1.7911, Mean=2.1669
#
# Epoch [39/1000], Training Loss: 0.0728
# Epoch [39/1000], Validation Loss: 0.0685, Validation Accuracy: 97.92%
# Output Summary: Max=25.9579, Min=-27.3114, Median=1.7894, Mean=2.1753
#
# Epoch [40/1000], Training Loss: 0.0716
# Epoch [40/1000], Validation Loss: 0.0682, Validation Accuracy: 97.94%
# Output Summary: Max=25.6538, Min=-27.1893, Median=1.7916, Mean=2.1195
#
# Epoch [41/1000], Training Loss: 0.0730
# Epoch [41/1000], Validation Loss: 0.0696, Validation Accuracy: 97.91%
# Output Summary: Max=25.2772, Min=-27.1283, Median=1.7925, Mean=2.0829
#
# Epoch [42/1000], Training Loss: 0.0670
# Epoch [42/1000], Validation Loss: 0.0682, Validation Accuracy: 97.83%
# Output Summary: Max=26.4487, Min=-27.7570, Median=1.7947, Mean=2.2114
#
# Epoch [43/1000], Training Loss: 0.0645
# Epoch [43/1000], Validation Loss: 0.0667, Validation Accuracy: 97.87%
# Output Summary: Max=26.5825, Min=-27.8831, Median=1.8307, Mean=2.2380
#
# Epoch [44/1000], Training Loss: 0.0626
# Epoch [44/1000], Validation Loss: 0.0677, Validation Accuracy: 97.88%
# Output Summary: Max=27.0695, Min=-28.2072, Median=1.8530, Mean=2.2828
#
# Epoch [45/1000], Training Loss: 0.0617
# Epoch [45/1000], Validation Loss: 0.0690, Validation Accuracy: 97.80%
# Output Summary: Max=27.1987, Min=-28.1862, Median=1.8403, Mean=2.2784
#
# Epoch [46/1000], Training Loss: 0.0616
# Epoch [46/1000], Validation Loss: 0.0690, Validation Accuracy: 97.74%
# Output Summary: Max=27.0884, Min=-28.3449, Median=1.8334, Mean=2.2834
#
# Epoch [47/1000], Training Loss: 0.0621
# Epoch [47/1000], Validation Loss: 0.0638, Validation Accuracy: 98.01%
# Output Summary: Max=26.2568, Min=-28.2938, Median=1.7007, Mean=2.0289
#
# Epoch [48/1000], Training Loss: 0.0580
# Epoch [48/1000], Validation Loss: 0.0618, Validation Accuracy: 98.02%
# Output Summary: Max=27.7025, Min=-29.4050, Median=1.7570, Mean=2.1130
#
# Epoch [49/1000], Training Loss: 0.0552
# Epoch [49/1000], Validation Loss: 0.0615, Validation Accuracy: 97.99%
# Output Summary: Max=28.1397, Min=-29.8120, Median=1.7579, Mean=2.1447
#
# Epoch [50/1000], Training Loss: 0.0534
# Epoch [50/1000], Validation Loss: 0.0626, Validation Accuracy: 98.01%
# Output Summary: Max=28.6240, Min=-30.0574, Median=1.7779, Mean=2.1645
#
# Epoch [51/1000], Training Loss: 0.0526
# Epoch [51/1000], Validation Loss: 0.0619, Validation Accuracy: 98.02%
# Output Summary: Max=28.7187, Min=-30.2197, Median=1.7845, Mean=2.1870
#
# Epoch [52/1000], Training Loss: 0.0514
# Epoch [52/1000], Validation Loss: 0.0598, Validation Accuracy: 98.06%
# Output Summary: Max=28.3050, Min=-29.9703, Median=1.7519, Mean=2.1262
#
# Epoch [53/1000], Training Loss: 0.0518
# Epoch [53/1000], Validation Loss: 0.0588, Validation Accuracy: 98.11%
# Output Summary: Max=28.4792, Min=-30.2526, Median=1.7598, Mean=2.1108
#
# Epoch [54/1000], Training Loss: 0.0512
# Epoch [54/1000], Validation Loss: 0.0559, Validation Accuracy: 98.28%
# Output Summary: Max=28.2419, Min=-30.1658, Median=1.7395, Mean=2.0341
#
# Epoch [55/1000], Training Loss: 0.0501
# Epoch [55/1000], Validation Loss: 0.0568, Validation Accuracy: 98.21%
# Output Summary: Max=29.1110, Min=-30.4994, Median=1.7532, Mean=2.0255
#
# Epoch [56/1000], Training Loss: 0.0489
# Epoch [56/1000], Validation Loss: 0.0578, Validation Accuracy: 98.17%
# Output Summary: Max=29.7792, Min=-30.6384, Median=1.7291, Mean=2.0223
#
# Epoch [57/1000], Training Loss: 0.0478
# Epoch [57/1000], Validation Loss: 0.0580, Validation Accuracy: 98.23%
# Output Summary: Max=30.0116, Min=-30.8478, Median=1.7050, Mean=2.0270
#
# Epoch [58/1000], Training Loss: 0.0471
# Epoch [58/1000], Validation Loss: 0.0591, Validation Accuracy: 98.15%
# Output Summary: Max=30.1236, Min=-30.9350, Median=1.6713, Mean=2.0161
#
# Epoch [59/1000], Training Loss: 0.0469
# Epoch [59/1000], Validation Loss: 0.0628, Validation Accuracy: 98.09%
# Output Summary: Max=30.0211, Min=-30.8993, Median=1.6506, Mean=2.0029
#
# Epoch [60/1000], Training Loss: 0.0467
# Epoch [60/1000], Validation Loss: 0.0628, Validation Accuracy: 98.04%
# Output Summary: Max=29.8462, Min=-30.4582, Median=1.5875, Mean=1.9219
#
# Epoch [61/1000], Training Loss: 0.0455
# Epoch [61/1000], Validation Loss: 0.0573, Validation Accuracy: 98.22%
# Output Summary: Max=29.9228, Min=-30.4086, Median=1.6166, Mean=1.9264
#
# Epoch [62/1000], Training Loss: 0.0431
# Epoch [62/1000], Validation Loss: 0.0555, Validation Accuracy: 98.33%
# Output Summary: Max=29.8264, Min=-30.5098, Median=1.6061, Mean=1.9249
#
# Epoch [63/1000], Training Loss: 0.0415
# Epoch [63/1000], Validation Loss: 0.0551, Validation Accuracy: 98.28%
# Output Summary: Max=30.4949, Min=-30.9239, Median=1.6296, Mean=2.0280
#
# Epoch [64/1000], Training Loss: 0.0400
# Epoch [64/1000], Validation Loss: 0.0579, Validation Accuracy: 98.15%
# Output Summary: Max=31.0218, Min=-30.8725, Median=1.6243, Mean=2.0968
#
# Epoch [65/1000], Training Loss: 0.0391
# Epoch [65/1000], Validation Loss: 0.0607, Validation Accuracy: 98.00%
# Output Summary: Max=31.4156, Min=-30.9863, Median=1.6106, Mean=2.1081
#
# Epoch [66/1000], Training Loss: 0.0382
# Epoch [66/1000], Validation Loss: 0.0598, Validation Accuracy: 98.10%
# Output Summary: Max=31.7876, Min=-31.1790, Median=1.6121, Mean=2.1108
#
# Epoch [67/1000], Training Loss: 0.0368
# Epoch [67/1000], Validation Loss: 0.0578, Validation Accuracy: 98.17%
# Output Summary: Max=32.0397, Min=-31.6707, Median=1.6473, Mean=2.1159
#
# Epoch [68/1000], Training Loss: 0.0353
# Epoch [68/1000], Validation Loss: 0.0566, Validation Accuracy: 98.27%
# Output Summary: Max=32.3286, Min=-31.8319, Median=1.6679, Mean=2.1463
#
# Epoch [69/1000], Training Loss: 0.0342
# Epoch [69/1000], Validation Loss: 0.0559, Validation Accuracy: 98.27%
# Output Summary: Max=32.4547, Min=-31.9717, Median=1.6898, Mean=2.1619
#
# Epoch [70/1000], Training Loss: 0.0333
# Epoch [70/1000], Validation Loss: 0.0554, Validation Accuracy: 98.25%
# Output Summary: Max=32.6105, Min=-32.1867, Median=1.7134, Mean=2.1740
#
# Epoch [71/1000], Training Loss: 0.0326
# Epoch [71/1000], Validation Loss: 0.0547, Validation Accuracy: 98.32%
# Output Summary: Max=32.7238, Min=-32.7582, Median=1.7105, Mean=2.1715
#
# Epoch [72/1000], Training Loss: 0.0319
# Epoch [72/1000], Validation Loss: 0.0542, Validation Accuracy: 98.35%
# Output Summary: Max=33.0539, Min=-33.8053, Median=1.7284, Mean=2.1765
#
# Epoch [73/1000], Training Loss: 0.0312
# Epoch [73/1000], Validation Loss: 0.0540, Validation Accuracy: 98.34%
# Output Summary: Max=33.4682, Min=-34.5988, Median=1.7517, Mean=2.1930
#
# Epoch [74/1000], Training Loss: 0.0306
# Epoch [74/1000], Validation Loss: 0.0541, Validation Accuracy: 98.39%
# Output Summary: Max=34.1505, Min=-35.3473, Median=1.8065, Mean=2.2450
#
# Epoch [75/1000], Training Loss: 0.0294
# Epoch [75/1000], Validation Loss: 0.0572, Validation Accuracy: 98.28%
# Output Summary: Max=34.7674, Min=-35.8825, Median=1.9121, Mean=2.3261
#
# Epoch [76/1000], Training Loss: 0.0285
# Epoch [76/1000], Validation Loss: 0.0587, Validation Accuracy: 98.29%
# Output Summary: Max=35.1469, Min=-36.6167, Median=1.9630, Mean=2.3622
#
# Epoch [77/1000], Training Loss: 0.0278
# Epoch [77/1000], Validation Loss: 0.0573, Validation Accuracy: 98.31%
# Output Summary: Max=35.6423, Min=-37.0244, Median=1.9459, Mean=2.3429
#
# Epoch [78/1000], Training Loss: 0.0275
# Epoch [78/1000], Validation Loss: 0.0575, Validation Accuracy: 98.37%
# Output Summary: Max=36.2419, Min=-37.5807, Median=1.9410, Mean=2.3270
#
# Epoch [79/1000], Training Loss: 0.0282
# Epoch [79/1000], Validation Loss: 0.0563, Validation Accuracy: 98.37%
# Output Summary: Max=36.7764, Min=-37.9540, Median=1.9928, Mean=2.3406
#
# Epoch [80/1000], Training Loss: 0.0287
# Epoch [80/1000], Validation Loss: 0.0516, Validation Accuracy: 98.42%
# Output Summary: Max=36.8452, Min=-38.8435, Median=1.9149, Mean=2.2113
#
# Epoch [81/1000], Training Loss: 0.0278
# Epoch [81/1000], Validation Loss: 0.0537, Validation Accuracy: 98.41%
# Output Summary: Max=38.1274, Min=-39.6312, Median=1.8285, Mean=2.1864
#
# Epoch [82/1000], Training Loss: 0.0275
# Epoch [82/1000], Validation Loss: 0.0534, Validation Accuracy: 98.45%
# Output Summary: Max=38.5426, Min=-39.4877, Median=1.7891, Mean=2.2057
#
# Epoch [83/1000], Training Loss: 0.0276
# Epoch [83/1000], Validation Loss: 0.0550, Validation Accuracy: 98.40%
# Output Summary: Max=37.8989, Min=-39.9181, Median=1.6790, Mean=2.1418
#
# Epoch [84/1000], Training Loss: 0.0279
# Epoch [84/1000], Validation Loss: 0.0561, Validation Accuracy: 98.38%
# Output Summary: Max=36.6303, Min=-39.7509, Median=1.6014, Mean=2.0782
#
# Epoch [85/1000], Training Loss: 0.0281
# Epoch [85/1000], Validation Loss: 0.0618, Validation Accuracy: 98.32%
# Output Summary: Max=38.0473, Min=-39.0078, Median=1.6288, Mean=2.0249
#
# Epoch [86/1000], Training Loss: 0.0282
# Epoch [86/1000], Validation Loss: 0.0635, Validation Accuracy: 98.19%
# Output Summary: Max=38.1739, Min=-39.3968, Median=1.6470, Mean=1.9576
#
# Epoch [87/1000], Training Loss: 0.0267
# Epoch [87/1000], Validation Loss: 0.0578, Validation Accuracy: 98.37%
# Output Summary: Max=38.2825, Min=-40.0893, Median=1.6500, Mean=2.0620
#
# Epoch [88/1000], Training Loss: 0.0254
# Epoch [88/1000], Validation Loss: 0.0530, Validation Accuracy: 98.48%
# Output Summary: Max=39.0970, Min=-40.1692, Median=1.5847, Mean=1.9798
#
# Epoch [89/1000], Training Loss: 0.0233
# Epoch [89/1000], Validation Loss: 0.0558, Validation Accuracy: 98.45%
# Output Summary: Max=39.7625, Min=-40.5651, Median=1.5320, Mean=1.9372
#
# Epoch [90/1000], Training Loss: 0.0266
# Epoch [90/1000], Validation Loss: 0.0620, Validation Accuracy: 98.18%
# Output Summary: Max=40.1155, Min=-40.3414, Median=1.4309, Mean=1.8514
#
# Epoch [91/1000], Training Loss: 0.0289
# Epoch [91/1000], Validation Loss: 0.0605, Validation Accuracy: 98.21%
# Output Summary: Max=39.3172, Min=-39.7498, Median=1.3301, Mean=1.8706
#
# Epoch [92/1000], Training Loss: 0.0266
# Epoch [92/1000], Validation Loss: 0.0509, Validation Accuracy: 98.54%
# Output Summary: Max=38.2786, Min=-39.8052, Median=1.3331, Mean=1.9534
#
# Epoch [93/1000], Training Loss: 0.0259
# Epoch [93/1000], Validation Loss: 0.0505, Validation Accuracy: 98.54%
# Output Summary: Max=37.9289, Min=-39.1223, Median=1.2827, Mean=1.8517
#
# Epoch [94/1000], Training Loss: 0.0250
# Epoch [94/1000], Validation Loss: 0.0518, Validation Accuracy: 98.53%
# Output Summary: Max=39.2614, Min=-40.4739, Median=1.3988, Mean=1.8689
#
# Epoch [95/1000], Training Loss: 0.0231
# Epoch [95/1000], Validation Loss: 0.0524, Validation Accuracy: 98.55%
# Output Summary: Max=39.1829, Min=-39.8806, Median=1.4017, Mean=1.8508
#
# Epoch [96/1000], Training Loss: 0.0226
# Epoch [96/1000], Validation Loss: 0.0543, Validation Accuracy: 98.47%
# Output Summary: Max=40.2331, Min=-40.8281, Median=1.4570, Mean=1.9750
#
# Epoch [97/1000], Training Loss: 0.0214
# Epoch [97/1000], Validation Loss: 0.0624, Validation Accuracy: 98.37%
# Output Summary: Max=42.1221, Min=-42.6101, Median=1.5545, Mean=2.0582
#
# Epoch [98/1000], Training Loss: 0.0192
# Epoch [98/1000], Validation Loss: 0.0630, Validation Accuracy: 98.34%
# Output Summary: Max=43.9484, Min=-44.2309, Median=1.5757, Mean=1.9951
#
# Epoch [99/1000], Training Loss: 0.0179
# Epoch [99/1000], Validation Loss: 0.0640, Validation Accuracy: 98.32%
# Output Summary: Max=44.3192, Min=-44.4190, Median=1.4805, Mean=1.9640
#
# Epoch [100/1000], Training Loss: 0.0173
# Epoch [100/1000], Validation Loss: 0.0639, Validation Accuracy: 98.25%
# Output Summary: Max=44.9990, Min=-44.8215, Median=1.4127, Mean=1.9426
#
# Epoch [101/1000], Training Loss: 0.0174
# Epoch [101/1000], Validation Loss: 0.0640, Validation Accuracy: 98.24%
# Output Summary: Max=45.0663, Min=-45.4472, Median=1.3734, Mean=1.8972
#
# Epoch [102/1000], Training Loss: 0.0179
# Epoch [102/1000], Validation Loss: 0.0628, Validation Accuracy: 98.31%
# Output Summary: Max=44.6881, Min=-45.5662, Median=1.2908, Mean=1.8013
#
# Epoch [103/1000], Training Loss: 0.0188
# Epoch [103/1000], Validation Loss: 0.0577, Validation Accuracy: 98.35%
# Output Summary: Max=42.6927, Min=-45.5133, Median=1.2744, Mean=1.7111
#
# Epoch [104/1000], Training Loss: 0.0189
# Epoch [104/1000], Validation Loss: 0.0537, Validation Accuracy: 98.46%
# Output Summary: Max=43.5183, Min=-46.1097, Median=1.2612, Mean=1.7945
#
# Epoch [105/1000], Training Loss: 0.0167
# Epoch [105/1000], Validation Loss: 0.0551, Validation Accuracy: 98.52%
# Output Summary: Max=45.7095, Min=-46.7616, Median=1.2571, Mean=1.8705
#
# Epoch [106/1000], Training Loss: 0.0140
# Epoch [106/1000], Validation Loss: 0.0560, Validation Accuracy: 98.55%
# Output Summary: Max=46.1643, Min=-48.2119, Median=1.3512, Mean=1.9092
#
# Epoch [107/1000], Training Loss: 0.0124
# Epoch [107/1000], Validation Loss: 0.0540, Validation Accuracy: 98.62%
# Output Summary: Max=46.6353, Min=-49.6144, Median=1.3774, Mean=1.9159
#
# Epoch [108/1000], Training Loss: 0.0116
# Epoch [108/1000], Validation Loss: 0.0547, Validation Accuracy: 98.58%
# Output Summary: Max=48.3376, Min=-50.6992, Median=1.3959, Mean=1.9707
#
# Epoch [109/1000], Training Loss: 0.0112
# Epoch [109/1000], Validation Loss: 0.0559, Validation Accuracy: 98.52%
# Output Summary: Max=49.1149, Min=-51.6843, Median=1.4431, Mean=2.0237
#
# Epoch [110/1000], Training Loss: 0.0110
# Epoch [110/1000], Validation Loss: 0.0570, Validation Accuracy: 98.51%
# Output Summary: Max=49.7324, Min=-52.5797, Median=1.4902, Mean=2.0513
#
# Epoch [111/1000], Training Loss: 0.0107
# Epoch [111/1000], Validation Loss: 0.0575, Validation Accuracy: 98.62%
# Output Summary: Max=50.4572, Min=-54.7797, Median=1.5064, Mean=2.0697
#
# Epoch [112/1000], Training Loss: 0.0105
# Epoch [112/1000], Validation Loss: 0.0576, Validation Accuracy: 98.59%
# Output Summary: Max=51.7439, Min=-56.1162, Median=1.4917, Mean=2.0056
#
# Epoch [113/1000], Training Loss: 0.0106
# Epoch [113/1000], Validation Loss: 0.0597, Validation Accuracy: 98.53%
# Output Summary: Max=52.1157, Min=-56.5872, Median=1.4814, Mean=2.0137
#
# Early stopping triggered after 113 epochs.
